# %%
# Import Dependencies
import pandas as pd
import random
import os
import csv
import requests
import json
import numpy as np

# %%
# Import data from csv file

happypath = os.path.join(".", "data", "happy.csv")
ginipath = os.path.join(".", "data", "gini.csv")
gdppath = os.path.join(".", "data", "pop.csv")
geopath = os.path.join(".", "data", "geo.csv")
happipath = os.path.join(".", "data", "happiness.csv")

happy_df = pd.read_csv(happypath)
gini_df = pd.read_csv(ginipath)
gdp_df = pd.read_csv(gdppath)
geo_df = pd.read_csv(geopath, encoding='latin-1')
happi_df = pd.read_csv(happipath)

# %%
# Create a loop to extract the most recent year data from each country.
country = []
year = []
happiness = []

for i in happy_df.index:
    if happy_df["Year"][i] < happy_df["Year"][i+1]:
        print(happy_df["Year"][i])
    else:
        country.append(happy_df["Country name"][i])
        year.append(happy_df["Year"][i])
        happiness.append(happy_df["Life Ladder"][i])
# Out:
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2010
# 2011
# 2012
# 2014
# 2016
# 2017
# 2011
# 2012
# 2013
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2006
# 2008
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2013
# 2014
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2008
# 2009
# 2011
# 2014
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2010
# 2011
# 2016
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2009
# 2010
# 2011
# 2012
# 2008
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2009
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2008
# 2009
# 2010
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2006
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2005
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2009
# 2010
# 2011
# 2012
# 2014
# 2016
# 2005
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2008
# 2012
# 2013
# 2015
# 2016
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2006
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2009
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2011
# 2013
# 2014
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2011
# 2012
# 2017
# 2006
# 2007
# 2008
# 2009
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2006
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2011
# 2016
# 2007
# 2008
# 2010
# 2014
# 2015
# 2016
# 2017
# 2012
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2009
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2006
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2011
# 2014
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2010
# 2011
# 2012
# 2013
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2011
# 2015
# 2017
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2014
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2012
# 2013
# 2015
# 2016
# 2017
# 2012
# 2013
# 2014
# 2015
# 2016
# 2006
# 2008
# 2012
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2006
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2009
# 2010
# 2011
# 2012
# 2005
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2009
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2010
# 2011
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2014
# 2015
# 2009
# 2010
# 2011
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2014
# 2015
# 2016
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2017
# 2009
# 2010
# 2011
# 2012
# 2011
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2009
# 2012
# 2014
# 2015
# 2016
# 2017
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2006
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2011
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2011
# 2013
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2009
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2006
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-fbba0f65957f> in <module>
#       5
#       6 for i in happy_df.index:
# ----> 7     if happy_df["Year"][i] < happy_df["Year"][i+1]:
#       8         print(happy_df["Year"][i])
#       9     else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1704

# %%
# Create a new dataframe to hold the data from the loop

happiness_df = pd.DataFrame(list(zip(country, year, happiness)),
                           columns=["country", "year", "happiness"])
happiness_df["year"] = happiness_df["year"].astype(str)
happiness_df = happiness_df.rename(index=str, columns={"country":"country_name"})
happiness_df = happiness_df.round({"happiness": 3})
happiness_df.head()
# Out:
#   country_name  year  happiness
# 0  Afghanistan  2018      2.694
# 1      Albania  2018      5.004
# 2      Algeria  2018      5.043
# 3       Angola  2014      3.795
# 4    Argentina  2018      5.793

# %%
# Create a loop to extract the most recent year data from each country
country = []
country_code = []
year = []
gini = []

for i in gini_df.index:
    if gini_df["Year"][i] < gini_df["Year"][i+1]:
        print(gini_df["Year"][i])
    else:
        country.append(gini_df["Country Name"][i])
        country_code.append(gini_df["Country Code"][i])
        year.append(gini_df["Year"][i])
        gini.append(gini_df["Value"][i])
# Out:
# 1996
# 2002
# 2005
# 2008
# 1988
# 1995
# 1980
# 1986
# 1987
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1999
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1981
# 1985
# 1989
# 1995
# 2001
# 2003
# 2008
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1995
# 2001
# 2002
# 2003
# 2004
# 1983
# 1985
# 1988
# 1991
# 1995
# 2000
# 2005
# 2010
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1993
# 1994
# 1996
# 1997
# 1998
# 1999
# 2003
# 2011
# 2003
# 2007
# 1990
# 1997
# 1999
# 2000
# 2001
# 2002
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2011
# 2012
# 2013
# 2014
# 2015
# 2001
# 2004
# 2007
# 2011
# 1985
# 1993
# 2002
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1992
# 1993
# 1995
# 1996
# 1997
# 1998
# 1999
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2011
# 2012
# 2013
# 2014
# 1992
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 1994
# 1998
# 2003
# 2009
# 1992
# 1998
# 2006
# 2001
# 1996
# 2001
# 2007
# 1981
# 1987
# 1991
# 1994
# 1997
# 1998
# 2000
# 2004
# 2007
# 2010
# 1992
# 2003
# 2003
# 1987
# 1990
# 1992
# 1994
# 1996
# 1998
# 2000
# 2003
# 2006
# 2009
# 2011
# 2013
# 2008
# 1992
# 1996
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2004
# 2004
# 2005
# 1981
# 1986
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1985
# 1986
# 1987
# 1988
# 1992
# 1995
# 1998
# 2002
# 2008
# 1988
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1993
# 1996
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2002
# 2012
# 1986
# 1989
# 1992
# 1996
# 1997
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1987
# 1994
# 1998
# 1999
# 2000
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1990
# 1995
# 1999
# 2004
# 2008
# 2010
# 2012
# 1991
# 1995
# 1996
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1993
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1995
# 1999
# 2004
# 2010
# 2002
# 2008
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1998
# 2003
# 2010
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1991
# 1994
# 2000
# 2001
# 2004
# 2006
# 2007
# 2010
# 2011
# 2013
# 1987
# 1988
# 1991
# 1998
# 2005
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1986
# 1989
# 2000
# 2006
# 1991
# 1994
# 2002
# 2007
# 1993
# 2002
# 1998
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1987
# 1989
# 1993
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2011
# 1986
# 1990
# 1994
# 1998
# 2005
# 2006
# 2009
# 2013
# 2006
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 1979
# 1986
# 1992
# 1997
# 2001
# 2005
# 2007
# 2010
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 1988
# 1990
# 1993
# 1996
# 1999
# 2002
# 2004
# 1986
# 1992
# 1997
# 2002
# 2006
# 2008
# 1996
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1992
# 1994
# 1997
# 2005
# 2006
# 2008
# 2010
# 2003
# 2005
# 2006
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1998
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1992
# 1997
# 2002
# 2007
# 1993
# 1995
# 1996
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1986
# 1994
# 2002
# 2007
# 1993
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2010
# 2011
# 2012
# 2013
# 1980
# 1993
# 1997
# 1999
# 2001
# 2005
# 2010
# 1997
# 2004
# 1984
# 1987
# 1989
# 1992
# 1995
# 1997
# 2004
# 2007
# 2002
# 1994
# 2001
# 2006
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 1987
# 1993
# 1995
# 2000
# 2004
# 2008
# 2006
# 1984
# 1992
# 1994
# 1996
# 1998
# 2000
# 2002
# 2004
# 2005
# 2006
# 2008
# 2010
# 2012
# 2014
# 2005
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1995
# 1998
# 2002
# 2007
# 2010
# 2011
# 2012
# 2014
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 1984
# 1990
# 1998
# 2000
# 1996
# 2002
# 2008
# 2014
# 2003
# 1995
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1993
# 1998
# 2001
# 2005
# 2009
# 1992
# 1994
# 2005
# 2007
# 2011
# 1985
# 1992
# 1996
# 2003
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1987
# 1990
# 1996
# 1998
# 2001
# 2004
# 2005
# 2007
# 2010
# 2011
# 1979
# 1989
# 1991
# 1995
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1996
# 1990
# 1995
# 1997
# 1999
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1985
# 1988
# 1991
# 1994
# 1997
# 2000
# 2003
# 2006
# 2009
# 2012
# 1993
# 1996
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 1993
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1984
# 2000
# 2005
# 2010
# 2000
# 1991
# 1994
# 2001
# 2005
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2013
# 2003
# 1996
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1993
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2005
# 1993
# 1996
# 2000
# 2005
# 2008
# 2010
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1985
# 1990
# 1995
# 2002
# 2006
# 2009
# 2012
# 1995
# 1994
# 2000
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 1999
# 2003
# 2004
# 2007
# 2009
# 1991
# 2000
# 2007
# 1981
# 1988
# 1990
# 1992
# 1994
# 1996
# 1998
# 1999
# 2000
# 2002
# 2004
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2001
# 2007
# 2006
# 2011
# 2001
# 1988
# 1985
# 1990
# 1995
# 2000
# 2005
# 1987
# 1994
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1998
# 1989
# 1992
# 1996
# 1999
# 2002
# 2005
# 2009
# 1995
# 1996
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1979
# 1986
# 1991
# 1994
# 1997
# 2000
# 2004
# 2007
# 2010
# 2013
# 1981
# 1989
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1998
# 2000
# 2002
# 2003
# 1981
# 1987
# 1989
# 1992
# 1995
# 1998
# 1999
# 2001
# 2002
# 2003
# 2004
# 2005
# 1992
# 1998
# 2002
# 2004
# 2006
# 2008
# 2010
# 2012
# 2004
# 2005
# 2006
# 2007
# 2009
# 2010
# 1998
# 2005
# 1991
# 1993
# 1996
# 1998
# 2002
# 2004
# 2006
# 2010
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-7e75cedd9109> in <module>
#       6
#       7 for i in gini_df.index:
# ----> 8     if gini_df["Year"][i] < gini_df["Year"][i+1]:
#       9         print(gini_df["Year"][i])
#      10     else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1378

# %%
# Create a new dataframe to hold the data from the loop
dict = {"country_name":country, "code":country_code, "gyear":year, "gini":gini}
gini_index_df = pd.DataFrame(dict)

# %%
gini_index_df["gyear"] = gini_index_df["gyear"].astype(str)
gini_index_df.head()
# Out:
#   country_name code gyear  gini
# 0      Albania  ALB  2012  29.0
# 1      Algeria  DZA  2011  27.6
# 2       Angola  AGO  2008  42.7
# 3    Argentina  ARG  2016  42.4
# 4      Armenia  ARM  2016  32.5

# %%
list(gdp_df.columns.values)

# %%
# Looop through the data and extract the data for the project
country = []
region_id = []
gdp = []
pop = []

for i in gdp_df.index:
    if gdp_df["gdp"][i] == "NaN":
        print(gdp_df["country_name"][i])
    else:
        country.append(gdp_df["country_name"][i])
        region_id.append(gdp_df["region_id"][i])
        gdp.append(gdp_df["gdp"][i])
        pop.append(gdp_df["population_population_number_of_people"][i])

# %%
print(len(country))

# %%
# Create a new dataframe to hold the data
dict = {"country_name":country, "region_id":region_id, 
       "gdp":gdp, "population":pop}
demo_df = pd.DataFrame(dict)

# %%
demo_df.head()
# Out:
#   country_name region_id           gdp  population
# 0        Aruba       LCN           NaN    103187.0
# 1  Afghanistan       SAS  2.141361e+10  34656032.0
# 2       Angola       SSF  1.030420e+11  25096150.0
# 3      Albania       ECS  1.347108e+10   2880703.0
# 4      Andorra       ECS  3.319880e+09     82431.0

# %%
geo_df = geo_df.rename(index=str, columns={"name":"country_name"})
geo_df.head()
# Out:
#   country   latitude  longitude          country_name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla

# %%
print(gini_index_df["gyear"].dtype)
print(happiness_df["year"].dtype)
# Out:
# object
# object

# %%
# Merging the dataframes

joined_df = pd.merge(demo_df, geo_df, on='country_name', how='inner')

# %%
joined_df = pd.merge(joined_df, gini_index_df, on="country_name", how="inner")

# %%
joined_df = pd.merge(joined_df, happiness_df, on="country_name", how="inner")

# %%
joined_df["gdpPerCap"] = round(joined_df["gdp"] / joined_df["population"], 2)
joined_df.head()
# print(joined_df["gdpPerCap"].min())
# Out:
#   country_name region_id           gdp  population country   latitude  \
# 0       Angola       SSF  1.030420e+11  25096150.0      AO -11.202692
# 1      Albania       ECS  1.347108e+10   2880703.0      AL  41.153332
# 2    Argentina       LCN  4.475180e+11  42981515.0      AR -38.416097
# 3      Armenia       ECS  1.150200e+10   2906220.0      AM  40.069099
# 4    Australia       EAS  1.349300e+12  23789338.0      AU -25.274398
#
#     longitude code gyear  gini  year  happiness  gdpPerCap
# 0   17.873887  AGO  2008  42.7  2014      3.795    4105.89
# 1   20.168331  ALB  2012  29.0  2018      5.004    4676.32
# 2  -63.616672  ARG  2016  42.4  2018      5.793   10411.87
# 3   45.038189  ARM  2016  32.5  2018      5.062    3957.72
# 4  133.775136  AUS  2010  34.7  2018      7.177   56718.69

# %%
joined_df.to_csv("outputs/joined_data.csv", index=False, header=True)

# %%
joined_df.groupby('region_id')['country_name'].nunique()

# %%
joined_df.groupby('region_id')['gini', 'happiness'].mean()

# %%
joined_df.groupby("region_id")["population", "gdp"].sum()

# %%
happi_df.head()
list(happi_df)
# Out:
# ['Country',
#  'Happiness score',
#  'Whisker-high',
#  'Whisker-low',
#  'Dystopia (1.88) + residual',
#  'Explained by: GDP per capita',
#  'Explained by: Social support',
#  'Explained by: Healthy life expectancy',
#  'Explained by: Freedom to make life choices',
#  'Explained by: Generosity',
#  'Explained by: Perceptions of corruption']

# %%
happy_df = pd.merge(happiness_df, geo_df, on='country_name', how='inner')
print(len(happy_df))
print(happy_df.head())
# Out:
# 154
#   country_name  year  happiness country   latitude  longitude
# 0  Afghanistan  2018      2.694      AF  33.939110  67.709953
# 1      Albania  2018      5.004      AL  41.153332  20.168331
# 2      Algeria  2018      5.043      DZ  28.033886   1.659626
# 3       Angola  2014      3.795      AO -11.202692  17.873887
# 4    Argentina  2018      5.793      AR -38.416097 -63.616672

# %%
# Export the dataframe and save it as a CSV file for later use
happy_df.to_csv("outputs/happy.csv", index=False, header=True)

# %%
gini_df = pd.merge(gini_index_df, geo_df, on='country_name', how='inner')
print(len(gini_df))
# Out:
# 133

# %%
# Save data as CSV file for later use
gini_df.to_csv("outputs/gini.csv", index=False, header=True)

# %%
demo_df = pd.merge(demo_df, geo_df, on='country_name', how='inner')
print(len(demo_df))
# Out:
# 182

# %%
# Save it as CSV file for later use
demo_df.to_csv("outputs/demographic.csv", index=False, header=True)

# %%
# Creating SQLite Database
from sqlalchemy import create_engine, Column, Integer, String, Float, Text
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import Session
Base = declarative_base()

# %%
# Define the happiness table
class Happiness(Base):
    __tablename__ = "happiness"
    id =Column(Integer, primary_key=True)
    country = Column(String)
    year = Column(Text)
    happiness = Column(Float)
    lat = Column(Float)
    lon = Column(Float)

# %%
# Table only exists in python and not in the actual database yet
Base.metadata.tables
# Out:
# immutabledict({'happiness': Table('happiness', MetaData(bind=None), Column('id', Integer(), table=<happiness>, primary_key=True, nullable=False), Column('country', String(), table=<happiness>), Column('year', Text(), table=<happiness>), Column('happiness', Float(), table=<happiness>), Column('lat', Float(), table=<happiness>), Column('lon', Float(), table=<happiness>), schema=None)})

# %%
# Create the database engine
engine = create_engine("sqlite:///./db/data.sqlite")

# %%
# This is where the tables was created in the database
Base.metadata.create_all(engine)

# %%
# The ORM's "handle" to the database is the Session
session = Session(engine)

# %%
# Adding the data to the session

for i in happy_df.index:
    session.add(Happiness(
        country = happy_df["country_name"][i], 
        year = happy_df["year"][i],
        happiness = happy_df["happiness"][i],
        lat = happy_df["latitude"][i],
        lon = happy_df["longitude"][i]
    ))

# %%
# Data has not been added to the database yet
engine.execute("SELECT * FROM Happiness").fetchall()
# Out:
# []

# %%
# Use the new attribute to see the queue of data ready to go into the database
session.new
# Out:
# IdentitySet([<__main__.Happiness object at 0x00000201AD988EF0>, <__main__.Happiness object at 0x00000201AD988F60>, <__main__.Happiness object at 0x00000201AD9B3048>, <__main__.Happiness object at 0x00000201AD9B30B8>, <__main__.Happiness object at 0x00000201AD9B3128>, <__main__.Happiness object at 0x00000201AD9B3198>, <__main__.Happiness object at 0x00000201AD9B3208>, <__main__.Happiness object at 0x00000201AD9B3278>, <__main__.Happiness object at 0x00000201AD9B32E8>, <__main__.Happiness object at 0x00000201AD9B3358>, <__main__.Happiness object at 0x00000201AD9B33C8>, <__main__.Happiness object at 0x00000201AD9B3438>, <__main__.Happiness object at 0x00000201AD9B34A8>, <__main__.Happiness object at 0x00000201AD9B3518>, <__main__.Happiness object at 0x00000201AD9B3588>, <__main__.Happiness object at 0x00000201AD9B35F8>, <__main__.Happiness object at 0x00000201AD9B3668>, <__main__.Happiness object at 0x00000201AD9B36D8>, <__main__.Happiness object at 0x00000201AD9B3748>, <__main__.Happiness object at 0x00000201AD9B37B8>, <__main__.Happiness object at 0x00000201AD9B3828>, <__main__.Happiness object at 0x00000201AD9B3898>, <__main__.Happiness object at 0x00000201AD9B3908>, <__main__.Happiness object at 0x00000201AD9B3978>, <__main__.Happiness object at 0x00000201AD9B39E8>, <__main__.Happiness object at 0x00000201AD9B3A58>, <__main__.Happiness object at 0x00000201AD9B3AC8>, <__main__.Happiness object at 0x00000201AD9B3B38>, <__main__.Happiness object at 0x00000201AD9B3BA8>, <__main__.Happiness object at 0x00000201AD9B3C18>, <__main__.Happiness object at 0x00000201AD9B3C88>, <__main__.Happiness object at 0x00000201AD9B3CF8>, <__main__.Happiness object at 0x00000201AD9B3D68>, <__main__.Happiness object at 0x00000201AD9B3DD8>, <__main__.Happiness object at 0x00000201AD9B3E48>, <__main__.Happiness object at 0x00000201AD9B3EB8>, <__main__.Happiness object at 0x00000201AD9B3F28>, <__main__.Happiness object at 0x00000201AD9B3F98>, <__main__.Happiness object at 0x00000201AD988F98>, <__main__.Happiness object at 0x00000201AD9BE080>, <__main__.Happiness object at 0x00000201AD9BE128>, <__main__.Happiness object at 0x00000201AD9BE208>, <__main__.Happiness object at 0x00000201AD9BE278>, <__main__.Happiness object at 0x00000201AD9BE2E8>, <__main__.Happiness object at 0x00000201AD9BE358>, <__main__.Happiness object at 0x00000201AD9BE3C8>, <__main__.Happiness object at 0x00000201AD9BE438>, <__main__.Happiness object at 0x00000201AD9BE4A8>, <__main__.Happiness object at 0x00000201AD9BE518>, <__main__.Happiness object at 0x00000201AD9BE588>, <__main__.Happiness object at 0x00000201AD9BE5F8>, <__main__.Happiness object at 0x00000201AD9BE668>, <__main__.Happiness object at 0x00000201AD9BE6D8>, <__main__.Happiness object at 0x00000201AD9BE748>, <__main__.Happiness object at 0x00000201AD9BE7B8>, <__main__.Happiness object at 0x00000201AD9BE828>, <__main__.Happiness object at 0x00000201AD9BE898>, <__main__.Happiness object at 0x00000201AD9BE908>, <__main__.Happiness object at 0x00000201AD9BE978>, <__main__.Happiness object at 0x00000201AD9BE9E8>, <__main__.Happiness object at 0x00000201AD9BEA58>, <__main__.Happiness object at 0x00000201AD9BEAC8>, <__main__.Happiness object at 0x00000201AD9BEB38>, <__main__.Happiness object at 0x00000201AD9BEBA8>, <__main__.Happiness object at 0x00000201AD9BEC18>, <__main__.Happiness object at 0x00000201AD9BEC88>, <__main__.Happiness object at 0x00000201AD9BECF8>, <__main__.Happiness object at 0x00000201AD9BED68>, <__main__.Happiness object at 0x00000201AD9BEDD8>, <__main__.Happiness object at 0x00000201AD9BEE48>, <__main__.Happiness object at 0x00000201AD9BEEB8>, <__main__.Happiness object at 0x00000201AD9BEF28>, <__main__.Happiness object at 0x00000201AD9BEF98>, <__main__.Happiness object at 0x00000201AD9C9048>, <__main__.Happiness object at 0x00000201AD9C90B8>, <__main__.Happiness object at 0x00000201AD9C9128>, <__main__.Happiness object at 0x00000201AD9C9198>, <__main__.Happiness object at 0x00000201AD9C9208>, <__main__ ...

# %%
# Commit flushes whatever remaining changes remain to the database and commits the transaction
session.commit()

# %%
# Confirm nothing new to add
session.new
# Out:
# IdentitySet([])

# %%
# Query the database to check the data
session.query(Happiness.country, Happiness.lat, Happiness.happiness).all()
# Out:
# [('Afghanistan', 33.93911, 2.694),
#  ('Albania', 41.153332, 5.004),
#  ('Algeria', 28.033886, 5.043),
#  ('Angola', -11.202691999999999, 3.795),
#  ('Argentina', -38.416097, 5.793),
#  ('Armenia', 40.069099, 5.062),
#  ('Australia', -25.274398, 7.177),
#  ('Austria', 47.516231, 7.396),
#  ('Azerbaijan', 40.143105, 5.168),
#  ('Bahrain', 25.930414000000003, 6.227),
#  ('Bangladesh', 23.684994, 4.499),
#  ('Belarus', 53.709807, 5.234),
#  ('Belgium', 50.503887, 6.892),
#  ('Belize', 17.189877, 5.956),
#  ('Benin', 9.30769, 5.82),
#  ('Bhutan', 27.514162, 5.082),
#  ('Bolivia', -16.290154, 5.916),
#  ('Bosnia and Herzegovina', 43.915886, 5.887),
#  ('Botswana', -22.328474, 3.461),
#  ('Brazil', -14.235004, 6.191),
#  ('Bulgaria', 42.733883, 5.099),
#  ('Burkina Faso', 12.238333, 4.927),
#  ('Burundi', -3.3730559999999996, 3.775),
#  ('Cambodia', 12.565679, 5.122),
#  ('Cameroon', 7.369722, 5.251),
#  ('Canada', 56.130366, 7.175),
#  ('Central African Republic', 6.611111, 3.476),
#  ('Chad', 15.454166, 4.486),
#  ('Chile', -35.675146999999996, 6.436),
#  ('China', 35.86166, 5.131),
#  ('Colombia', 4.570868, 5.984),
#  ('Comoros', -11.875001, 3.973),
#  ('Costa Rica', 9.748917, 7.141),
#  ('Croatia', 45.1, 5.536),
#  ('Cuba', 21.521757, 5.418),
#  ('Cyprus', 35.126413, 6.276),
#  ('Czech Republic', 49.817492, 7.034),
#  ('Denmark', 56.26392, 7.649),
#  ('Djibouti', 11.825138, 4.369),
#  ('Dominican Republic', 18.735692999999998, 5.433),
#  ('Ecuador', -1.8312389999999998, 6.128),
#  ('Egypt', 26.820553000000004, 4.005),
#  ('El Salvador', 13.794185, 6.276),
#  ('Estonia', 58.595271999999994, 6.091),
#  ('Ethiopia', 9.145, 4.379),
#  ('Finland', 61.92411, 7.858),
#  ('France', 46.227638, 6.666),
#  ('Gabon', -0.803689, 4.783),
#  ('Gambia', 13.443182, 4.922),
#  ('Georgia', 42.315407, 4.659),
#  ('Germany', 51.165690999999995, 7.118),
#  ('Ghana', 7.946527000000001, 5.481),
#  ('Greece', 39.074208, 5.409),
#  ('Guatemala', 15.783470999999999, 6.627),
#  ('Guinea', 9.945587, 5.252),
#  ('Guyana', 4.860416000000001, 5.993),
#  ('Haiti', 18.971187, 3.615),
#  ('Honduras', 15.199998999999998, 5.908),
#  ('Hungary', 47.162494, 6.065),
#  ('Iceland', 64.96305100000001, 7.476),
#  ('India', 20.593684, 3.818),
#  ('Indonesia', -0.789275, 5.34),
#  ('Iran', 32.427908, 4.278),
#  ('Iraq', 33.223191, 4.462),
#  ('Ireland', 53.41291, 6.962),
#  ('Israel', 31.046051000000002, 6.927),
#  ('Italy', 41.87194, 6.517),
#  ('Jamaica', 18.109581, 5.89),
#  ('Japan', 36.204824, 5.794),
#  ('Jordan', 30.585164000000002, 4.639),
#  ('Kazakhstan', 48.019573, 6.008),
#  ('Kenya', -0.023559, 4.656),
#  ('Kosovo', 42.602636, 6.392),
#  ('Kuwait', 29.311659999999996, 6.094),
#  ('Kyrgyzstan', 41.20438, 5.297),
#  ('Laos', 19.856270000000002, 4.859),
#  ('Latvia', 56.879635, 5.901),
#  ('Lebanon', 33.854721000000005, 5.167),
#  ('Lesotho', -29.609988, 3.795),
#  ('Liberia', 6.4280550000000005, 4.135),
#  ('Libya', 26.3351, 5.494),
#  ('Lithuania', 55.169438, 6.309),
#  ('Luxembourg', 49.815273, 7.243),
#  ('Madagascar', -18.766947000000002, 4.071),
#  ('Malawi', -13.254307999999998, 3.335),
#  ('Malaysia', 4.210483999999999, 5.339),
#  ('Mali', 17.570692, 4.416),
#  ('Malta', 35.937496, 6.91),
#  ('Mauritania', 21.00789, 4.314),
#  ('Mauritius', -20.348404000000002, 5.882),
#  ('Mexico', 23.634501, 6.55),
#  ('Moldova', 47.411631, 5.682),
#  ('Mongolia', 46.862496, 5.465),
#  ('Montenegro', 42.708678000000006, 5.65),
#  ('Morocco', 31.791702, 4.897),
#  ('Mozambique', -18.665695, 4.654),
#  ('Namibia', -22.957639999999998, 4.834),
#  ('Nepal', 28.394857000000002, 4.91),
#  ('Netherlands', 52.132633, 7.463),
#  ('New Zealand', -40.900557, 7.37),
#  ('Nicaragua', 12.865416, 5.819),
#  ('Niger', 17.607789, 5.164),
#  ('Nigeria', 9.081999, 5.252),
#  ('Norway', 60.472024, 7.444),
#  ('Oman', 21.512583, 6.853),
#  ('Pakistan', 30.375321000000003, 5.472),
#  ('Palestinian Territories', 31.952162, 4.554),
#  ('Panama', 8.537981, 6.281),
#  ('Paraguay', -23.442503, 5.713),
#  ('Peru', -9.189967, 5.68),
#  ('Philippines', 12.879721, 5.869),
#  ('Poland', 51.919438, 6.201),
#  ('Portugal', 39.399871999999995, 5.92),
#  ('Qatar', 25.354826, 6.375),
#  ('Romania', 45.943160999999996, 6.151),
#  ('Russia', 61.52401, 5.514),
#  ('Rwanda', -1.940278, 3.561),
#  ('Saudi Arabia', 23.885942, 6.356),
#  ('Senegal', 14.497401000000002, 4.769),
#  ('Serbia', 44.016521000000004, 5.936),
#  ('Sierra Leone', 8.460555000000001, 4.306),
#  ('Singapore', 1.352083, 6.375),
#  ('Slovakia', 48.669026, 6.235),
#  ('Slovenia', 46.151241, 6.249),
#  ('Somalia', 5.152149, 4.668),
#  ('South Africa', -30.559482, 4.884),
#  ('South Korea', 35.907757000000004, 5.84),
#  ('Spain', 40.463667, 6.513),
#  ('Sri Lanka', 7.873054, 4.4),
#  ('Sudan', 12.862807, 4.139),
#  ('Suriname', 3.9193050000000005, 6.269),
#  ('Swaziland', -26.522503000000004, 4.212),
#  ('Sweden', 60.128161, 7.375),
#  ('Switzerland', 46.818188, 7.509),
#  ('Syria', 34.802075, 3.462),
#  ('Tajikistan', 38.861034000000004, 5.829),
#  ('Tanzania', -6.369028, 3.445),
#  ('Thailand', 15.870032, 6.012),
#  ('Togo', 8.619543, 4.023),
#  ('Trinidad and Tobago', 10.691803, 6.192),
#  ('Tunisia', 33.886917, 4.741),
#  ('Turkey', 38.963745, 5.186),
#  ('Turkmenistan', 38.969719, 4.621),
#  ('Uganda', 1.373333, 4.322),
#  ('Ukraine', 48.379433, 4.662),
#  ('United Arab Emirates', 23.424076, 6.604),
#  ('United Kingdom', 55.378051, 7.233),
#  ('United States', 37.09024, 6.883),
#  ('Uruguay', -32.522779, 6.372),
#  ('Uzbekistan', 41.377491, 6.205),
#  ('Venezuela', 6.42375, 5.006),
#  ('Vietnam', 14.058323999999999, 5.296),
#  ('Yemen', 15.552726999999999, 3.058),
#  ('Zambia', -13.133897, 4.041)]

# %%
# Create a class for gini
class Gini(Base):
    __tablename__ = "gini"
    id =Column(Integer, primary_key=True)
    country = Column(String)
    country_code = Column(String)
    year = Column(Text)
    gini = Column(Float)
    lat = Column(Float)
    lon = Column(Float)

# %%
Base.metadata.tables
# Out:
# immutabledict({'happiness': Table('happiness', MetaData(bind=None), Column('id', Integer(), table=<happiness>, primary_key=True, nullable=False), Column('country', String(), table=<happiness>), Column('year', Text(), table=<happiness>), Column('happiness', Float(), table=<happiness>), Column('lat', Float(), table=<happiness>), Column('lon', Float(), table=<happiness>), schema=None), 'gini': Table('gini', MetaData(bind=None), Column('id', Integer(), table=<gini>, primary_key=True, nullable=False), Column('country', String(), table=<gini>), Column('country_code', String(), table=<gini>), Column('year', Text(), table=<gini>), Column('gini', Float(), table=<gini>), Column('lat', Float(), table=<gini>), Column('lon', Float(), table=<gini>), schema=None)})

# %%
engine = create_engine("sqlite:///./db/data.sqlite")

# %%
Base.metadata.create_all(engine)

# %%
session = Session(engine)

# %%
for i in gini_df.index:
    session.add(Gini(
        country = gini_df["country_name"][i], 
        country_code = gini_df["code"][i],
        year = gini_df["gyear"][i],
        gini = gini_df["gini"][i],
        lat = gini_df["latitude"][i],
        lon = gini_df["longitude"][i]
    ))

# %%
engine.execute("SELECT * FROM Gini").fetchall()
# Out:
# []

# %%
session.new
# Out:
# IdentitySet([<__main__.Gini object at 0x00000201ADA2CA58>, <__main__.Gini object at 0x00000201ADA2CCC0>, <__main__.Gini object at 0x00000201ADA2C438>, <__main__.Gini object at 0x00000201ADA2C550>, <__main__.Gini object at 0x00000201ADA2C278>, <__main__.Gini object at 0x00000201ADA2C390>, <__main__.Gini object at 0x00000201ADA2C358>, <__main__.Gini object at 0x00000201ADA37BE0>, <__main__.Gini object at 0x00000201ADA37C50>, <__main__.Gini object at 0x00000201ADA37CC0>, <__main__.Gini object at 0x00000201ADA37D30>, <__main__.Gini object at 0x00000201ADA37DA0>, <__main__.Gini object at 0x00000201ADA37E10>, <__main__.Gini object at 0x00000201ADA37E80>, <__main__.Gini object at 0x00000201ADA37EF0>, <__main__.Gini object at 0x00000201ADA37F60>, <__main__.Gini object at 0x00000201ADA37FD0>, <__main__.Gini object at 0x00000201ADA41080>, <__main__.Gini object at 0x00000201ADA410F0>, <__main__.Gini object at 0x00000201ADA41160>, <__main__.Gini object at 0x00000201ADA411D0>, <__main__.Gini object at 0x00000201ADA41240>, <__main__.Gini object at 0x00000201ADA412B0>, <__main__.Gini object at 0x00000201ADA41320>, <__main__.Gini object at 0x00000201ADA41390>, <__main__.Gini object at 0x00000201ADA41400>, <__main__.Gini object at 0x00000201ADA41470>, <__main__.Gini object at 0x00000201ADA414E0>, <__main__.Gini object at 0x00000201ADA41550>, <__main__.Gini object at 0x00000201ADA415C0>, <__main__.Gini object at 0x00000201ADA41630>, <__main__.Gini object at 0x00000201ADA416A0>, <__main__.Gini object at 0x00000201ADA41710>, <__main__.Gini object at 0x00000201ADA41780>, <__main__.Gini object at 0x00000201ADA41828>, <__main__.Gini object at 0x00000201ADA41908>, <__main__.Gini object at 0x00000201ADA41978>, <__main__.Gini object at 0x00000201ADA419E8>, <__main__.Gini object at 0x00000201ADA41A58>, <__main__.Gini object at 0x00000201ADA41AC8>, <__main__.Gini object at 0x00000201ADA41B38>, <__main__.Gini object at 0x00000201ADA41BA8>, <__main__.Gini object at 0x00000201ADA41C18>, <__main__.Gini object at 0x00000201ADA41C88>, <__main__.Gini object at 0x00000201ADA41CF8>, <__main__.Gini object at 0x00000201ADA41D68>, <__main__.Gini object at 0x00000201ADA41DD8>, <__main__.Gini object at 0x00000201ADA41E48>, <__main__.Gini object at 0x00000201ADA41EB8>, <__main__.Gini object at 0x00000201ADA41F28>, <__main__.Gini object at 0x00000201ADA41F98>, <__main__.Gini object at 0x00000201ADA4D048>, <__main__.Gini object at 0x00000201ADA4D0B8>, <__main__.Gini object at 0x00000201ADA4D128>, <__main__.Gini object at 0x00000201ADA4D198>, <__main__.Gini object at 0x00000201ADA4D208>, <__main__.Gini object at 0x00000201ADA4D278>, <__main__.Gini object at 0x00000201ADA4D2E8>, <__main__.Gini object at 0x00000201ADA4D358>, <__main__.Gini object at 0x00000201ADA4D3C8>, <__main__.Gini object at 0x00000201ADA4D438>, <__main__.Gini object at 0x00000201ADA4D4A8>, <__main__.Gini object at 0x00000201ADA4D518>, <__main__.Gini object at 0x00000201ADA4D588>, <__main__.Gini object at 0x00000201ADA4D5F8>, <__main__.Gini object at 0x00000201ADA4D668>, <__main__.Gini object at 0x00000201ADA4D6D8>, <__main__.Gini object at 0x00000201ADA4D748>, <__main__.Gini object at 0x00000201ADA4D7B8>, <__main__.Gini object at 0x00000201ADA4D828>, <__main__.Gini object at 0x00000201ADA4D898>, <__main__.Gini object at 0x00000201ADA4D908>, <__main__.Gini object at 0x00000201ADA4D978>, <__main__.Gini object at 0x00000201ADA4D9E8>, <__main__.Gini object at 0x00000201ADA4DA58>, <__main__.Gini object at 0x00000201ADA4DAC8>, <__main__.Gini object at 0x00000201ADA4DB38>, <__main__.Gini object at 0x00000201ADA4DBA8>, <__main__.Gini object at 0x00000201ADA4DC18>, <__main__.Gini object at 0x00000201ADA4DC88>, <__main__.Gini object at 0x00000201ADA4DCF8>, <__main__.Gini object at 0x00000201ADA4DD68>, <__main__.Gini object at 0x00000201ADA2CD30>, <__main__.Gini object at 0x00000201ADA4DE10>, <__main__.Gini object at 0x00000201ADA4DE80>, <__main__.Gini object at 0x00000201ADA4DEF0>, <__main__.Gini object at 0x0000 ...

# %%
session.commit()

# %%
session.new
# Out:
# IdentitySet([])

# %%
session.query(Gini.country, Gini.country_code, Gini.year, Gini.gini).all()
# Out:
# [('Albania', 'ALB', '2012', 29.0),
#  ('Algeria', 'DZA', '2011', 27.6),
#  ('Angola', 'AGO', '2008', 42.7),
#  ('Argentina', 'ARG', '2016', 42.4),
#  ('Armenia', 'ARM', '2016', 32.5),
#  ('Australia', 'AUS', '2010', 34.7),
#  ('Austria', 'AUT', '2015', 30.5),
#  ('Azerbaijan', 'AZE', '2005', 16.6),
#  ('Bangladesh', 'BGD', '2016', 32.4),
#  ('Belarus', 'BLR', '2016', 27.0),
#  ('Belgium', 'BEL', '2015', 27.7),
#  ('Benin', 'BEN', '2015', 47.8),
#  ('Bhutan', 'BTN', '2012', 38.8),
#  ('Bolivia', 'BOL', '2016', 44.6),
#  ('Bosnia and Herzegovina', 'BIH', '2015', 32.7),
#  ('Botswana', 'BWA', '2009', 60.5),
#  ('Brazil', 'BRA', '2015', 51.3),
#  ('Bulgaria', 'BGR', '2014', 37.4),
#  ('Burkina Faso', 'BFA', '2014', 35.3),
#  ('Burundi', 'BDI', '2013', 38.6),
#  ('Cameroon', 'CMR', '2014', 46.6),
#  ('Canada', 'CAN', '2013', 34.0),
#  ('Central African Republic', 'CAF', '2008', 56.2),
#  ('Chad', 'TCD', '2011', 43.3),
#  ('Chile', 'CHL', '2015', 47.7),
#  ('China', 'CHN', '2012', 42.2),
#  ('Colombia', 'COL', '2016', 50.8),
#  ('Comoros', 'COM', '2013', 45.3),
#  ('Costa Rica', 'CRI', '2016', 48.7),
#  ('Croatia', 'HRV', '2015', 30.8),
#  ('Cyprus', 'CYP', '2015', 34.0),
#  ('Czech Republic', 'CZE', '2015', 25.9),
#  ('Denmark', 'DNK', '2015', 28.2),
#  ('Djibouti', 'DJI', '2013', 44.1),
#  ('Dominican Republic', 'DOM', '2016', 45.3),
#  ('Ecuador', 'ECU', '2016', 45.0),
#  ('El Salvador', 'SLV', '2016', 40.0),
#  ('Estonia', 'EST', '2015', 32.7),
#  ('Ethiopia', 'ETH', '2015', 39.1),
#  ('Fiji', 'FJI', '2013', 36.4),
#  ('Finland', 'FIN', '2015', 27.1),
#  ('France', 'FRA', '2015', 32.7),
#  ('Gabon', 'GAB', '2005', 42.2),
#  ('Georgia', 'GEO', '2016', 36.5),
#  ('Germany', 'DEU', '2015', 31.7),
#  ('Ghana', 'GHA', '2012', 42.4),
#  ('Greece', 'GRC', '2015', 36.0),
#  ('Guatemala', 'GTM', '2014', 48.3),
#  ('Guinea', 'GIN', '2012', 33.7),
#  ('Guinea-Bissau', 'GNB', '2010', 50.7),
#  ('Haiti', 'HTI', '2012', 41.1),
#  ('Honduras', 'HND', '2016', 50.0),
#  ('Hungary', 'HUN', '2015', 30.4),
#  ('Iceland', 'ISL', '2014', 25.6),
#  ('Indonesia', 'IDN', '2013', 39.5),
#  ('Iraq', 'IRQ', '2012', 29.5),
#  ('Ireland', 'IRL', '2014', 31.9),
#  ('Israel', 'ISR', '2012', 41.4),
#  ('Italy', 'ITA', '2014', 34.7),
#  ('Japan', 'JPN', '2008', 32.1),
#  ('Jordan', 'JOR', '2010', 33.7),
#  ('Kazakhstan', 'KAZ', '2015', 26.9),
#  ('Kiribati', 'KIR', '2006', 37.0),
#  ('Kosovo', 'XKX', '2015', 26.4),
#  ('Latvia', 'LVA', '2015', 34.2),
#  ('Lebanon', 'LBN', '2011', 31.8),
#  ('Lesotho', 'LSO', '2010', 54.2),
#  ('Liberia', 'LBR', '2014', 33.2),
#  ('Lithuania', 'LTU', '2015', 37.4),
#  ('Luxembourg', 'LUX', '2014', 31.2),
#  ('Madagascar', 'MDG', '2012', 42.6),
#  ('Malawi', 'MWI', '2010', 45.5),
#  ('Malaysia', 'MYS', '2009', 46.3),
#  ('Maldives', 'MDV', '2009', 38.4),
#  ('Mali', 'MLI', '2009', 33.0),
#  ('Malta', 'MLT', '2014', 29.0),
#  ('Mauritania', 'MRT', '2014', 32.6),
#  ('Mauritius', 'MUS', '2012', 35.8),
#  ('Mexico', 'MEX', '2016', 43.4),
#  ('Moldova', 'MDA', '2016', 26.3),
#  ('Mongolia', 'MNG', '2016', 32.3),
#  ('Montenegro', 'MNE', '2014', 31.9),
#  ('Morocco', 'MAR', '2006', 40.7),
#  ('Namibia', 'NAM', '2009', 61.0),
#  ('Nepal', 'NPL', '2010', 32.8),
#  ('Netherlands', 'NLD', '2015', 29.3),
#  ('Nicaragua', 'NIC', '2014', 46.2),
#  ('Niger', 'NER', '2014', 34.3),
#  ('Nigeria', 'NGA', '2009', 43.0),
#  ('Norway', 'NOR', '2015', 27.5),
#  ('Pakistan', 'PAK', '2013', 30.7),
#  ('Panama', 'PAN', '2016', 50.4),
#  ('Papua New Guinea', 'PNG', '2009', 41.9),
#  ('Paraguay', 'PRY', '2016', 47.9),
#  ('Peru', 'PER', '2016', 43.8),
#  ('Philippines', 'PHL', '2015', 40.1),
#  ('Poland', 'POL', '2015', 31.8),
#  ('Portugal', 'PRT', '2015', 35.5),
#  ('Romania', 'ROU', '2016', 28.3),
#  ('Rwanda', 'RWA', '2013', 50.4),
#  ('Samoa', 'WSM', '2008', 42.0),
#  ('Senegal', 'SEN', '2011', 40.3),
#  ('Serbia', 'SRB', '2015', 28.5),
#  ('Seychelles', 'SYC', '2013', 46.8),
#  ('Sierra Leone', 'SLE', '2011', 34.0),
#  ('Slovenia', 'SVN', '2015', 25.4),
#  ('Solomon Islands', 'SLB', '2013', 37.1),
#  ('South Africa', 'ZAF', '2014', 63.0),
#  ('Spain', 'ESP', '2015', 36.2),
#  ('Sri Lanka', 'LKA', '2016', 39.8),
#  ('Sudan', 'SDN', '2009', 35.4),
#  ('Suriname', 'SUR', '1999', 57.6),
#  ('Swaziland', 'SWZ', '2009', 51.5),
#  ('Sweden', 'SWE', '2015', 29.2),
#  ('Switzerland', 'CHE', '2014', 32.5),
#  ('Tajikistan', 'TJK', '2015', 34.0),
#  ('Tanzania', 'TZA', '2011', 37.8),
#  ('Thailand', 'THA', '2013', 37.8),
#  ('Timor-Leste', 'TLS', '2014', 28.7),
#  ('Togo', 'TGO', '2015', 43.1),
#  ('Tonga', 'TON', '2009', 37.5),
#  ('Trinidad and Tobago', 'TTO', '1992', 40.3),
#  ('Tunisia', 'TUN', '2010', 35.8),
#  ('Turkey', 'TUR', '2016', 41.9),
#  ('Tuvalu', 'TUV', '2010', 39.1),
#  ('Uganda', 'UGA', '2012', 41.0),
#  ('Ukraine', 'UKR', '2016', 25.0),
#  ('United Kingdom', 'GBR', '2015', 33.2),
#  ('United States', 'USA', '2016', 41.5),
#  ('Uruguay', 'URY', '2016', 39.7),
#  ('Vanuatu', 'VUT', '2010', 37.6),
#  ('Vietnam', 'VNM', '2014', 34.8),
#  ('Zambia', 'ZMB', '2015', 57.1)]

# %%
# Create a class for demographic
class Demographic(Base):
    __tablename__ = "demographic"
    id =Column(Integer, primary_key=True)
    country = Column(String)
    region_id = Column(String)
    year = Column(Text)
    gdp = Column(Float)
    population = Column(Float)
    lat = Column(Float)
    lon = Column(Float)

# %%
Base.metadata.tables
# Out:
# immutabledict({'happiness': Table('happiness', MetaData(bind=None), Column('id', Integer(), table=<happiness>, primary_key=True, nullable=False), Column('country', String(), table=<happiness>), Column('year', Text(), table=<happiness>), Column('happiness', Float(), table=<happiness>), Column('lat', Float(), table=<happiness>), Column('lon', Float(), table=<happiness>), schema=None), 'gini': Table('gini', MetaData(bind=None), Column('id', Integer(), table=<gini>, primary_key=True, nullable=False), Column('country', String(), table=<gini>), Column('country_code', String(), table=<gini>), Column('year', Text(), table=<gini>), Column('gini', Float(), table=<gini>), Column('lat', Float(), table=<gini>), Column('lon', Float(), table=<gini>), schema=None), 'demographic': Table('demographic', MetaData(bind=None), Column('id', Integer(), table=<demographic>, primary_key=True, nullable=False), Column('country', String(), table=<demographic>), Column('region_id', String(), table=<demographic>), Column('year', Text(), table=<demographic>), Column('gdp', Float(), table=<demographic>), Column('population', Float(), table=<demographic>), Column('lat', Float(), table=<demographic>), Column('lon', Float(), table=<demographic>), schema=None)})

# %%
engine = create_engine("sqlite:///./db/data.sqlite")

# %%
Base.metadata.create_all(engine)

# %%
session = Session(engine)

# %%
for i in demo_df.index:
    session.add(Demographic(
        country = demo_df["country_name"][i], 
        region_id = demo_df["region_id"][i],
        year = "2018",
        gdp = demo_df["gdp"][i],
        population = demo_df["population"][i],
        lat = demo_df["latitude"][i],
        lon = demo_df["longitude"][i]
    ))

# %%
engine.execute("SELECT * FROM Demographic").fetchall()
# Out:
# []

# %%
session.new
# Out:
# IdentitySet([<__main__.Demographic object at 0x00000201ADA99E10>, <__main__.Demographic object at 0x00000201ADA99E80>, <__main__.Demographic object at 0x00000201ADA99F28>, <__main__.Demographic object at 0x00000201ADA99F98>, <__main__.Demographic object at 0x00000201ADA9E048>, <__main__.Demographic object at 0x00000201ADA9E0B8>, <__main__.Demographic object at 0x00000201ADA9E128>, <__main__.Demographic object at 0x00000201ADA9E198>, <__main__.Demographic object at 0x00000201ADA9E208>, <__main__.Demographic object at 0x00000201ADA9E278>, <__main__.Demographic object at 0x00000201ADA9E2E8>, <__main__.Demographic object at 0x00000201ADA9E358>, <__main__.Demographic object at 0x00000201ADA9E3C8>, <__main__.Demographic object at 0x00000201ADA9E438>, <__main__.Demographic object at 0x00000201ADA9E4A8>, <__main__.Demographic object at 0x00000201ADA9E518>, <__main__.Demographic object at 0x00000201ADA9E588>, <__main__.Demographic object at 0x00000201ADA9E5F8>, <__main__.Demographic object at 0x00000201ADA9E668>, <__main__.Demographic object at 0x00000201ADA9E6D8>, <__main__.Demographic object at 0x00000201ADA99C88>, <__main__.Demographic object at 0x00000201ADA9E780>, <__main__.Demographic object at 0x00000201ADA9E7F0>, <__main__.Demographic object at 0x00000201ADA9E860>, <__main__.Demographic object at 0x00000201ADA9E8D0>, <__main__.Demographic object at 0x00000201ADA9E940>, <__main__.Demographic object at 0x00000201ADA9E9B0>, <__main__.Demographic object at 0x00000201ADA9EA20>, <__main__.Demographic object at 0x00000201ADA9EA90>, <__main__.Demographic object at 0x00000201ADA9EB00>, <__main__.Demographic object at 0x00000201ADA9EB70>, <__main__.Demographic object at 0x00000201ADA9EBE0>, <__main__.Demographic object at 0x00000201ADA9EC50>, <__main__.Demographic object at 0x00000201ADA9ECC0>, <__main__.Demographic object at 0x00000201ADA9ED30>, <__main__.Demographic object at 0x00000201ADA9EDA0>, <__main__.Demographic object at 0x00000201ADA9EE10>, <__main__.Demographic object at 0x00000201ADA9EE80>, <__main__.Demographic object at 0x00000201ADA9EEF0>, <__main__.Demographic object at 0x00000201ADA9EF60>, <__main__.Demographic object at 0x00000201ADA9EFD0>, <__main__.Demographic object at 0x00000201ADAA5080>, <__main__.Demographic object at 0x00000201ADAA50F0>, <__main__.Demographic object at 0x00000201ADAA5160>, <__main__.Demographic object at 0x00000201ADAA51D0>, <__main__.Demographic object at 0x00000201ADAA5240>, <__main__.Demographic object at 0x00000201ADA99EB8>, <__main__.Demographic object at 0x00000201ADA89860>, <__main__.Demographic object at 0x00000201ADA89D68>, <__main__.Demographic object at 0x00000201ADAA52E8>, <__main__.Demographic object at 0x00000201ADAA5358>, <__main__.Demographic object at 0x00000201ADAA53C8>, <__main__.Demographic object at 0x00000201ADAA5438>, <__main__.Demographic object at 0x00000201ADAA54A8>, <__main__.Demographic object at 0x00000201ADAA5518>, <__main__.Demographic object at 0x00000201ADAA5588>, <__main__.Demographic object at 0x00000201ADAA55F8>, <__main__.Demographic object at 0x00000201ADAA5668>, <__main__.Demographic object at 0x00000201ADAA56D8>, <__main__.Demographic object at 0x00000201ADAA5748>, <__main__.Demographic object at 0x00000201ADAA57B8>, <__main__.Demographic object at 0x00000201ADAA5828>, <__main__.Demographic object at 0x00000201ADAA5898>, <__main__.Demographic object at 0x00000201ADAA5908>, <__main__.Demographic object at 0x00000201ADAA5978>, <__main__.Demographic object at 0x00000201ADAA59E8>, <__main__.Demographic object at 0x00000201ADAA5A58>, <__main__.Demographic object at 0x00000201ADAA5AC8>, <__main__.Demographic object at 0x00000201ADAA5B38>, <__main__.Demographic object at 0x00000201ADAA5BA8>, <__main__.Demographic object at 0x00000201ADAA5C18>, <__main__.Demographic object at 0x00000201ADAA5C88>, <__main__.Demographic object at 0x00000201ADAA5CF8>, <__main__.Demographic object at 0x00000201ADAA5D68>, <__main__.Demographic object at 0x00000201ADAA5DD8>, <__main__.De ...

# %%
session.commit()

# %%
session.new
# Out:
# IdentitySet([])

# %%
session.query(Demographic.country, Demographic.region_id, Demographic.lat, Demographic.gdp, Demographic.population).all()
# Out:
# [('Aruba', 'LCN', 12.52111, None, 103187.0),
#  ('Afghanistan', 'SAS', 33.93911, 21413614653.0, 34656032.0),
#  ('Angola', 'SSF', -11.202691999999999, 103042000000.0, 25096150.0),
#  ('Albania', 'ECS', 41.153332, 13471082475.0, 2880703.0),
#  ('Andorra', 'ECS', 42.546245, 3319880351.0, 82431.0),
#  ('United Arab Emirates', 'MEA', 23.424076, 384222000000.0, 9269612.0),
#  ('Argentina', 'LCN', -38.416097, 447518000000.0, 42981515.0),
#  ('Armenia', 'ECS', 40.069099, 11501998666.0, 2906220.0),
#  ('American Samoa', 'EAS', -14.270972, 534555066.1, 55599.0),
#  ('Antigua and Barbuda', 'LCN', 17.060816, 1344373698.0, 96777.0),
#  ('Australia', 'EAS', -25.274398, 1349300000000.0, 23789338.0),
#  ('Austria', 'ECS', 47.516231, 420040000000.0, 8633169.0),
#  ('Azerbaijan', 'ECS', 40.143105, 57195531762.0, 9649341.0),
#  ('Burundi', 'SSF', -3.3730559999999996, 2297241392.0, 6741569.0),
#  ('Belgium', 'ECS', 50.503887, 515103000000.0, 11274196.0),
#  ('Benin', 'SSF', 9.30769, 9102277423.0, 5521763.0),
#  ('Burkina Faso', 'SSF', 12.238333, 12380518526.0, 18110624.0),
#  ('Bangladesh', 'SAS', 23.684994, 167771000000.0, 155727053.0),
#  ('Bulgaria', 'ECS', 42.733883, 56792405577.0, 7177991.0),
#  ('Bahrain', 'MEA', 25.930414000000003, 31769062885.0, 1425171.0),
#  ('Bosnia and Herzegovina', 'ECS', 43.915886, 18929698720.0, 3535961.0),
#  ('Belarus', 'ECS', 53.709807, 59187019676.0, 9489616.0),
#  ('Belize', 'LCN', 17.189877, 1602671549.0, 359288.0),
#  ('Bermuda', 'NAC', 32.321384, None, 64798.0),
#  ('Bolivia', 'LCN', -16.290154, 26758341469.0, 10724705.0),
#  ('Brazil', 'LCN', -14.235004, 2256910000000.0, 205962108.0),
#  ('Barbados', 'LCN', 13.193887, 4637855785.0, 280601.0),
#  ('Bhutan', 'SAS', 27.514162, 2234759342.0, 686958.0),
#  ('Botswana', 'SSF', -22.328474, 16843294913.0, 2014866.0),
#  ('Central African Republic', 'SSF', 6.611111, 1496562092.0, 4515392.0),
#  ('Canada', 'NAC', 56.130366, 1828000000000.0, 35544564.0),
#  ('Switzerland', 'ECS', 46.818188, 642090000000.0, 8372098.0),
#  ('Chile', 'LCN', -35.675146999999996, 267904000000.0, 16829442.0),
#  ('China', 'EAS', 35.86166, 9505160000000.0, 1370000000.0),
#  ('Cameroon', 'SSF', 7.369722, 35051979601.0, 21655715.0),
#  ('Colombia', 'LCN', 4.570868, 366457000000.0, 46406646.0),
#  ('Comoros', 'SSF', -11.875001, 611370805.2, 777424.0),
#  ('Costa Rica', 'LCN', 9.748917, 46551438317.0, 4757575.0),
#  ('Cuba', 'LCN', 21.521757, None, 11303687.0),
#  ('Cayman Islands', 'LCN', 19.513469, None, 59172.0),
#  ('Cyprus', 'ECS', 35.126413, 24311614955.0, 1160985.0),
#  ('Czech Republic', 'ECS', 49.817492, 231340000000.0, 10546059.0),
#  ('Germany', 'ECS', 51.165690999999995, 3781700000000.0, 81686611.0),
#  ('Djibouti', 'MEA', 11.825138, None, 746221.0),
#  ('Dominica', 'LCN', 15.414999, 506021862.9, 72400.0),
#  ('Denmark', 'ECS', 56.26392, 347520000000.0, 5683483.0),
#  ('Dominican Republic', 'LCN', 18.735692999999998, 73664129265.0, 10528394.0),
#  ('Algeria', 'MEA', 28.033886, 196035000000.0, 40606052.0),
#  ('Ecuador', 'LCN', -1.8312389999999998, 85056519293.0, 16144368.0),
#  ('Eritrea', 'SSF', 15.179383999999999, None, 4474690.0),
#  ('Spain', 'ECS', 40.463667, 1464510000000.0, 46447697.0),
#  ('Estonia', 'ECS', 58.595271999999994, 23808677023.0, 1315407.0),
#  ('Ethiopia', 'SSF', 9.145, 52347226230.0, 99873033.0),
#  ('Finland', 'ECS', 61.92411, 252692000000.0, 5479531.0),
#  ('Fiji', 'EAS', -16.578193, 3771168286.0, 867086.0),
#  ('France', 'ECS', 46.227638, 2806040000000.0, 66624068.0),
#  ('Gabon', 'SSF', -0.803689, 18912467101.0, 1086137.0),
#  ('United Kingdom', 'ECS', 55.378051, 2757620000000.0, 65128861.0),
#  ('Georgia', 'ECS', 42.315407, 15189614351.0, 3717100.0),
#  ('Ghana', 'SSF', 7.946527000000001, 48199090352.0, 21542009.0),
#  ('Gibraltar', 'ECS', 36.137741, None, 33623.0),
#  ('Guinea', 'SSF', 9.945587, 9667718427.0, 8132552.0),
#  ('Guinea-Bissau', 'SSF', 11.803749, 1062488925.0, 1770526.0),
#  ('Equatorial Guinea', 'SSF', 1.6508009999999997, 15045964750.0, 1221490.0),
#  ('Greece', 'ECS', 39.074208, 244481000000.0, 10892413.0),
#  ('Grenada', 'LCN', 12.262775999999999, 931118693.5, 105481.0),
#  ('Greenland', 'ECS', 71.706936, 2823634004.0, 56905.0),
#  ('Guatemala', 'LCN', 15.783470999999999, 51421926688.0, 16252429.0),
#  ('Guam', 'EAS', 13.444304, 5214914976.0, 159973.0),
#  ('Guyana', 'LCN', 4.860416000000001, 2925825406.0, 746556.0),
#  ('Honduras', 'LCN', 15.199998999999998, 19545909275.0, 9112867.0),
#  ('Croatia', 'ECS', 45.1, 61095271083.0, 4203604.0),
#  ('Haiti', 'LCN', 18.971187, 7911616492.0, 10847334.0),
#  ('Hungary', 'ECS', 47.162494, 147183000000.0, 9843028.0),
#  ('Indonesia', 'EAS', -0.789275, 1037860000000.0, 261115456.0),
#  ('Isle of Man', 'ECS', 54.236107, None, 80759.0),
#  ('India', 'SAS', 20.593684, 2466180000000.0, 1071477855.0),
#  ('Ireland', 'ECS', 53.41291, 332361000000.0, 4586897.0),
#  ('Iraq', 'MEA', 33.223191, 213938000000.0, 36115649.0),
#  ('Iceland', 'ECS', 64.96305100000001, 16434890343.0, 330815.0),
#  ('Israel', 'MEA', 31.046051000000002, 287808000000.0, 8380100.0),
#  ('Italy', 'ECS', 41.87194, 2080640000000.0, 60730582.0),
#  ('Jamaica', 'LCN', 18.109581, 13801803130.0, 2881355.0),
#  ('Jordan', 'MEA', 30.585164000000002, 30811666897.0, 8413464.0),
#  ('Japan', 'EAS', 36.204824, 6052670000000.0, 127000000.0),
#  ('Kazakhstan', 'ECS', 48.019573, 188309000000.0, 16791425.0),
#  ('Kenya', 'SSF', -0.023559, 55409230682.0, 41350152.0),
#  ('Cambodia', 'EAS', 12.565679, 17009386902.0, 15270790.0),
#  ('Kiribati', 'EAS', -3.3704169999999998, 192869131.3, 114395.0),
#  ('Kuwait', 'MEA', 29.311659999999996, 142857000000.0, 2998083.0),
#  ('Lebanon', 'MEA', 33.854721000000005, 42911390492.0, 5603279.0),
#  ('Liberia', 'SSF', 6.4280550000000005, 1627046588.0, 3512932.0),
#  ('Libya', 'MEA', 26.3351, 36808842591.0, 6193501.0),
#  ('Liechtenstein', 'ECS', 47.166000000000004, None, 36545.0),
#  ('Sri Lanka', 'SAS', 7.873054, 79907042295.0, 21200000.0),
#  ('Lesotho', 'SSF', -29.609988, 2980616573.0, 1965662.0),
#  ('Lithuania', 'ECS', 55.169438, 45735444769.0, 2904910.0),
#  ('Luxembourg', 'ECS', 49.815273, 63207264513.0, 569604.0),
#  ('Latvia', 'ECS', 56.879635, 28871503534.0, 1977527.0),
#  ('Morocco', 'MEA', 31.791702, 114784000000.0, 34318082.0),
#  ('Monaco', 'ECS', 43.750298, None, 37783.0),
#  ('Moldova', 'ECS', 47.411631, 7354798041.0, 3554108.0),
#  ('Madagascar', 'SSF', -18.766947000000002, 10356200861.0, 24894551.0),
#  ('Maldives', 'SAS', 3.202778, 3600398618.0, 409163.0),
#  ('Mexico', 'LCN', 23.634501, 1259040000000.0, 125890949.0),
#  ('Marshall Islands', 'EAS', 7.131474000000001, 179041793.9, 52793.0),
#  ('Mali', 'SSF', 17.570692, 13421822111.0, 16006670.0),
#  ('Malta', 'MEA', 35.937496, 11868476821.0, 431874.0),
#  ('Montenegro', 'ECS', 42.708678000000006, 4662831376.0, 622159.0),
#  ('Mongolia', 'EAS', 46.862496, 11825367387.0, 3027398.0),
#  ('Northern Mariana Islands', 'EAS', 17.33083, 1051785360.0, 54036.0),
#  ('Mozambique', 'SSF', -18.665695, 14846071335.0, 27212382.0),
#  ('Mauritania', 'SSF', 21.00789, 5574151157.0, 3506288.0),
#  ('Mauritius', 'SSF', -20.348404000000002, 12409842083.0, 1263473.0),
#  ('Malawi', 'SSF', -13.254307999999998, 8710223822.0, 16577147.0),
#  ('Malaysia', 'EAS', 4.210483999999999, 344052000000.0, 30228017.0),
#  ('Namibia', 'SSF', -22.957639999999998, 14950179757.0, 1559983.0),
#  ('New Caledonia', 'EAS', -20.904304999999997, None, 278000.0),
#  ('Niger', 'SSF', 17.607789, 8106889865.0, 8842415.0),
#  ('Nigeria', 'SSF', 9.081999, 456775000000.0, 154402181.0),
#  ('Nicaragua', 'LCN', 12.865416, 11955466051.0, 5737723.0),
#  ('Netherlands', 'ECS', 52.132633, 890136000000.0, 16939923.0),
#  ('Norway', 'ECS', 60.472024, 472766000000.0, 5188607.0),
#  ('Nepal', 'SAS', 28.394857000000002, 19856634053.0, 28982771.0),
#  ('Nauru', 'EAS', -0.522778, 125930267.7, 13049.0),
#  ('New Zealand', 'EAS', -40.900557, 176129000000.0, 4692700.0),
#  ('Oman', 'MEA', 21.512583, 75054356307.0, 3960925.0),
#  ('Pakistan', 'SAS', 30.375321000000003, 227867000000.0, 193203476.0),
#  ('Panama', 'LCN', 8.537981, 44789036003.0, 3969249.0),
#  ('Peru', 'LCN', -9.189967, 193653000000.0, 30973354.0),
#  ('Philippines', 'EAS', 12.879721, 284349000000.0, 103320222.0),
#  ('Palau', 'EAS', 7.51498, 225308048.6, 21503.0),
#  ('Papua New Guinea', 'EAS', -6.314993, 19389192291.0, 7755785.0),
#  ('Poland', 'ECS', 51.919438, 572132000000.0, 37986412.0),
#  ('Puerto Rico', 'LCN', 18.220833, 93028633826.0, 3473181.0),
#  ('Portugal', 'ECS', 39.399871999999995, 231745000000.0, 10401062.0),
#  ('Paraguay', 'LCN', -23.442503, 26400622643.0, 6639119.0),
#  ('French Polynesia', 'EAS', -17.679742, None, 273528.0),
#  ('Qatar', 'MEA', 25.354826, 170663000000.0, 2109568.0),
#  ('Romania', 'ECS', 45.943160999999996, 200217000000.0, 19815481.0),
#  ('Rwanda', 'SSF', -1.940278, 8805014649.0, 11917508.0),
#  ('Saudi Arabia', 'MEA', 23.885942, 690000000000.0, 31557144.0),
#  ('Sudan', 'SSF', 12.862807, 76149479953.0, 38647803.0),
#  ('Senegal', 'SSF', 14.497401000000002, 16833353304.0, 15411614.0),
#  ('Singapore', 'EAS', 1.352083, 299170000000.0, 5607283.0),
#  ('Solomon Islands', 'EAS', -9.645710000000001, 900859048.9, 563513.0),
#  ('Sierra Leone', 'SSF', 8.460555000000001, 3355384560.0, 5439695.0),
#  ('El Salvador', 'LCN', 13.794185, 21588556542.0, 6164626.0),
#  ('San Marino', 'ECS', 43.94236, 1746352442.0, 33203.0),
#  ('Somalia', 'SSF', 5.152149, None, 14317996.0),
#  ('Serbia', 'ECS', 44.016521000000004, 41308012850.0, 7095383.0),
#  ('São Tomé and Príncipe', 'SSF', 0.18636, 256822056.3, 191266.0),
#  ('Suriname', 'LCN', 3.9193050000000005, 4527379879.0, 526103.0),
#  ('Slovenia', 'ECS', 46.151241, 50511749002.0, 2063531.0),
#  ('Sweden', 'ECS', 60.128161, 560387000000.0, 9799186.0),
#  ('Seychelles', 'SSF', -4.679574, 1287449683.0, 88303.0),
#  ('Turks and Caicos Islands', 'LCN', 21.694025, None, 34900.0),
#  ('Chad', 'SSF', 15.454166, 12642608725.0, 11887202.0),
#  ('Togo', 'SSF', 8.619543, 4264876064.0, 7228915.0),
#  ('Thailand', 'EAS', 15.870032, 407015000000.0, 68657600.0),
#  ('Tajikistan', 'ECS', 38.861034000000004, 8458800788.0, 8177809.0),
#  ('Turkmenistan', 'ECS', 38.969719, 39563379206.0, 5366277.0),
#  ('Timor-Leste', 'EAS', -8.874217, 3765074847.0, 1268671.0),
#  ('Tonga', 'EAS', -21.178986, 406237705.3, 104951.0),
#  ('Trinidad and Tobago', 'LCN', 10.691803, 21519942195.0, 1328100.0),
#  ('Tunisia', 'MEA', 33.886917, 48682059522.0, 11143908.0),
#  ('Turkey', 'ECS', 38.963745, 1122510000000.0, 78271472.0),
#  ('Tuvalu', 'EAS', -7.109535, 39216157.28, 11097.0),
#  ('Tanzania', 'SSF', -6.369028, 46775259596.0, 49082997.0),
#  ('Uganda', 'SSF', 1.373333, 27483055272.0, 35093648.0),
#  ('Ukraine', 'ECS', 48.379433, 124000000000.0, 45004645.0),
#  ('Uruguay', 'LCN', -32.522779, 48362932954.0, 3431552.0),
#  ('United States', 'NAC', 37.09024, 16920300000000.0, 318563456.0),
#  ('Uzbekistan', 'ECS', 41.377491, 62469088152.0, 29774500.0),
#  ('British Virgin Islands', 'LCN', 18.420695000000002, None, 20645.0),
#  ('Vietnam', 'EAS', 14.058323999999999, 164105000000.0, 86932500.0),
#  ('Vanuatu', 'EAS', -15.376706, 777052317.5, 270402.0),
#  ('Samoa', 'EAS', -13.759029, 738041747.0, 187665.0),
#  ('Kosovo', 'ECS', 42.602636, 7129271792.0, 1801800.0),
#  ('South Africa', 'SSF', -30.559482, 421209000000.0, 51729345.36),
#  ('Zambia', 'SSF', -13.133897, 27037168289.0, 14264756.0),
#  ('Zimbabwe', 'SSF', -19.015438, 14818986231.0, 12500525.0)]

# %%
# Define the happiness table
class Geo(Base):
    __tablename__ = "geo"
    id =Column(Integer, primary_key=True)
    country = Column(String)
    lat = Column(Float)
    lon = Column(Float)
    init = Column(String)

# %%
Base.metadata.tables
# Out:
# immutabledict({'happiness': Table('happiness', MetaData(bind=None), Column('id', Integer(), table=<happiness>, primary_key=True, nullable=False), Column('country', String(), table=<happiness>), Column('year', Text(), table=<happiness>), Column('happiness', Float(), table=<happiness>), Column('lat', Float(), table=<happiness>), Column('lon', Float(), table=<happiness>), schema=None), 'gini': Table('gini', MetaData(bind=None), Column('id', Integer(), table=<gini>, primary_key=True, nullable=False), Column('country', String(), table=<gini>), Column('country_code', String(), table=<gini>), Column('year', Text(), table=<gini>), Column('gini', Float(), table=<gini>), Column('lat', Float(), table=<gini>), Column('lon', Float(), table=<gini>), schema=None), 'demographic': Table('demographic', MetaData(bind=None), Column('id', Integer(), table=<demographic>, primary_key=True, nullable=False), Column('country', String(), table=<demographic>), Column('region_id', String(), table=<demographic>), Column('year', Text(), table=<demographic>), Column('gdp', Float(), table=<demographic>), Column('population', Float(), table=<demographic>), Column('lat', Float(), table=<demographic>), Column('lon', Float(), table=<demographic>), schema=None), 'geo': Table('geo', MetaData(bind=None), Column('id', Integer(), table=<geo>, primary_key=True, nullable=False), Column('country', String(), table=<geo>), Column('lat', Float(), table=<geo>), Column('lon', Float(), table=<geo>), Column('init', String(), table=<geo>), schema=None)})

# %%
engine = create_engine("sqlite:///./db/data.sqlite")

# %%
Base.metadata.create_all(engine)

# %%
session = Session(engine)

# %%
for i in geo_df.index:
    session.add(Geo(
        country = geo_df["country_name"][i], 
        lat = geo_df["latitude"][i],
        lon = geo_df["longitude"][i],
        init = geo_df["country"][i]
    ))

# %%
engine.execute("SELECT * FROM Geo").fetchall()
# Out:
# []

# %%
session.new
# Out:
# IdentitySet([<__main__.Geo object at 0x00000201ADB0A080>, <__main__.Geo object at 0x00000201ADB0A0B8>, <__main__.Geo object at 0x00000201ADB0A198>, <__main__.Geo object at 0x00000201ADB0A208>, <__main__.Geo object at 0x00000201ADB0A2E8>, <__main__.Geo object at 0x00000201ADB0A358>, <__main__.Geo object at 0x00000201ADB0A3C8>, <__main__.Geo object at 0x00000201ADB0A438>, <__main__.Geo object at 0x00000201ADAF8CC0>, <__main__.Geo object at 0x00000201ADAF8B00>, <__main__.Geo object at 0x00000201ADAFBD68>, <__main__.Geo object at 0x00000201ADAFBFD0>, <__main__.Geo object at 0x00000201ADAFBC88>, <__main__.Geo object at 0x00000201ADAFBDD8>, <__main__.Geo object at 0x00000201ADAFBB00>, <__main__.Geo object at 0x00000201ADAFBCF8>, <__main__.Geo object at 0x00000201ADB0A4A8>, <__main__.Geo object at 0x00000201ADB0A518>, <__main__.Geo object at 0x00000201ADB0A588>, <__main__.Geo object at 0x00000201ADB0A5F8>, <__main__.Geo object at 0x00000201ADB0A668>, <__main__.Geo object at 0x00000201ADB0A6D8>, <__main__.Geo object at 0x00000201ADB0A748>, <__main__.Geo object at 0x00000201ADB0A7B8>, <__main__.Geo object at 0x00000201ADB0A828>, <__main__.Geo object at 0x00000201ADB0A898>, <__main__.Geo object at 0x00000201ADB0A908>, <__main__.Geo object at 0x00000201ADB0A978>, <__main__.Geo object at 0x00000201ADB0A9E8>, <__main__.Geo object at 0x00000201ADB0AA58>, <__main__.Geo object at 0x00000201ADB0AAC8>, <__main__.Geo object at 0x00000201ADB0AB38>, <__main__.Geo object at 0x00000201ADB0ABA8>, <__main__.Geo object at 0x00000201ADB0AC18>, <__main__.Geo object at 0x00000201ADB0AC88>, <__main__.Geo object at 0x00000201ADB0ACF8>, <__main__.Geo object at 0x00000201ADB0AD68>, <__main__.Geo object at 0x00000201ADB0ADD8>, <__main__.Geo object at 0x00000201ADB0AE48>, <__main__.Geo object at 0x00000201ADB0AEB8>, <__main__.Geo object at 0x00000201ADB0AF28>, <__main__.Geo object at 0x00000201ADB0AF98>, <__main__.Geo object at 0x00000201ADB11048>, <__main__.Geo object at 0x00000201ADB110B8>, <__main__.Geo object at 0x00000201ADB11128>, <__main__.Geo object at 0x00000201ADB11198>, <__main__.Geo object at 0x00000201ADB11208>, <__main__.Geo object at 0x00000201ADB11278>, <__main__.Geo object at 0x00000201ADB112E8>, <__main__.Geo object at 0x00000201ADB11358>, <__main__.Geo object at 0x00000201ADB113C8>, <__main__.Geo object at 0x00000201ADB11438>, <__main__.Geo object at 0x00000201ADB114A8>, <__main__.Geo object at 0x00000201ADB11518>, <__main__.Geo object at 0x00000201ADB11588>, <__main__.Geo object at 0x00000201ADB115F8>, <__main__.Geo object at 0x00000201ADB11668>, <__main__.Geo object at 0x00000201ADB116D8>, <__main__.Geo object at 0x00000201ADB11748>, <__main__.Geo object at 0x00000201ADB117B8>, <__main__.Geo object at 0x00000201ADB11828>, <__main__.Geo object at 0x00000201ADB11898>, <__main__.Geo object at 0x00000201ADB11908>, <__main__.Geo object at 0x00000201ADB11978>, <__main__.Geo object at 0x00000201ADB119E8>, <__main__.Geo object at 0x00000201ADB11A58>, <__main__.Geo object at 0x00000201ADB11AC8>, <__main__.Geo object at 0x00000201ADB11B38>, <__main__.Geo object at 0x00000201ADB11BA8>, <__main__.Geo object at 0x00000201ADB11C18>, <__main__.Geo object at 0x00000201ADB11C88>, <__main__.Geo object at 0x00000201ADB11CF8>, <__main__.Geo object at 0x00000201ADB11D68>, <__main__.Geo object at 0x00000201ADB11DD8>, <__main__.Geo object at 0x00000201ADB11E48>, <__main__.Geo object at 0x00000201ADB11EB8>, <__main__.Geo object at 0x00000201ADB11F28>, <__main__.Geo object at 0x00000201ADB11F98>, <__main__.Geo object at 0x00000201ADB19048>, <__main__.Geo object at 0x00000201ADB190B8>, <__main__.Geo object at 0x00000201ADB19128>, <__main__.Geo object at 0x00000201ADB19198>, <__main__.Geo object at 0x00000201ADB19208>, <__main__.Geo object at 0x00000201ADB19278>, <__main__.Geo object at 0x00000201ADB192E8>, <__main__.Geo object at 0x00000201ADB19358>, <__main__.Geo object at 0x00000201ADB193C8>, <__main__.Geo object at 0x00000201ADB19438>, <__main__.Geo object at 0x0 ...

# %%
session.commit()

# %%
session.new
# Out:
# IdentitySet([])

# %%
session.query(Geo.country, Geo.lat, Geo.lon, Geo.init).all()
# Out:
# [('Andorra', 42.546245, 1.6015540000000001, 'AD'),
#  ('United Arab Emirates', 23.424076, 53.847818000000004, 'AE'),
#  ('Afghanistan', 33.93911, 67.709953, 'AF'),
#  ('Antigua and Barbuda', 17.060816, -61.796428000000006, 'AG'),
#  ('Anguilla', 18.220554, -63.068615, 'AI'),
#  ('Albania', 41.153332, 20.168331, 'AL'),
#  ('Armenia', 40.069099, 45.038189, 'AM'),
#  ('Netherlands Antilles', 12.226078999999999, -69.060087, 'AN'),
#  ('Angola', -11.202691999999999, 17.873887, 'AO'),
#  ('Antarctica', -75.250973, -0.071389, 'AQ'),
#  ('Argentina', -38.416097, -63.616671999999994, 'AR'),
#  ('American Samoa', -14.270972, -170.132217, 'AS'),
#  ('Austria', 47.516231, 14.550072, 'AT'),
#  ('Australia', -25.274398, 133.775136, 'AU'),
#  ('Aruba', 12.52111, -69.968338, 'AW'),
#  ('Azerbaijan', 40.143105, 47.576927000000005, 'AZ'),
#  ('Bosnia and Herzegovina', 43.915886, 17.679076000000002, 'BA'),
#  ('Barbados', 13.193887, -59.543198, 'BB'),
#  ('Bangladesh', 23.684994, 90.35633100000001, 'BD'),
#  ('Belgium', 50.503887, 4.469936, 'BE'),
#  ('Burkina Faso', 12.238333, -1.561593, 'BF'),
#  ('Bulgaria', 42.733883, 25.48583, 'BG'),
#  ('Bahrain', 25.930414000000003, 50.637772, 'BH'),
#  ('Burundi', -3.3730559999999996, 29.918885999999997, 'BI'),
#  ('Benin', 9.30769, 2.315834, 'BJ'),
#  ('Bermuda', 32.321384, -64.75737, 'BM'),
#  ('Brunei', 4.535277, 114.72766899999999, 'BN'),
#  ('Bolivia', -16.290154, -63.588653, 'BO'),
#  ('Brazil', -14.235004, -51.92528, 'BR'),
#  ('Bahamas', 25.03428, -77.39628, 'BS'),
#  ('Bhutan', 27.514162, 90.433601, 'BT'),
#  ('Bouvet Island', -54.423199, 3.4131940000000003, 'BV'),
#  ('Botswana', -22.328474, 24.684866, 'BW'),
#  ('Belarus', 53.709807, 27.953389, 'BY'),
#  ('Belize', 17.189877, -88.49765, 'BZ'),
#  ('Canada', 56.130366, -106.34677099999999, 'CA'),
#  ('Cocos [Keeling] Islands', -12.164164999999999, 96.870956, 'CC'),
#  ('Congo [DRC]', -4.038333000000001, 21.758664000000003, 'CD'),
#  ('Central African Republic', 6.611111, 20.939444, 'CF'),
#  ('Congo [Republic]', -0.228021, 15.827658999999999, 'CG'),
#  ('Switzerland', 46.818188, 8.227511999999999, 'CH'),
#  ("Côte d'Ivoire", 7.539989, -5.54708, 'CI'),
#  ('Cook Islands', -21.236735999999997, -159.777671, 'CK'),
#  ('Chile', -35.675146999999996, -71.542969, 'CL'),
#  ('Cameroon', 7.369722, 12.354722, 'CM'),
#  ('China', 35.86166, 104.195397, 'CN'),
#  ('Colombia', 4.570868, -74.297333, 'CO'),
#  ('Costa Rica', 9.748917, -83.753428, 'CR'),
#  ('Cuba', 21.521757, -77.78116700000001, 'CU'),
#  ('Cape Verde', 16.002082, -24.013197, 'CV'),
#  ('Christmas Island', -10.447525, 105.690449, 'CX'),
#  ('Cyprus', 35.126413, 33.429859, 'CY'),
#  ('Czech Republic', 49.817492, 15.472961999999999, 'CZ'),
#  ('Germany', 51.165690999999995, 10.451526, 'DE'),
#  ('Djibouti', 11.825138, 42.590275, 'DJ'),
#  ('Denmark', 56.26392, 9.501785, 'DK'),
#  ('Dominica', 15.414999, -61.370976, 'DM'),
#  ('Dominican Republic', 18.735692999999998, -70.162651, 'DO'),
#  ('Algeria', 28.033886, 1.6596259999999998, 'DZ'),
#  ('Ecuador', -1.8312389999999998, -78.183406, 'EC'),
#  ('Estonia', 58.595271999999994, 25.013607, 'EE'),
#  ('Egypt', 26.820553000000004, 30.802497999999996, 'EG'),
#  ('Western Sahara', 24.215526999999998, -12.885834, 'EH'),
#  ('Eritrea', 15.179383999999999, 39.782334000000006, 'ER'),
#  ('Spain', 40.463667, -3.7492199999999998, 'ES'),
#  ('Ethiopia', 9.145, 40.489672999999996, 'ET'),
#  ('Finland', 61.92411, 25.748151, 'FI'),
#  ('Fiji', -16.578193, 179.414413, 'FJ'),
#  ('Falkland Islands [Islas Malvinas]', -51.796253, -59.523613, 'FK'),
#  ('Micronesia', 7.425553999999999, 150.550812, 'FM'),
#  ('Faroe Islands', 61.892635, -6.9118059999999995, 'FO'),
#  ('France', 46.227638, 2.213749, 'FR'),
#  ('Gabon', -0.803689, 11.609444, 'GA'),
#  ('United Kingdom', 55.378051, -3.435973, 'GB'),
#  ('Grenada', 12.262775999999999, -61.604170999999994, 'GD'),
#  ('Georgia', 42.315407, 43.356891999999995, 'GE'),
#  ('French Guiana', 3.9338889999999997, -53.125781999999994, 'GF'),
#  ('Guernsey', 49.465691, -2.5852779999999997, 'GG'),
#  ('Ghana', 7.946527000000001, -1.0231940000000002, 'GH'),
#  ('Gibraltar', 36.137741, -5.345374, 'GI'),
#  ('Greenland', 71.706936, -42.604303, 'GL'),
#  ('Gambia', 13.443182, -15.310139000000001, 'GM'),
#  ('Guinea', 9.945587, -9.696645, 'GN'),
#  ('Guadeloupe', 16.995971, -62.067641, 'GP'),
#  ('Equatorial Guinea', 1.6508009999999997, 10.267895, 'GQ'),
#  ('Greece', 39.074208, 21.824312, 'GR'),
#  ('South Georgia and the South Sandwich Islands',
#   -54.429579000000004,
#   -36.587909,
#   'GS'),
#  ('Guatemala', 15.783470999999999, -90.23075899999999, 'GT'),
#  ('Guam', 13.444304, 144.793731, 'GU'),
#  ('Guinea-Bissau', 11.803749, -15.180413, 'GW'),
#  ('Guyana', 4.860416000000001, -58.93018000000001, 'GY'),
#  ('Gaza Strip', 31.354676, 34.308825, 'GZ'),
#  ('Hong Kong', 22.396428, 114.10949699999999, 'HK'),
#  ('Heard Island and McDonald Islands', -53.08181, 73.50415799999999, 'HM'),
#  ('Honduras', 15.199998999999998, -86.241905, 'HN'),
#  ('Croatia', 45.1, 15.2, 'HR'),
#  ('Haiti', 18.971187, -72.28521500000001, 'HT'),
#  ('Hungary', 47.162494, 19.503304, 'HU'),
#  ('Indonesia', -0.789275, 113.921327, 'ID'),
#  ('Ireland', 53.41291, -8.243889999999999, 'IE'),
#  ('Israel', 31.046051000000002, 34.851612, 'IL'),
#  ('Isle of Man', 54.236107, -4.548056, 'IM'),
#  ('India', 20.593684, 78.96288, 'IN'),
#  ('British Indian Ocean Territory', -6.343194, 71.87651899999999, 'IO'),
#  ('Iraq', 33.223191, 43.679291, 'IQ'),
#  ('Iran', 32.427908, 53.68804599999999, 'IR'),
#  ('Iceland', 64.96305100000001, -19.020835, 'IS'),
#  ('Italy', 41.87194, 12.56738, 'IT'),
#  ('Jersey', 49.214439, -2.13125, 'JE'),
#  ('Jamaica', 18.109581, -77.297508, 'JM'),
#  ('Jordan', 30.585164000000002, 36.238414, 'JO'),
#  ('Japan', 36.204824, 138.252924, 'JP'),
#  ('Kenya', -0.023559, 37.906193, 'KE'),
#  ('Kyrgyzstan', 41.20438, 74.766098, 'KG'),
#  ('Cambodia', 12.565679, 104.990963, 'KH'),
#  ('Kiribati', -3.3704169999999998, -168.734039, 'KI'),
#  ('Comoros', -11.875001, 43.872219, 'KM'),
#  ('Saint Kitts and Nevis', 17.357822, -62.782998, 'KN'),
#  ('North Korea', 40.339852, 127.510093, 'KP'),
#  ('South Korea', 35.907757000000004, 127.766922, 'KR'),
#  ('Kuwait', 29.311659999999996, 47.481766, 'KW'),
#  ('Cayman Islands', 19.513469, -80.566956, 'KY'),
#  ('Kazakhstan', 48.019573, 66.923684, 'KZ'),
#  ('Laos', 19.856270000000002, 102.495496, 'LA'),
#  ('Lebanon', 33.854721000000005, 35.862285, 'LB'),
#  ('Saint Lucia', 13.909444, -60.97889300000001, 'LC'),
#  ('Liechtenstein', 47.166000000000004, 9.555373, 'LI'),
#  ('Sri Lanka', 7.873054, 80.77179699999999, 'LK'),
#  ('Liberia', 6.4280550000000005, -9.429499, 'LR'),
#  ('Lesotho', -29.609988, 28.233608, 'LS'),
#  ('Lithuania', 55.169438, 23.881275, 'LT'),
#  ('Luxembourg', 49.815273, 6.129583, 'LU'),
#  ('Latvia', 56.879635, 24.603189, 'LV'),
#  ('Libya', 26.3351, 17.228331, 'LY'),
#  ('Morocco', 31.791702, -7.09262, 'MA'),
#  ('Monaco', 43.750298, 7.412841, 'MC'),
#  ('Moldova', 47.411631, 28.369884999999996, 'MD'),
#  ('Montenegro', 42.708678000000006, 19.37439, 'ME'),
#  ('Madagascar', -18.766947000000002, 46.869107, 'MG'),
#  ('Marshall Islands', 7.131474000000001, 171.184478, 'MH'),
#  ('Macedonia [FYROM]', 41.608635, 21.745275, 'MK'),
#  ('Mali', 17.570692, -3.9961660000000006, 'ML'),
#  ('Myanmar [Burma]', 21.913965, 95.956223, 'MM'),
#  ('Mongolia', 46.862496, 103.84665600000001, 'MN'),
#  ('Macau', 22.198745000000002, 113.543873, 'MO'),
#  ('Northern Mariana Islands', 17.33083, 145.38468999999998, 'MP'),
#  ('Martinique', 14.641528, -61.024174, 'MQ'),
#  ('Mauritania', 21.00789, -10.940835, 'MR'),
#  ('Montserrat', 16.742498, -62.187366000000004, 'MS'),
#  ('Malta', 35.937496, 14.375416, 'MT'),
#  ('Mauritius', -20.348404000000002, 57.552152, 'MU'),
#  ('Maldives', 3.202778, 73.22068, 'MV'),
#  ('Malawi', -13.254307999999998, 34.301525, 'MW'),
#  ('Mexico', 23.634501, -102.552784, 'MX'),
#  ('Malaysia', 4.210483999999999, 101.97576600000001, 'MY'),
#  ('Mozambique', -18.665695, 35.529562, 'MZ'),
#  ('Namibia', -22.957639999999998, 18.49041, None),
#  ('New Caledonia', -20.904304999999997, 165.618042, 'NC'),
#  ('Niger', 17.607789, 8.081666, 'NE'),
#  ('Norfolk Island', -29.040834999999998, 167.954712, 'NF'),
#  ('Nigeria', 9.081999, 8.675277000000001, 'NG'),
#  ('Nicaragua', 12.865416, -85.207229, 'NI'),
#  ('Netherlands', 52.132633, 5.291266, 'NL'),
#  ('Norway', 60.472024, 8.468946, 'NO'),
#  ('Nepal', 28.394857000000002, 84.12400799999999, 'NP'),
#  ('Nauru', -0.522778, 166.931503, 'NR'),
#  ('Niue', -19.054445, -169.867233, 'NU'),
#  ('New Zealand', -40.900557, 174.88597099999998, 'NZ'),
#  ('Oman', 21.512583, 55.923255000000005, 'OM'),
#  ('Panama', 8.537981, -80.782127, 'PA'),
#  ('Peru', -9.189967, -75.015152, 'PE'),
#  ('French Polynesia', -17.679742, -149.40684299999998, 'PF'),
#  ('Papua New Guinea', -6.314993, 143.95555, 'PG'),
#  ('Philippines', 12.879721, 121.77401699999999, 'PH'),
#  ('Pakistan', 30.375321000000003, 69.345116, 'PK'),
#  ('Poland', 51.919438, 19.145135999999997, 'PL'),
#  ('Saint Pierre and Miquelon', 46.941936, -56.27111, 'PM'),
#  ('Pitcairn Islands', -24.703615, -127.43930800000001, 'PN'),
#  ('Puerto Rico', 18.220833, -66.590149, 'PR'),
#  ('Palestinian Territories', 31.952162, 35.233154, 'PS'),
#  ('Portugal', 39.399871999999995, -8.224454, 'PT'),
#  ('Palau', 7.51498, 134.58252, 'PW'),
#  ('Paraguay', -23.442503, -58.44383199999999, 'PY'),
#  ('Qatar', 25.354826, 51.183884, 'QA'),
#  ('Réunion', -21.115141, 55.536384, 'RE'),
#  ('Romania', 45.943160999999996, 24.96676, 'RO'),
#  ('Serbia', 44.016521000000004, 21.005859, 'RS'),
#  ('Russia', 61.52401, 105.31875600000001, 'RU'),
#  ('Rwanda', -1.940278, 29.873888, 'RW'),
#  ('Saudi Arabia', 23.885942, 45.079162, 'SA'),
#  ('Solomon Islands', -9.645710000000001, 160.156194, 'SB'),
#  ('Seychelles', -4.679574, 55.491977, 'SC'),
#  ('Sudan', 12.862807, 30.217636, 'SD'),
#  ('Sweden', 60.128161, 18.643501, 'SE'),
#  ('Singapore', 1.352083, 103.819836, 'SG'),
#  ('Saint Helena', -24.143473999999998, -10.030696, 'SH'),
#  ('Slovenia', 46.151241, 14.995463, 'SI'),
#  ('Svalbard and Jan Mayen', 77.553604, 23.670272, 'SJ'),
#  ('Slovakia', 48.669026, 19.699023999999998, 'SK'),
#  ('Sierra Leone', 8.460555000000001, -11.779889, 'SL'),
#  ('San Marino', 43.94236, 12.457777, 'SM'),
#  ('Senegal', 14.497401000000002, -14.452361999999999, 'SN'),
#  ('Somalia', 5.152149, 46.199616, 'SO'),
#  ('Suriname', 3.9193050000000005, -56.02778299999999, 'SR'),
#  ('São Tomé and Príncipe', 0.18636, 6.613081, 'ST'),
#  ('El Salvador', 13.794185, -88.89653, 'SV'),
#  ('Syria', 34.802075, 38.996815000000005, 'SY'),
#  ('Swaziland', -26.522503000000004, 31.465866, 'SZ'),
#  ('Turks and Caicos Islands', 21.694025, -71.797928, 'TC'),
#  ('Chad', 15.454166, 18.732207, 'TD'),
#  ('French Southern Territories', -49.280366, 69.348557, 'TF'),
#  ('Togo', 8.619543, 0.824782, 'TG'),
#  ('Thailand', 15.870032, 100.992541, 'TH'),
#  ('Tajikistan', 38.861034000000004, 71.276093, 'TJ'),
#  ('Tokelau', -8.967363, -171.855881, 'TK'),
#  ('Timor-Leste', -8.874217, 125.727539, 'TL'),
#  ('Turkmenistan', 38.969719, 59.556278000000006, 'TM'),
#  ('Tunisia', 33.886917, 9.537499, 'TN'),
#  ('Tonga', -21.178986, -175.198242, 'TO'),
#  ('Turkey', 38.963745, 35.243322, 'TR'),
#  ('Trinidad and Tobago', 10.691803, -61.222503, 'TT'),
#  ('Tuvalu', -7.109535, 177.64933, 'TV'),
#  ('Taiwan', 23.69781, 120.96051499999999, 'TW'),
#  ('Tanzania', -6.369028, 34.888822, 'TZ'),
#  ('Ukraine', 48.379433, 31.16558, 'UA'),
#  ('Uganda', 1.373333, 32.290275, 'UG'),
#  ('U.S. Minor Outlying Islands', None, None, 'UM'),
#  ('United States', 37.09024, -95.712891, 'US'),
#  ('Uruguay', -32.522779, -55.765834999999996, 'UY'),
#  ('Uzbekistan', 41.377491, 64.585262, 'UZ'),
#  ('Vatican City', 41.902916, 12.453389, 'VA'),
#  ('Saint Vincent and the Grenadines', 12.984305, -61.287228000000006, 'VC'),
#  ('Venezuela', 6.42375, -66.58973, 'VE'),
#  ('British Virgin Islands', 18.420695000000002, -64.63996800000001, 'VG'),
#  ('U.S. Virgin Islands', 18.335765, -64.896335, 'VI'),
#  ('Vietnam', 14.058323999999999, 108.277199, 'VN'),
#  ('Vanuatu', -15.376706, 166.959158, 'VU'),
#  ('Wallis and Futuna', -13.768752, -177.156097, 'WF'),
#  ('Samoa', -13.759029, -172.10462900000002, 'WS'),
#  ('Kosovo', 42.602636, 20.902977, 'XK'),
#  ('Yemen', 15.552726999999999, 48.516388, 'YE'),
#  ('Mayotte', -12.8275, 45.166244, 'YT'),
#  ('South Africa', -30.559482, 22.937506, 'ZA'),
#  ('Zambia', -13.133897, 27.849332, 'ZM'),
#  ('Zimbabwe', -19.015438, 29.154857, 'ZW')]

# %%
# Define the joined table
class Join(Base):
    __tablename__ = "join"
    id =Column(Integer, primary_key=True)
    country = Column(String)
    country_code = Column(String)
    region_id = Column(String)
    gdp = Column(Float)
    population = Column(Float)
    lat = Column(Float)
    lon = Column(Float)
    gini = Column(Float)
    happiness = Column(Float)
    gdpPerCap = Column(Float)

# %%
Base.metadata.tables
# Out:
# immutabledict({'happiness': Table('happiness', MetaData(bind=None), Column('id', Integer(), table=<happiness>, primary_key=True, nullable=False), Column('country', String(), table=<happiness>), Column('year', Text(), table=<happiness>), Column('happiness', Float(), table=<happiness>), Column('lat', Float(), table=<happiness>), Column('lon', Float(), table=<happiness>), schema=None), 'gini': Table('gini', MetaData(bind=None), Column('id', Integer(), table=<gini>, primary_key=True, nullable=False), Column('country', String(), table=<gini>), Column('country_code', String(), table=<gini>), Column('year', Text(), table=<gini>), Column('gini', Float(), table=<gini>), Column('lat', Float(), table=<gini>), Column('lon', Float(), table=<gini>), schema=None), 'demographic': Table('demographic', MetaData(bind=None), Column('id', Integer(), table=<demographic>, primary_key=True, nullable=False), Column('country', String(), table=<demographic>), Column('region_id', String(), table=<demographic>), Column('year', Text(), table=<demographic>), Column('gdp', Float(), table=<demographic>), Column('population', Float(), table=<demographic>), Column('lat', Float(), table=<demographic>), Column('lon', Float(), table=<demographic>), schema=None), 'geo': Table('geo', MetaData(bind=None), Column('id', Integer(), table=<geo>, primary_key=True, nullable=False), Column('country', String(), table=<geo>), Column('lat', Float(), table=<geo>), Column('lon', Float(), table=<geo>), Column('init', String(), table=<geo>), schema=None), 'join': Table('join', MetaData(bind=None), Column('id', Integer(), table=<join>, primary_key=True, nullable=False), Column('country', String(), table=<join>), Column('country_code', String(), table=<join>), Column('region_id', String(), table=<join>), Column('gdp', Float(), table=<join>), Column('population', Float(), table=<join>), Column('lat', Float(), table=<join>), Column('lon', Float(), table=<join>), Column('gini', Float(), table=<join>), Column('happiness', Float(), table=<join>), Column('gdpPerCap', Float(), table=<join>), schema=None)})

# %%
engine = create_engine("sqlite:///./db/data.sqlite")

# %%
Base.metadata.create_all(engine)

# %%
session = Session(engine)

# %%
for i in joined_df.index:
    session.add(Join(
        country = joined_df["country_name"][i],
        country_code = joined_df["code"][i],
        region_id = joined_df["region_id"][i],
        gdp = joined_df["gdp"][i],
        population = joined_df["population"][i],
        lat = joined_df["latitude"][i],
        lon = joined_df["longitude"][i],
        gini = joined_df["gini"][i],
        happiness = joined_df["happiness"][i],
        gdpPerCap = joined_df["gdpPerCap"][i]
    ))

# %%
engine.execute("SELECT * FROM Geo").fetchall()
# Out:
# [(1, 'Andorra', 42.546245, 1.6015540000000001, 'AD'),
#  (2, 'United Arab Emirates', 23.424076, 53.847818000000004, 'AE'),
#  (3, 'Afghanistan', 33.93911, 67.709953, 'AF'),
#  (4, 'Antigua and Barbuda', 17.060816, -61.796428000000006, 'AG'),
#  (5, 'Anguilla', 18.220554, -63.068615, 'AI'),
#  (6, 'Albania', 41.153332, 20.168331, 'AL'),
#  (7, 'Armenia', 40.069099, 45.038189, 'AM'),
#  (8, 'Netherlands Antilles', 12.226078999999999, -69.060087, 'AN'),
#  (9, 'Angola', -11.202691999999999, 17.873887, 'AO'),
#  (10, 'Antarctica', -75.250973, -0.071389, 'AQ'),
#  (11, 'Argentina', -38.416097, -63.616671999999994, 'AR'),
#  (12, 'American Samoa', -14.270972, -170.132217, 'AS'),
#  (13, 'Austria', 47.516231, 14.550072, 'AT'),
#  (14, 'Australia', -25.274398, 133.775136, 'AU'),
#  (15, 'Aruba', 12.52111, -69.968338, 'AW'),
#  (16, 'Azerbaijan', 40.143105, 47.576927000000005, 'AZ'),
#  (17, 'Bosnia and Herzegovina', 43.915886, 17.679076000000002, 'BA'),
#  (18, 'Barbados', 13.193887, -59.543198, 'BB'),
#  (19, 'Bangladesh', 23.684994, 90.35633100000001, 'BD'),
#  (20, 'Belgium', 50.503887, 4.469936, 'BE'),
#  (21, 'Burkina Faso', 12.238333, -1.561593, 'BF'),
#  (22, 'Bulgaria', 42.733883, 25.48583, 'BG'),
#  (23, 'Bahrain', 25.930414000000003, 50.637772, 'BH'),
#  (24, 'Burundi', -3.3730559999999996, 29.918885999999997, 'BI'),
#  (25, 'Benin', 9.30769, 2.315834, 'BJ'),
#  (26, 'Bermuda', 32.321384, -64.75737, 'BM'),
#  (27, 'Brunei', 4.535277, 114.72766899999999, 'BN'),
#  (28, 'Bolivia', -16.290154, -63.588653, 'BO'),
#  (29, 'Brazil', -14.235004, -51.92528, 'BR'),
#  (30, 'Bahamas', 25.03428, -77.39628, 'BS'),
#  (31, 'Bhutan', 27.514162, 90.433601, 'BT'),
#  (32, 'Bouvet Island', -54.423199, 3.4131940000000003, 'BV'),
#  (33, 'Botswana', -22.328474, 24.684866, 'BW'),
#  (34, 'Belarus', 53.709807, 27.953389, 'BY'),
#  (35, 'Belize', 17.189877, -88.49765, 'BZ'),
#  (36, 'Canada', 56.130366, -106.34677099999999, 'CA'),
#  (37, 'Cocos [Keeling] Islands', -12.164164999999999, 96.870956, 'CC'),
#  (38, 'Congo [DRC]', -4.038333000000001, 21.758664000000003, 'CD'),
#  (39, 'Central African Republic', 6.611111, 20.939444, 'CF'),
#  (40, 'Congo [Republic]', -0.228021, 15.827658999999999, 'CG'),
#  (41, 'Switzerland', 46.818188, 8.227511999999999, 'CH'),
#  (42, "Côte d'Ivoire", 7.539989, -5.54708, 'CI'),
#  (43, 'Cook Islands', -21.236735999999997, -159.777671, 'CK'),
#  (44, 'Chile', -35.675146999999996, -71.542969, 'CL'),
#  (45, 'Cameroon', 7.369722, 12.354722, 'CM'),
#  (46, 'China', 35.86166, 104.195397, 'CN'),
#  (47, 'Colombia', 4.570868, -74.297333, 'CO'),
#  (48, 'Costa Rica', 9.748917, -83.753428, 'CR'),
#  (49, 'Cuba', 21.521757, -77.78116700000001, 'CU'),
#  (50, 'Cape Verde', 16.002082, -24.013197, 'CV'),
#  (51, 'Christmas Island', -10.447525, 105.690449, 'CX'),
#  (52, 'Cyprus', 35.126413, 33.429859, 'CY'),
#  (53, 'Czech Republic', 49.817492, 15.472961999999999, 'CZ'),
#  (54, 'Germany', 51.165690999999995, 10.451526, 'DE'),
#  (55, 'Djibouti', 11.825138, 42.590275, 'DJ'),
#  (56, 'Denmark', 56.26392, 9.501785, 'DK'),
#  (57, 'Dominica', 15.414999, -61.370976, 'DM'),
#  (58, 'Dominican Republic', 18.735692999999998, -70.162651, 'DO'),
#  (59, 'Algeria', 28.033886, 1.6596259999999998, 'DZ'),
#  (60, 'Ecuador', -1.8312389999999998, -78.183406, 'EC'),
#  (61, 'Estonia', 58.595271999999994, 25.013607, 'EE'),
#  (62, 'Egypt', 26.820553000000004, 30.802497999999996, 'EG'),
#  (63, 'Western Sahara', 24.215526999999998, -12.885834, 'EH'),
#  (64, 'Eritrea', 15.179383999999999, 39.782334000000006, 'ER'),
#  (65, 'Spain', 40.463667, -3.7492199999999998, 'ES'),
#  (66, 'Ethiopia', 9.145, 40.489672999999996, 'ET'),
#  (67, 'Finland', 61.92411, 25.748151, 'FI'),
#  (68, 'Fiji', -16.578193, 179.414413, 'FJ'),
#  (69, 'Falkland Islands [Islas Malvinas]', -51.796253, -59.523613, 'FK'),
#  (70, 'Micronesia', 7.425553999999999, 150.550812, 'FM'),
#  (71, 'Faroe Islands', 61.892635, -6.9118059999999995, 'FO'),
#  (72, 'France', 46.227638, 2.213749, 'FR'),
#  (73, 'Gabon', -0.803689, 11.609444, 'GA'),
#  (74, 'United Kingdom', 55.378051, -3.435973, 'GB'),
#  (75, 'Grenada', 12.262775999999999, -61.604170999999994, 'GD'),
#  (76, 'Georgia', 42.315407, 43.356891999999995, 'GE'),
#  (77, 'French Guiana', 3.9338889999999997, -53.125781999999994, 'GF'),
#  (78, 'Guernsey', 49.465691, -2.5852779999999997, 'GG'),
#  (79, 'Ghana', 7.946527000000001, -1.0231940000000002, 'GH'),
#  (80, 'Gibraltar', 36.137741, -5.345374, 'GI'),
#  (81, 'Greenland', 71.706936, -42.604303, 'GL'),
#  (82, 'Gambia', 13.443182, -15.310139000000001, 'GM'),
#  (83, 'Guinea', 9.945587, -9.696645, 'GN'),
#  (84, 'Guadeloupe', 16.995971, -62.067641, 'GP'),
#  (85, 'Equatorial Guinea', 1.6508009999999997, 10.267895, 'GQ'),
#  (86, 'Greece', 39.074208, 21.824312, 'GR'),
#  (87, 'South Georgia and the South Sandwich Islands', -54.429579000000004, -36.587909, 'GS'),
#  (88, 'Guatemala', 15.783470999999999, -90.23075899999999, 'GT'),
#  (89, 'Guam', 13.444304, 144.793731, 'GU'),
#  (90, 'Guinea-Bissau', 11.803749, -15.180413, 'GW'),
#  (91, 'Guyana', 4.860416000000001, -58.93018000000001, 'GY'),
#  (92, 'Gaza Strip', 31.354676, 34.308825, 'GZ'),
#  (93, 'Hong Kong', 22.396428, 114.10949699999999, 'HK'),
#  (94, 'Heard Island and McDonald Islands', -53.08181, 73.50415799999999, 'HM'),
#  (95, 'Honduras', 15.199998999999998, -86.241905, 'HN'),
#  (96, 'Croatia', 45.1, 15.2, 'HR'),
#  (97, 'Haiti', 18.971187, -72.28521500000001, 'HT'),
#  (98, 'Hungary', 47.162494, 19.503304, 'HU'),
#  (99, 'Indonesia', -0.789275, 113.921327, 'ID'),
#  (100, 'Ireland', 53.41291, -8.243889999999999, 'IE'),
#  (101, 'Israel', 31.046051000000002, 34.851612, 'IL'),
#  (102, 'Isle of Man', 54.236107, -4.548056, 'IM'),
#  (103, 'India', 20.593684, 78.96288, 'IN'),
#  (104, 'British Indian Ocean Territory', -6.343194, 71.87651899999999, 'IO'),
#  (105, 'Iraq', 33.223191, 43.679291, 'IQ'),
#  (106, 'Iran', 32.427908, 53.68804599999999, 'IR'),
#  (107, 'Iceland', 64.96305100000001, -19.020835, 'IS'),
#  (108, 'Italy', 41.87194, 12.56738, 'IT'),
#  (109, 'Jersey', 49.214439, -2.13125, 'JE'),
#  (110, 'Jamaica', 18.109581, -77.297508, 'JM'),
#  (111, 'Jordan', 30.585164000000002, 36.238414, 'JO'),
#  (112, 'Japan', 36.204824, 138.252924, 'JP'),
#  (113, 'Kenya', -0.023559, 37.906193, 'KE'),
#  (114, 'Kyrgyzstan', 41.20438, 74.766098, 'KG'),
#  (115, 'Cambodia', 12.565679, 104.990963, 'KH'),
#  (116, 'Kiribati', -3.3704169999999998, -168.734039, 'KI'),
#  (117, 'Comoros', -11.875001, 43.872219, 'KM'),
#  (118, 'Saint Kitts and Nevis', 17.357822, -62.782998, 'KN'),
#  (119, 'North Korea', 40.339852, 127.510093, 'KP'),
#  (120, 'South Korea', 35.907757000000004, 127.766922, 'KR'),
#  (121, 'Kuwait', 29.311659999999996, 47.481766, 'KW'),
#  (122, 'Cayman Islands', 19.513469, -80.566956, 'KY'),
#  (123, 'Kazakhstan', 48.019573, 66.923684, 'KZ'),
#  (124, 'Laos', 19.856270000000002, 102.495496, 'LA'),
#  (125, 'Lebanon', 33.854721000000005, 35.862285, 'LB'),
#  (126, 'Saint Lucia', 13.909444, -60.97889300000001, 'LC'),
#  (127, 'Liechtenstein', 47.166000000000004, 9.555373, 'LI'),
#  (128, 'Sri Lanka', 7.873054, 80.77179699999999, 'LK'),
#  (129, 'Liberia', 6.4280550000000005, -9.429499, 'LR'),
#  (130, 'Lesotho', -29.609988, 28.233608, 'LS'),
#  (131, 'Lithuania', 55.169438, 23.881275, 'LT'),
#  (132, 'Luxembourg', 49.815273, 6.129583, 'LU'),
#  (133, 'Latvia', 56.879635, 24.603189, 'LV'),
#  (134, 'Libya', 26.3351, 17.228331, 'LY'),
#  (135, 'Morocco', 31.791702, -7.09262, 'MA'),
#  (136, 'Monaco', 43.750298, 7.412841, 'MC'),
#  (137, 'Moldova', 47.411631, 28.369884999999996, 'MD'),
#  (138, 'Montenegro', 42.708678000000006, 19.37439, 'ME'),
#  (139, 'Madagascar', -18.766947000000002, 46.869107, 'MG'),
#  (140, 'Marshall Islands', 7.131474000000001, 171.184478, 'MH'),
#  (141, 'Macedonia [FYROM]', 41.608635, 21.745275, 'MK'),
#  (142, 'Mali', 17.570692, -3.9961660000000006, 'ML'),
#  (143, 'Myanmar [Burma]', 21.913965, 95.956223, 'MM'),
#  (144, 'Mongolia', 46.862496, 103.84665600000001, 'MN'),
#  (145, 'Macau', 22.198745000000002, 113.543873, 'MO'),
#  (146, 'Northern Mariana Islands', 17.33083, 145.38468999999998, 'MP'),
#  (147, 'Martinique', 14.641528, -61.024174, 'MQ'),
#  (148, 'Mauritania', 21.00789, -10.940835, 'MR'),
#  (149, 'Montserrat', 16.742498, -62.187366000000004, 'MS'),
#  (150, 'Malta', 35.937496, 14.375416, 'MT'),
#  (151, 'Mauritius', -20.348404000000002, 57.552152, 'MU'),
#  (152, 'Maldives', 3.202778, 73.22068, 'MV'),
#  (153, 'Malawi', -13.254307999999998, 34.301525, 'MW'),
#  (154, 'Mexico', 23.634501, -102.552784, 'MX'),
#  (155, 'Malaysia', 4.210483999999999, 101.97576600000001, 'MY'),
#  (156, 'Mozambique', -18.665695, 35.529562, 'MZ'),
#  (157, 'Namibia', -22.957639999999998, 18.49041, None),
#  (158, 'New Caledonia', -20.904304999999997, 165.618042, 'NC'),
#  (159, 'Niger', 17.607789, 8.081666, 'NE'),
#  (160, 'Norfolk Island', -29.040834999999998, 167.954712, 'NF'),
#  (161, 'Nigeria', 9.081999, 8.675277000000001, 'NG'),
#  (162, 'Nicaragua', 12.865416, -85.207229, 'NI'),
#  (163, 'Netherlands', 52.132633, 5.291266, 'NL'),
#  (164, 'Norway', 60.472024, 8.468946, 'NO'),
#  (165, 'Nepal', 28.394857000000002, 84.12400799999999, 'NP'),
#  (166, 'Nauru', -0.522778, 166.931503, 'NR'),
#  (167, 'Niue', -19.054445, -169.867233, 'NU'),
#  (168, 'New Zealand', -40.900557, 174.88597099999998, 'NZ'),
#  (169, 'Oman', 21.512583, 55.923255000000005, 'OM'),
#  (170, 'Panama', 8.537981, -80.782127, 'PA'),
#  (171, 'Peru', -9.189967, -75.015152, 'PE'),
#  (172, 'French Polynesia', -17.679742, -149.40684299999998, 'PF'),
#  (173, 'Papua New Guinea', -6.314993, 143.95555, 'PG'),
#  (174, 'Philippines', 12.879721, 121.77401699999999, 'PH'),
#  (175, 'Pakistan', 30.375321000000003, 69.345116, 'PK'),
#  (176, 'Poland', 51.919438, 19.145135999999997, 'PL'),
#  (177, 'Saint Pierre and Miquelon', 46.941936, -56.27111, 'PM'),
#  (178, 'Pitcairn Islands', -24.703615, -127.43930800000001, 'PN'),
#  (179, 'Puerto Rico', 18.220833, -66.590149, 'PR'),
#  (180, 'Palestinian Territories', 31.952162, 35.233154, 'PS'),
#  (181, 'Portugal', 39.399871999999995, -8.224454, 'PT'),
#  (182, 'Palau', 7.51498, 134.58252, 'PW'),
#  (183, 'Paraguay', -23.442503, -58.44383199999999, 'PY'),
#  (184, 'Qatar', 25.354826, 51.183884, 'QA'),
#  (185, 'Réunion', -21.115141, 55.536384, 'RE'),
#  (186, 'Romania', 45.943160999999996, 24.96676, 'RO'),
#  (187, 'Serbia', 44.016521000000004, 21.005859, 'RS'),
#  (188, 'Russia', 61.52401, 105.31875600000001, 'RU'),
#  (189, 'Rwanda', -1.940278, 29.873888, 'RW'),
#  (190, 'Saudi Arabia', 23.885942, 45.079162, 'SA'),
#  (191, 'Solomon Islands', -9.645710000000001, 160.156194, 'SB'),
#  (192, 'Seychelles', -4.679574, 55.491977, 'SC'),
#  (193, 'Sudan', 12.862807, 30.217636, 'SD'),
#  (194, 'Sweden', 60.128161, 18.643501, 'SE'),
#  (195, 'Singapore', 1.352083, 103.819836, 'SG'),
#  (196, 'Saint Helena', -24.143473999999998, -10.030696, 'SH'),
#  (197, 'Slovenia', 46.151241, 14.995463, 'SI'),
#  (198, 'Svalbard and Jan Mayen', 77.553604, 23.670272, 'SJ'),
#  (199, 'Slovakia', 48.669026, 19.699023999999998, 'SK'),
#  (200, 'Sierra Leone', 8.460555000000001, -11.779889, 'SL'),
#  (201, 'San Marino', 43.94236, 12.457777, 'SM'),
#  (202, 'Senegal', 14.497401000000002, -14.452361999999999, 'SN'),
#  (203, 'Somalia', 5.152149, 46.199616, 'SO'),
#  (204, 'Suriname', 3.9193050000000005, -56.02778299999999, 'SR'),
#  (205, 'São Tomé and Príncipe', 0.18636, 6.613081, 'ST'),
#  (206, 'El Salvador', 13.794185, -88.89653, 'SV'),
#  (207, 'Syria', 34.802075, 38.996815000000005, 'SY'),
#  (208, 'Swaziland', -26.522503000000004, 31.465866, 'SZ'),
#  (209, 'Turks and Caicos Islands', 21.694025, -71.797928, 'TC'),
#  (210, 'Chad', 15.454166, 18.732207, 'TD'),
#  (211, 'French Southern Territories', -49.280366, 69.348557, 'TF'),
#  (212, 'Togo', 8.619543, 0.824782, 'TG'),
#  (213, 'Thailand', 15.870032, 100.992541, 'TH'),
#  (214, 'Tajikistan', 38.861034000000004, 71.276093, 'TJ'),
#  (215, 'Tokelau', -8.967363, -171.855881, 'TK'),
#  (216, 'Timor-Leste', -8.874217, 125.727539, 'TL'),
#  (217, 'Turkmenistan', 38.969719, 59.556278000000006, 'TM'),
#  (218, 'Tunisia', 33.886917, 9.537499, 'TN'),
#  (219, 'Tonga', -21.178986, -175.198242, 'TO'),
#  (220, 'Turkey', 38.963745, 35.243322, 'TR'),
#  (221, 'Trinidad and Tobago', 10.691803, -61.222503, 'TT'),
#  (222, 'Tuvalu', -7.109535, 177.64933, 'TV'),
#  (223, 'Taiwan', 23.69781, 120.96051499999999, 'TW'),
#  (224, 'Tanzania', -6.369028, 34.888822, 'TZ'),
#  (225, 'Ukraine', 48.379433, 31.16558, 'UA'),
#  (226, 'Uganda', 1.373333, 32.290275, 'UG'),
#  (227, 'U.S. Minor Outlying Islands', None, None, 'UM'),
#  (228, 'United States', 37.09024, -95.712891, 'US'),
#  (229, 'Uruguay', -32.522779, -55.765834999999996, 'UY'),
#  (230, 'Uzbekistan', 41.377491, 64.585262, 'UZ'),
#  (231, 'Vatican City', 41.902916, 12.453389, 'VA'),
#  (232, 'Saint Vincent and the Grenadines', 12.984305, -61.287228000000006, 'VC'),
#  (233, 'Venezuela', 6.42375, -66.58973, 'VE'),
#  (234, 'British Virgin Islands', 18.420695000000002, -64.63996800000001, 'VG'),
#  (235, 'U.S. Virgin Islands', 18.335765, -64.896335, 'VI'),
#  (236, 'Vietnam', 14.058323999999999, 108.277199, 'VN'),
#  (237, 'Vanuatu', -15.376706, 166.959158, 'VU'),
#  (238, 'Wallis and Futuna', -13.768752, -177.156097, 'WF'),
#  (239, 'Samoa', -13.759029, -172.10462900000002, 'WS'),
#  (240, 'Kosovo', 42.602636, 20.902977, 'XK'),
#  (241, 'Yemen', 15.552726999999999, 48.516388, 'YE'),
#  (242, 'Mayotte', -12.8275, 45.166244, 'YT'),
#  (243, 'South Africa', -30.559482, 22.937506, 'ZA'),
#  (244, 'Zambia', -13.133897, 27.849332, 'ZM'),
#  (245, 'Zimbabwe', -19.015438, 29.154857, 'ZW')]

# %%
session.new
# Out:
# IdentitySet([<__main__.Join object at 0x00000201ADB9ACC0>, <__main__.Join object at 0x00000201ADB9AD30>, <__main__.Join object at 0x00000201ADB9ADD8>, <__main__.Join object at 0x00000201ADB9AE48>, <__main__.Join object at 0x00000201ADB9AEB8>, <__main__.Join object at 0x00000201ADB7F320>, <__main__.Join object at 0x00000201ADB7F160>, <__main__.Join object at 0x00000201ADB5AE80>, <__main__.Join object at 0x00000201ADB5AF28>, <__main__.Join object at 0x00000201ADB5AE48>, <__main__.Join object at 0x00000201ADB5AE10>, <__main__.Join object at 0x00000201ADB5ACC0>, <__main__.Join object at 0x00000201ADB81EB8>, <__main__.Join object at 0x00000201ADB9AF28>, <__main__.Join object at 0x00000201ADB9AF98>, <__main__.Join object at 0x00000201ADBA4048>, <__main__.Join object at 0x00000201ADBA40B8>, <__main__.Join object at 0x00000201ADBA4128>, <__main__.Join object at 0x00000201ADBA4198>, <__main__.Join object at 0x00000201ADBA4208>, <__main__.Join object at 0x00000201ADBA4278>, <__main__.Join object at 0x00000201ADBA42E8>, <__main__.Join object at 0x00000201ADBA4438>, <__main__.Join object at 0x00000201ADBA44A8>, <__main__.Join object at 0x00000201ADBA4518>, <__main__.Join object at 0x00000201ADBA4588>, <__main__.Join object at 0x00000201ADBA45F8>, <__main__.Join object at 0x00000201ADBA4668>, <__main__.Join object at 0x00000201ADBA46D8>, <__main__.Join object at 0x00000201ADBA4748>, <__main__.Join object at 0x00000201ADBA47B8>, <__main__.Join object at 0x00000201ADBA4828>, <__main__.Join object at 0x00000201ADBA4898>, <__main__.Join object at 0x00000201ADBA4908>, <__main__.Join object at 0x00000201ADBA4978>, <__main__.Join object at 0x00000201ADBA49E8>, <__main__.Join object at 0x00000201ADBA4A58>, <__main__.Join object at 0x00000201ADBA4AC8>, <__main__.Join object at 0x00000201ADBA4B38>, <__main__.Join object at 0x00000201ADBA4BA8>, <__main__.Join object at 0x00000201ADBA4C18>, <__main__.Join object at 0x00000201ADBA4C88>, <__main__.Join object at 0x00000201ADBA4CF8>, <__main__.Join object at 0x00000201ADBA4D68>, <__main__.Join object at 0x00000201ADBA4DD8>, <__main__.Join object at 0x00000201ADBA4E48>, <__main__.Join object at 0x00000201ADBA4EB8>, <__main__.Join object at 0x00000201ADBA4F28>, <__main__.Join object at 0x00000201ADBA4F98>, <__main__.Join object at 0x00000201ADBAF048>, <__main__.Join object at 0x00000201ADBAF0B8>, <__main__.Join object at 0x00000201ADBAF128>, <__main__.Join object at 0x00000201ADBAF198>, <__main__.Join object at 0x00000201ADBAF208>, <__main__.Join object at 0x00000201ADBAF278>, <__main__.Join object at 0x00000201ADBAF2E8>, <__main__.Join object at 0x00000201ADBA4400>, <__main__.Join object at 0x00000201ADB81B38>, <__main__.Join object at 0x00000201ADBAF390>, <__main__.Join object at 0x00000201ADBAF400>, <__main__.Join object at 0x00000201ADBAF470>, <__main__.Join object at 0x00000201ADBAF4E0>, <__main__.Join object at 0x00000201ADBAF550>, <__main__.Join object at 0x00000201ADBAF5C0>, <__main__.Join object at 0x00000201ADBAF630>, <__main__.Join object at 0x00000201ADBAF6A0>, <__main__.Join object at 0x00000201ADBAF710>, <__main__.Join object at 0x00000201ADBAF780>, <__main__.Join object at 0x00000201ADBAF7F0>, <__main__.Join object at 0x00000201ADBAF860>, <__main__.Join object at 0x00000201ADBAF8D0>, <__main__.Join object at 0x00000201ADBAF940>, <__main__.Join object at 0x00000201ADBAF9B0>, <__main__.Join object at 0x00000201ADBAFA20>, <__main__.Join object at 0x00000201ADBAFA90>, <__main__.Join object at 0x00000201ADBAFB00>, <__main__.Join object at 0x00000201ADBAFB70>, <__main__.Join object at 0x00000201ADBAFBE0>, <__main__.Join object at 0x00000201ADBAFC50>, <__main__.Join object at 0x00000201ADBAFCC0>, <__main__.Join object at 0x00000201ADBAFD30>, <__main__.Join object at 0x00000201ADBAFDA0>, <__main__.Join object at 0x00000201ADBAFE10>, <__main__.Join object at 0x00000201ADBAFE80>, <__main__.Join object at 0x00000201ADBAFEF0>, <__main__.Join object at 0x00000201ADBAFF60>, <__main__.Join object at 0x0000 ...

# %%
session.commit()

# %%
session.new
# Out:
# IdentitySet([])

# %%
session.query(Join.country, Join.lat, Join.lon, Join.gdpPerCap).all()
# Out:
# [('Angola', -11.202691999999999, 17.873887, 4105.89),
#  ('Albania', 41.153332, 20.168331, 4676.32),
#  ('Argentina', -38.416097, -63.616671999999994, 10411.87),
#  ('Armenia', 40.069099, 45.038189, 3957.72),
#  ('Australia', -25.274398, 133.775136, 56718.69),
#  ('Austria', 47.516231, 14.550072, 48654.21),
#  ('Azerbaijan', 40.143105, 47.576927000000005, 5927.4),
#  ('Burundi', -3.3730559999999996, 29.918885999999997, 340.76),
#  ('Belgium', 50.503887, 4.469936, 45688.67),
#  ('Benin', 9.30769, 2.315834, 1648.44),
#  ('Burkina Faso', 12.238333, -1.561593, 683.61),
#  ('Bangladesh', 23.684994, 90.35633100000001, 1077.34),
#  ('Bulgaria', 42.733883, 25.48583, 7912.02),
#  ('Bosnia and Herzegovina', 43.915886, 17.679076000000002, 5353.48),
#  ('Belarus', 53.709807, 27.953389, 6237.03),
#  ('Bolivia', -16.290154, -63.588653, 2495.02),
#  ('Brazil', -14.235004, -51.92528, 10957.89),
#  ('Bhutan', 27.514162, 90.433601, 3253.12),
#  ('Botswana', -22.328474, 24.684866, 8359.51),
#  ('Central African Republic', 6.611111, 20.939444, 331.44),
#  ('Canada', 56.130366, -106.34677099999999, 51428.4),
#  ('Switzerland', 46.818188, 8.227511999999999, 76694.04),
#  ('Chile', -35.675146999999996, -71.542969, 15918.77),
#  ('China', 35.86166, 104.195397, 6938.07),
#  ('Cameroon', 7.369722, 12.354722, 1618.6),
#  ('Colombia', 4.570868, -74.297333, 7896.65),
#  ('Comoros', -11.875001, 43.872219, 786.41),
#  ('Costa Rica', 9.748917, -83.753428, 9784.7),
#  ('Cyprus', 35.126413, 33.429859, 20940.51),
#  ('Czech Republic', 49.817492, 15.472961999999999, 21936.16),
#  ('Germany', 51.165690999999995, 10.451526, 46295.22),
#  ('Djibouti', 11.825138, 42.590275, None),
#  ('Denmark', 56.26392, 9.501785, 61145.6),
#  ('Dominican Republic', 18.735692999999998, -70.162651, 6996.71),
#  ('Algeria', 28.033886, 1.6596259999999998, 4827.73),
#  ('Ecuador', -1.8312389999999998, -78.183406, 5268.49),
#  ('Spain', 40.463667, -3.7492199999999998, 31530.3),
#  ('Estonia', 58.595271999999994, 25.013607, 18099.86),
#  ('Ethiopia', 9.145, 40.489672999999996, 524.14),
#  ('Finland', 61.92411, 25.748151, 46115.63),
#  ('France', 46.227638, 2.213749, 42117.51),
#  ('Gabon', -0.803689, 11.609444, 17412.6),
#  ('United Kingdom', 55.378051, -3.435973, 42340.98),
#  ('Georgia', 42.315407, 43.356891999999995, 4086.42),
#  ('Ghana', 7.946527000000001, -1.0231940000000002, 2237.45),
#  ('Guinea', 9.945587, -9.696645, 1188.77),
#  ('Greece', 39.074208, 21.824312, 22445.07),
#  ('Guatemala', 15.783470999999999, -90.23075899999999, 3163.95),
#  ('Honduras', 15.199998999999998, -86.241905, 2144.87),
#  ('Croatia', 45.1, 15.2, 14534.02),
#  ('Haiti', 18.971187, -72.28521500000001, 729.36),
#  ('Hungary', 47.162494, 19.503304, 14953.02),
#  ('Indonesia', -0.789275, 113.921327, 3974.72),
#  ('Ireland', 53.41291, -8.243889999999999, 72458.79),
#  ('Iraq', 33.223191, 43.679291, 5923.69),
#  ('Iceland', 64.96305100000001, -19.020835, 49680.0),
#  ('Israel', 31.046051000000002, 34.851612, 34344.22),
#  ('Italy', 41.87194, 12.56738, 34260.17),
#  ('Jordan', 30.585164000000002, 36.238414, 3662.19),
#  ('Japan', 36.204824, 138.252924, 47658.82),
#  ('Kazakhstan', 48.019573, 66.923684, 11214.59),
#  ('Lebanon', 33.854721000000005, 35.862285, 7658.26),
#  ('Liberia', 6.4280550000000005, -9.429499, 463.16),
#  ('Sri Lanka', 7.873054, 80.77179699999999, 3769.2),
#  ('Lesotho', -29.609988, 28.233608, 1516.34),
#  ('Lithuania', 55.169438, 23.881275, 15744.19),
#  ('Luxembourg', 49.815273, 6.129583, 110967.03),
#  ('Latvia', 56.879635, 24.603189, 14599.8),
#  ('Morocco', 31.791702, -7.09262, 3344.71),
#  ('Moldova', 47.411631, 28.369884999999996, 2069.38),
#  ('Madagascar', -18.766947000000002, 46.869107, 416.0),
#  ('Mexico', 23.634501, -102.552784, 10001.04),
#  ('Mali', 17.570692, -3.9961660000000006, 838.51),
#  ('Malta', 35.937496, 14.375416, 27481.34),
#  ('Montenegro', 42.708678000000006, 19.37439, 7494.6),
#  ('Mongolia', 46.862496, 103.84665600000001, 3906.12),
#  ('Mauritania', 21.00789, -10.940835, 1589.76),
#  ('Mauritius', -20.348404000000002, 57.552152, 9822.01),
#  ('Malawi', -13.254307999999998, 34.301525, 525.44),
#  ('Malaysia', 4.210483999999999, 101.97576600000001, 11381.89),
#  ('Namibia', -22.957639999999998, 18.49041, 9583.55),
#  ('Niger', 17.607789, 8.081666, 916.82),
#  ('Nigeria', 9.081999, 8.675277000000001, 2958.35),
#  ('Nicaragua', 12.865416, -85.207229, 2083.66),
#  ('Netherlands', 52.132633, 5.291266, 52546.64),
#  ('Norway', 60.472024, 8.468946, 91116.17),
#  ('Nepal', 28.394857000000002, 84.12400799999999, 685.12),
#  ('Pakistan', 30.375321000000003, 69.345116, 1179.41),
#  ('Panama', 8.537981, -80.782127, 11284.01),
#  ('Peru', -9.189967, -75.015152, 6252.25),
#  ('Philippines', 12.879721, 121.77401699999999, 2752.11),
#  ('Poland', 51.919438, 19.145135999999997, 15061.49),
#  ('Portugal', 39.399871999999995, -8.224454, 22280.9),
#  ('Paraguay', -23.442503, -58.44383199999999, 3976.52),
#  ('Romania', 45.943160999999996, 24.96676, 10104.07),
#  ('Rwanda', -1.940278, 29.873888, 738.83),
#  ('Sudan', 12.862807, 30.217636, 1970.34),
#  ('Senegal', 14.497401000000002, -14.452361999999999, 1092.25),
#  ('Sierra Leone', 8.460555000000001, -11.779889, 616.83),
#  ('El Salvador', 13.794185, -88.89653, 3502.01),
#  ('Serbia', 44.016521000000004, 21.005859, 5821.82),
#  ('Suriname', 3.9193050000000005, -56.02778299999999, 8605.5),
#  ('Slovenia', 46.151241, 14.995463, 24478.31),
#  ('Sweden', 60.128161, 18.643501, 57187.1),
#  ('Chad', 15.454166, 18.732207, 1063.55),
#  ('Togo', 8.619543, 0.824782, 589.97),
#  ('Thailand', 15.870032, 100.992541, 5928.19),
#  ('Tajikistan', 38.861034000000004, 71.276093, 1034.36),
#  ('Trinidad and Tobago', 10.691803, -61.222503, 16203.56),
#  ('Tunisia', 33.886917, 9.537499, 4368.49),
#  ('Turkey', 38.963745, 35.243322, 14341.24),
#  ('Tanzania', -6.369028, 34.888822, 952.98),
#  ('Uganda', 1.373333, 32.290275, 783.13),
#  ('Ukraine', 48.379433, 31.16558, 2755.27),
#  ('Uruguay', -32.522779, -55.765834999999996, 14093.6),
#  ('United States', 37.09024, -95.712891, 53114.38),
#  ('Vietnam', 14.058323999999999, 108.277199, 1887.73),
#  ('Kosovo', 42.602636, 20.902977, 3956.75),
#  ('South Africa', -30.559482, 22.937506, 8142.55),
#  ('Zambia', -13.133897, 27.849332, 1895.38)]

# %%
# Define the joined table
class Explain(Base):
    __tablename__ = "explain"
    id =Column(Integer, primary_key=True)
    country = Column(String)
    happiness = Column(Float)
    gdppercap = Column(Float)
    social = Column(Float)
    health = Column(Float)
    freedom = Column(Float)
    generosity = Column(Float)
    corruption = Column(Float)
    residual = Column(Float)

# %%
Base.metadata.tables
# Out:
# immutabledict({'happiness': Table('happiness', MetaData(bind=None), Column('id', Integer(), table=<happiness>, primary_key=True, nullable=False), Column('country', String(), table=<happiness>), Column('year', Text(), table=<happiness>), Column('happiness', Float(), table=<happiness>), Column('lat', Float(), table=<happiness>), Column('lon', Float(), table=<happiness>), schema=None), 'gini': Table('gini', MetaData(bind=None), Column('id', Integer(), table=<gini>, primary_key=True, nullable=False), Column('country', String(), table=<gini>), Column('country_code', String(), table=<gini>), Column('year', Text(), table=<gini>), Column('gini', Float(), table=<gini>), Column('lat', Float(), table=<gini>), Column('lon', Float(), table=<gini>), schema=None), 'demographic': Table('demographic', MetaData(bind=None), Column('id', Integer(), table=<demographic>, primary_key=True, nullable=False), Column('country', String(), table=<demographic>), Column('region_id', String(), table=<demographic>), Column('year', Text(), table=<demographic>), Column('gdp', Float(), table=<demographic>), Column('population', Float(), table=<demographic>), Column('lat', Float(), table=<demographic>), Column('lon', Float(), table=<demographic>), schema=None), 'geo': Table('geo', MetaData(bind=None), Column('id', Integer(), table=<geo>, primary_key=True, nullable=False), Column('country', String(), table=<geo>), Column('lat', Float(), table=<geo>), Column('lon', Float(), table=<geo>), Column('init', String(), table=<geo>), schema=None), 'join': Table('join', MetaData(bind=None), Column('id', Integer(), table=<join>, primary_key=True, nullable=False), Column('country', String(), table=<join>), Column('country_code', String(), table=<join>), Column('region_id', String(), table=<join>), Column('gdp', Float(), table=<join>), Column('population', Float(), table=<join>), Column('lat', Float(), table=<join>), Column('lon', Float(), table=<join>), Column('gini', Float(), table=<join>), Column('happiness', Float(), table=<join>), Column('gdpPerCap', Float(), table=<join>), schema=None), 'explain': Table('explain', MetaData(bind=None), Column('id', Integer(), table=<explain>, primary_key=True, nullable=False), Column('country', String(), table=<explain>), Column('happiness', Float(), table=<explain>), Column('gdppercap', Float(), table=<explain>), Column('social', Float(), table=<explain>), Column('health', Float(), table=<explain>), Column('freedom', Float(), table=<explain>), Column('generosity', Float(), table=<explain>), Column('corruption', Float(), table=<explain>), Column('residual', Float(), table=<explain>), schema=None)})

# %%
engine = create_engine("sqlite:///./db/data.sqlite")

# %%
Base.metadata.create_all(engine)

# %%
session = Session(engine)

# %%
for i in happi_df.index:
    session.add(Explain(
        country = happi_df["Country"][i],
        happiness = happi_df["Happiness score"][i],
        gdppercap = happi_df["Explained by: GDP per capita"][i],
        social = happi_df["Explained by: Social support"][i],
        health = happi_df["Explained by: Healthy life expectancy"][i],
        freedom = happi_df["Explained by: Freedom to make life choices"][i],
        generosity = happi_df["Explained by: Generosity"][i],
        corruption = happi_df["Explained by: Perceptions of corruption"][i],
        residual = happi_df["Dystopia (1.88) + residual"][i],
    ))

# %%
engine.execute("SELECT * FROM Explain").fetchall()
# Out:
# []

# %%
session.new
# Out:
# IdentitySet([<__main__.Explain object at 0x00000201ADBF5B70>, <__main__.Explain object at 0x00000201ADBF5BE0>, <__main__.Explain object at 0x00000201ADBF5C88>, <__main__.Explain object at 0x00000201ADBF5CF8>, <__main__.Explain object at 0x00000201ADBF5D68>, <__main__.Explain object at 0x00000201ADBF5DD8>, <__main__.Explain object at 0x00000201ADBF5E48>, <__main__.Explain object at 0x00000201ADBF5EB8>, <__main__.Explain object at 0x00000201ADBF5F28>, <__main__.Explain object at 0x00000201ADBF5F98>, <__main__.Explain object at 0x00000201ADBFB048>, <__main__.Explain object at 0x00000201ADBFB0B8>, <__main__.Explain object at 0x00000201ADBFB128>, <__main__.Explain object at 0x00000201ADBFB198>, <__main__.Explain object at 0x00000201ADBFB208>, <__main__.Explain object at 0x00000201ADBFB278>, <__main__.Explain object at 0x00000201ADBFB2E8>, <__main__.Explain object at 0x00000201ADBFB358>, <__main__.Explain object at 0x00000201ADBFB3C8>, <__main__.Explain object at 0x00000201ADBFB438>, <__main__.Explain object at 0x00000201ADBFB4A8>, <__main__.Explain object at 0x00000201ADBFB518>, <__main__.Explain object at 0x00000201ADBF5C18>, <__main__.Explain object at 0x00000201ADBD7F28>, <__main__.Explain object at 0x00000201ADBAD6A0>, <__main__.Explain object at 0x00000201ADBAD2B0>, <__main__.Explain object at 0x00000201ADBAD080>, <__main__.Explain object at 0x00000201ADBAD5C0>, <__main__.Explain object at 0x00000201ADB90A58>, <__main__.Explain object at 0x00000201ADB908D0>, <__main__.Explain object at 0x00000201ADB906D8>, <__main__.Explain object at 0x00000201ADB90BA8>, <__main__.Explain object at 0x00000201ADB90D30>, <__main__.Explain object at 0x00000201ADBD1630>, <__main__.Explain object at 0x00000201ADB81C50>, <__main__.Explain object at 0x00000201ADB81748>, <__main__.Explain object at 0x00000201ADB81BE0>, <__main__.Explain object at 0x00000201ADB5ACF8>, <__main__.Explain object at 0x00000201ADB0A2B0>, <__main__.Explain object at 0x00000201ADB7F358>, <__main__.Explain object at 0x00000201ADB7F588>, <__main__.Explain object at 0x00000201ADAF89E8>, <__main__.Explain object at 0x00000201ADAFBB70>, <__main__.Explain object at 0x00000201ADAFB5F8>, <__main__.Explain object at 0x00000201ADAFB668>, <__main__.Explain object at 0x00000201ADAFB390>, <__main__.Explain object at 0x00000201ADAFB400>, <__main__.Explain object at 0x00000201ADAA67B8>, <__main__.Explain object at 0x00000201ADBFB668>, <__main__.Explain object at 0x00000201ADBFB630>, <__main__.Explain object at 0x00000201ADBFB6D8>, <__main__.Explain object at 0x00000201ADBD4A90>, <__main__.Explain object at 0x00000201ADBFB748>, <__main__.Explain object at 0x00000201ADBFB7B8>, <__main__.Explain object at 0x00000201ADBFB828>, <__main__.Explain object at 0x00000201ADBFB898>, <__main__.Explain object at 0x00000201ADBFB908>, <__main__.Explain object at 0x00000201ADBFB978>, <__main__.Explain object at 0x00000201ADBFB9E8>, <__main__.Explain object at 0x00000201ADBFBA58>, <__main__.Explain object at 0x00000201ADBFBAC8>, <__main__.Explain object at 0x00000201ADBFBB38>, <__main__.Explain object at 0x00000201ADBFBBA8>, <__main__.Explain object at 0x00000201ADBFBC18>, <__main__.Explain object at 0x00000201ADBFBC88>, <__main__.Explain object at 0x00000201ADBFBCF8>, <__main__.Explain object at 0x00000201ADBFBD68>, <__main__.Explain object at 0x00000201ADBFBDD8>, <__main__.Explain object at 0x00000201ADBFBE48>, <__main__.Explain object at 0x00000201ADBFBEB8>, <__main__.Explain object at 0x00000201ADBFBF28>, <__main__.Explain object at 0x00000201ADBFBF98>, <__main__.Explain object at 0x00000201ADC0E048>, <__main__.Explain object at 0x00000201ADC0E0B8>, <__main__.Explain object at 0x00000201ADC0E128>, <__main__.Explain object at 0x00000201ADC0E198>, <__main__.Explain object at 0x00000201ADC0E208>, <__main__.Explain object at 0x00000201ADC0E278>, <__main__.Explain object at 0x00000201ADC0E2E8>, <__main__.Explain object at 0x00000201ADC0E358>, <__main__.Explain object at 0x00000201ADC0E3C8>, <__main__.Explain  ...

# %%
session.commit()

# %%
session.new
# Out:
# IdentitySet([])

# %%
session.query(Explain.country, Explain.gdppercap, Explain.social, Explain.health).all()
# Out:
# [('Finland', 1.34, 1.587, 0.986),
#  ('Denmark', 1.383, 1.5730000000000002, 0.996),
#  ('Norway', 1.4880000000000002, 1.5819999999999999, 1.028),
#  ('Iceland', 1.38, 1.624, 1.026),
#  ('Netherlands', 1.396, 1.5219999999999998, 0.9990000000000001),
#  ('Switzerland', 1.452, 1.526, 1.052),
#  ('Sweden', 1.3869999999999998, 1.4869999999999999, 1.0090000000000001),
#  ('New Zealand', 1.3030000000000002, 1.557, 1.026),
#  ('Canada', 1.365, 1.505, 1.0390000000000001),
#  ('Austria', 1.376, 1.475, 1.016),
#  ('Australia', 1.3719999999999999, 1.548, 1.036),
#  ('Costa Rica', 1.034, 1.4409999999999998, 0.963),
#  ('Israel', 1.276, 1.455, 1.0290000000000001),
#  ('Luxembourg', 1.609, 1.479, 1.012),
#  ('United Kingdom', 1.3330000000000002, 1.538, 0.996),
#  ('Ireland', 1.499, 1.5530000000000002, 0.9990000000000001),
#  ('Germany', 1.3730000000000002, 1.454, 0.987),
#  ('Belgium', 1.3559999999999999, 1.504, 0.986),
#  ('United States', 1.433, 1.4569999999999999, 0.8740000000000001),
#  ('Czech Republic', 1.2690000000000001, 1.4869999999999999, 0.92),
#  ('United Arab Emirates', 1.5030000000000001, 1.31, 0.825),
#  ('Malta', 1.3, 1.52, 0.9990000000000001),
#  ('Mexico', 1.07, 1.3230000000000002, 0.861),
#  ('France', 1.324, 1.472, 1.045),
#  ('Taiwan Province of China', 1.368, 1.43, 0.914),
#  ('Chile', 1.159, 1.369, 0.92),
#  ('Guatemala', 0.8, 1.2690000000000001, 0.746),
#  ('Saudi Arabia', 1.403, 1.357, 0.795),
#  ('Qatar', 1.6840000000000002, 1.3130000000000002, 0.871),
#  ('Spain', 1.286, 1.484, 1.062),
#  ('Panama', 1.149, 1.442, 0.91),
#  ('Brazil', 1.004, 1.439, 0.802),
#  ('Uruguay', 1.124, 1.465, 0.8909999999999999),
#  ('Singapore', 1.5719999999999998, 1.463, 1.141),
#  ('El Salvador', 0.794, 1.242, 0.789),
#  ('Italy', 1.294, 1.4880000000000002, 1.0390000000000001),
#  ('Bahrain', 1.3619999999999999, 1.368, 0.871),
#  ('Slovakia', 1.246, 1.504, 0.8809999999999999),
#  ('Trinidad and Tobago', 1.2309999999999999, 1.4769999999999999, 0.713),
#  ('Poland', 1.206, 1.4380000000000002, 0.884),
#  ('Uzbekistan', 0.745, 1.5290000000000001, 0.7559999999999999),
#  ('Lithuania', 1.238, 1.515, 0.818),
#  ('Colombia', 0.985, 1.41, 0.841),
#  ('Slovenia', 1.258, 1.5230000000000001, 0.953),
#  ('Nicaragua', 0.6940000000000001, 1.325, 0.835),
#  ('Kosovo', 0.882, 1.232, 0.758),
#  ('Argentina', 1.092, 1.432, 0.8809999999999999),
#  ('Romania', 1.162, 1.232, 0.825),
#  ('Cyprus', 1.263, 1.2229999999999999, 1.042),
#  ('Ecuador', 0.912, 1.3119999999999998, 0.868),
#  ('Kuwait', 1.5, 1.319, 0.8079999999999999),
#  ('Thailand', 1.05, 1.409, 0.828),
#  ('Latvia', 1.187, 1.465, 0.812),
#  ('South Korea', 1.301, 1.219, 1.036),
#  ('Estonia', 1.237, 1.528, 0.8740000000000001),
#  ('Jamaica', 0.831, 1.4780000000000002, 0.831),
#  ('Mauritius', 1.12, 1.402, 0.7979999999999999),
#  ('Japan', 1.327, 1.419, 1.088),
#  ('Honduras', 0.642, 1.236, 0.828),
#  ('Kazakhstan', 1.173, 1.508, 0.7290000000000001),
#  ('Bolivia', 0.7759999999999999, 1.209, 0.706),
#  ('Hungary', 1.2009999999999998, 1.41, 0.828),
#  ('Paraguay', 0.855, 1.475, 0.777),
#  ('North Cyprus', 1.263, 1.252, 1.042),
#  ('Peru', 0.96, 1.274, 0.8540000000000001),
#  ('Portugal', 1.2209999999999999, 1.431, 0.9990000000000001),
#  ('Pakistan', 0.677, 0.8859999999999999, 0.535),
#  ('Russia', 1.183, 1.452, 0.726),
#  ('Philippines', 0.807, 1.2930000000000001, 0.657),
#  ('Serbia', 1.004, 1.383, 0.8540000000000001),
#  ('Moldova', 0.685, 1.328, 0.7390000000000001),
#  ('Libya', 1.044, 1.3030000000000002, 0.6729999999999999),
#  ('Montenegro', 1.051, 1.361, 0.871),
#  ('Tajikistan', 0.493, 1.0979999999999999, 0.718),
#  ('Croatia', 1.155, 1.266, 0.914),
#  ('Hong Kong S.A.R. of China', 1.4380000000000002, 1.2770000000000001, 1.122),
#  ('Dominican Republic', 1.015, 1.401, 0.779),
#  ('Bosnia and Herzegovina', 0.945, 1.212, 0.845),
#  ('Turkey', 1.183, 1.36, 0.8079999999999999),
#  ('Malaysia', 1.2209999999999999, 1.171, 0.828),
#  ('Belarus', 1.067, 1.465, 0.789),
#  ('Greece', 1.181, 1.156, 0.9990000000000001),
#  ('Mongolia', 0.948, 1.531, 0.667),
#  ('Macedonia', 0.983, 1.294, 0.838),
#  ('Nigeria', 0.696, 1.111, 0.245),
#  ('Kyrgyzstan', 0.551, 1.4380000000000002, 0.723),
#  ('Turkmenistan', 1.052, 1.538, 0.657),
#  ('Algeria', 1.002, 1.16, 0.785),
#  ('Morocco', 0.8009999999999999, 0.782, 0.782),
#  ('Azerbaijan', 1.043, 1.147, 0.769),
#  ('Lebanon', 0.987, 1.224, 0.815),
#  ('Indonesia', 0.9309999999999999, 1.203, 0.66),
#  ('China', 1.0290000000000001, 1.125, 0.893),
#  ('Vietnam', 0.741, 1.3459999999999999, 0.851),
#  ('Bhutan', 0.813, 1.321, 0.604),
#  ('Cameroon', 0.5489999999999999, 0.91, 0.331),
#  ('Bulgaria', 1.092, 1.5130000000000001, 0.815),
#  ('Ghana', 0.611, 0.868, 0.486),
#  ('Ivory Coast', 0.569, 0.8079999999999999, 0.23199999999999998),
#  ('Nepal', 0.446, 1.226, 0.677),
#  ('Jordan', 0.8370000000000001, 1.225, 0.815),
#  ('Benin', 0.39299999999999996, 0.43700000000000006, 0.397),
#  ('Congo (Brazzaville)', 0.6729999999999999, 0.799, 0.508),
#  ('Gabon', 1.057, 1.183, 0.5710000000000001),
#  ('Laos', 0.764, 1.03, 0.551),
#  ('South Africa', 0.96, 1.351, 0.469),
#  ('Albania', 0.9470000000000001, 0.848, 0.8740000000000001),
#  ('Venezuela', 0.96, 1.4269999999999998, 0.805),
#  ('Cambodia', 0.574, 1.122, 0.637),
#  ('Palestinian Territories', 0.657, 1.247, 0.672),
#  ('Senegal', 0.45, 1.1340000000000001, 0.5710000000000001),
#  ('Somalia', 0.0, 0.698, 0.268),
#  ('Namibia', 0.879, 1.3130000000000002, 0.47700000000000004),
#  ('Niger', 0.138, 0.774, 0.366),
#  ('Burkina Faso', 0.331, 1.056, 0.38),
#  ('Armenia', 0.85, 1.055, 0.815),
#  ('Iran', 1.1, 0.8420000000000001, 0.785),
#  ('Guinea', 0.38, 0.8290000000000001, 0.375),
#  ('Georgia', 0.8859999999999999, 0.6659999999999999, 0.752),
#  ('Gambia', 0.308, 0.9390000000000001, 0.428),
#  ('Kenya', 0.512, 0.983, 0.581),
#  ('Mauritania', 0.57, 1.167, 0.489),
#  ('Mozambique', 0.204, 0.986, 0.39),
#  ('Tunisia', 0.9209999999999999, 1.0, 0.815),
#  ('Bangladesh', 0.562, 0.9279999999999999, 0.723),
#  ('Iraq', 1.043, 0.98, 0.574),
#  ('Congo (Kinshasa)', 0.094, 1.125, 0.35700000000000004),
#  ('Mali', 0.385, 1.105, 0.308),
#  ('Sierra Leone', 0.268, 0.841, 0.242),
#  ('Sri Lanka', 0.9490000000000001, 1.265, 0.831),
#  ('Myanmar', 0.71, 1.181, 0.555),
#  ('Chad', 0.35, 0.7659999999999999, 0.192),
#  ('Ukraine', 0.82, 1.39, 0.7390000000000001),
#  ('Ethiopia', 0.336, 1.033, 0.532),
#  ('Swaziland', 0.8109999999999999, 1.149, 0.0),
#  ('Uganda', 0.332, 1.069, 0.44299999999999995),
#  ('Egypt', 0.9129999999999999, 1.0390000000000001, 0.644),
#  ('Zambia', 0.578, 1.058, 0.426),
#  ('Togo', 0.275, 0.5720000000000001, 0.41),
#  ('India', 0.755, 0.765, 0.588),
#  ('Liberia', 0.073, 0.922, 0.44299999999999995),
#  ('Comoros', 0.27399999999999997, 0.757, 0.505),
#  ('Madagascar', 0.27399999999999997, 0.9159999999999999, 0.555),
#  ('Lesotho', 0.489, 1.169, 0.168),
#  ('Burundi', 0.046, 0.447, 0.38),
#  ('Zimbabwe', 0.366, 1.114, 0.433),
#  ('Haiti', 0.32299999999999995, 0.688, 0.449),
#  ('Botswana', 1.041, 1.145, 0.5379999999999999),
#  ('Syria', 0.619, 0.37799999999999995, 0.44),
#  ('Malawi', 0.191, 0.56, 0.495),
#  ('Yemen', 0.287, 1.163, 0.46299999999999997),
#  ('Rwanda', 0.359, 0.711, 0.614),
#  ('Tanzania', 0.47600000000000003, 0.885, 0.499),
#  ('Afghanistan', 0.35, 0.517, 0.361),
#  ('Central African Republic', 0.026000000000000002, 0.0, 0.105),
#  ('South Sudan', 0.306, 0.575, 0.295)]
