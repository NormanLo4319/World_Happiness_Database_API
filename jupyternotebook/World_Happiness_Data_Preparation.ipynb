# %% [markdown]
# # World Happiness API Project
#
# ## Data Preparation Workflow:
#
# 1. Import Dataset from Local Machine
# 2. Manipulate Dataset
# 3. Save Data into SQLite Database File
#
# ### ETL Workflow:
#
# ![ETL](https://www.slideteam.net/media/catalog/product/cache/960x720/t/h/three_components_of_etl_process_flow_model_slide01.jpg)

# %%
# Import Dependencies
import pandas as pd
import random
import os
import csv
import requests
import json
import numpy as np

# %%
# Import data from csv file

happypath = os.path.join("..", "data", "happy.csv")
ginipath = os.path.join("..", "data", "gini.csv")
gdppath = os.path.join("..", "data", "pop.csv")
geopath = os.path.join("..", "data", "geo.csv")
happipath = os.path.join("..", "data", "happiness.csv")

happy_df = pd.read_csv(happypath)
gini_df = pd.read_csv(ginipath)
gdp_df = pd.read_csv(gdppath)
geo_df = pd.read_csv(geopath, encoding='latin-1')
happi_df = pd.read_csv(happipath)

# %%
happy_df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
# Create a loop to extract the most recent year data from each country.
country = []
year = []
happiness = []

for i in happy_df.index:
    if i < happy_df.shape[0]-1:
        if happy_df["Year"][i] < happy_df["Year"][i+1]:
            print(happy_df["Year"][i])
        else:
            country.append(happy_df["Country name"][i])
            year.append(happy_df["Year"][i])
            happiness.append(happy_df["Life Ladder"][i])
    else:
        break
# Out:
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2010
# 2011
# 2012
# 2014
# 2016
# 2017
# 2011
# 2012
# 2013
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2006
# 2008
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2013
# 2014
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2008
# 2009
# 2011
# 2014
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2010
# 2011
# 2016
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2009
# 2010
# 2011
# 2012
# 2008
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2009
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2008
# 2009
# 2010
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2006
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2005
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2009
# 2010
# 2011
# 2012
# 2014
# 2016
# 2005
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2008
# 2012
# 2013
# 2015
# 2016
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2006
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2009
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2011
# 2013
# 2014
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2011
# 2012
# 2017
# 2006
# 2007
# 2008
# 2009
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2006
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2011
# 2016
# 2007
# 2008
# 2010
# 2014
# 2015
# 2016
# 2017
# 2012
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2009
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2006
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2011
# 2014
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2010
# 2011
# 2012
# 2013
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2011
# 2015
# 2017
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2014
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2012
# 2013
# 2015
# 2016
# 2017
# 2012
# 2013
# 2014
# 2015
# 2016
# 2006
# 2008
# 2012
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2006
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2009
# 2010
# 2011
# 2012
# 2005
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2009
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2010
# 2011
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2014
# 2015
# 2009
# 2010
# 2011
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2014
# 2015
# 2016
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2017
# 2009
# 2010
# 2011
# 2012
# 2011
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2009
# 2012
# 2014
# 2015
# 2016
# 2017
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2006
# 2008
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2011
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2011
# 2013
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2009
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2005
# 2006
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2007
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017

# %%
# Create a new dataframe to hold the data from the loop

happiness_df = pd.DataFrame(list(zip(country, year, happiness)),
                           columns=["country", "year", "happiness"])
happiness_df["year"] = happiness_df["year"].astype(str)
happiness_df = happiness_df.rename(index=str, columns={"country":"country_name"})
happiness_df = happiness_df.round({"happiness": 3})
happiness_df.head()
# Out:
#   country_name  year  happiness
# 0  Afghanistan  2018      2.694
# 1      Albania  2018      5.004
# 2      Algeria  2018      5.043
# 3       Angola  2014      3.795
# 4    Argentina  2018      5.793

# %%
# Create a loop to extract the most recent year data from each country
country = []
country_code = []
year = []
gini = []

for i in gini_df.index:
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1995
# 1998
# 2002
# 2007
# 2010
# 2011
# 2012
# 2014
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 1984
# 1990
# 1998
# 2000
# 1996
# 2002
# 2008
# 2014
# 2003
# 1995
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1993
# 1998
# 2001
# 2005
# 2009
# 1992
# 1994
# 2005
# 2007
# 2011
# 1985
# 1992
# 1996
# 2003
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1987
# 1990
# 1996
# 1998
# 2001
# 2004
# 2005
# 2007
# 2010
# 2011
# 1979
# 1989
# 1991
# 1995
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1996
# 1990
# 1995
# 1997
# 1999
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1985
# 1988
# 1991
# 1994
# 1997
# 2000
# 2003
# 2006
# 2009
# 2012
# 1993
# 1996
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 1993
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1984
# 2000
# 2005
# 2010
# 2000
# 1991
# 1994
# 2001
# 2005
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2013
# 2003
# 1996
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1993
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2005
# 1993
# 1996
# 2000
# 2005
# 2008
# 2010
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1985
# 1990
# 1995
# 2002
# 2006
# 2009
# 2012
# 1995
# 1994
# 2000
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 1999
# 2003
# 2004
# 2007
# 2009
# 1991
# 2000
# 2007
# 1981
# 1988
# 1990
# 1992
# 1994
# 1996
# 1998
# 1999
# 2000
# 2002
# 2004
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2001
# 2007
# 2006
# 2011
# 2001
# 1988
# 1985
# 1990
# 1995
# 2000
# 2005
# 1987
# 1994
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1998
# 1989
# 1992
# 1996
# 1999
# 2002
# 2005
# 2009
# 1995
# 1996
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 1979
# 1986
# 1991
# 1994
# 1997
# 2000
# 2004
# 2007
# 2010
# 2013
# 1981
# 1989
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 1998
# 2000
# 2002
# 2003
# 1981
# 1987
# 1989
# 1992
# 1995
# 1998
# 1999
# 2001
# 2002
# 2003
# 2004
# 2005
# 1992
# 1998
# 2002
# 2004
# 2006
# 2008
# 2010
# 2012
# 2004
# 2005
# 2006
# 2007
# 2009
# 2010
# 1998
# 2005
# 1991
# 1993
# 1996
# 1998
# 2002
# 2004
# 2006
# 2010

# %%
# Create a new dataframe to hold the data from the loop
dict = {"country_name":country, "code":country_code, "gyear":year, "gini":gini}
gini_index_df = pd.DataFrame(dict)

# %%
gini_index_df["gyear"] = gini_index_df["gyear"].astype(str)
gini_index_df.head()
# Out:
#   country_name code gyear  gini
# 0      Albania  ALB  2012  29.0
# 1      Algeria  DZA  2011  27.6
# 2       Angola  AGO  2008  42.7
# 3    Argentina  ARG  2016  42.4
# 4      Armenia  ARM  2016  32.5

# %%
# Check column names in gdp_df
list(gdp_df.columns.values)
# Out:
# ['iso3c',
#  'region_id',
#  'country_name',
#  'income_id',
#  'gdp',
#  'composition_food_organic_waste_percent',
#  'composition_glass_percent',
#  'composition_metal_percent',
#  'composition_other_percent',
#  'composition_paper_cardboard_percent',
#  'composition_plastic_percent',
#  'composition_rubber_leather_percent',
#  'composition_wood_percent',
#  'composition_yard_garden_green_waste_percent',
#  'other_information_information_system_for_solid_waste_management',
#  'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
#  'other_information_national_law_governing_solid_waste_management_in_the_country',
#  'other_information_ppp_rules_and_regulations',
#  'other_information_summary_of_key_solid_waste_information_made_available_to_the_public',
#  'population_population_number_of_people',
#  'special_waste_agricultural_waste_tons_year',
#  'special_waste_construction_and_demolition_waste_tons_year',
#  'special_waste_e_waste_tons_year',
#  'special_waste_hazardous_waste_tons_year',
#  'special_waste_industrial_waste_tons_year',
#  'special_waste_medical_waste_tons_year',
#  'total_msw_total_msw_generated_tons_year',
#  'waste_collection_coverage_rural_percent_of_geographic_area',
#  'waste_collection_coverage_rural_percent_of_households',
#  'waste_collection_coverage_rural_percent_of_population',
#  'waste_collection_coverage_rural_percent_of_waste',
#  'waste_collection_coverage_total_percent_of_geographic_area',
#  'waste_collection_coverage_total_percent_of_households',
#  'waste_collection_coverage_total_percent_of_population',
#  'waste_collection_coverage_total_percent_of_waste',
#  'waste_collection_coverage_urban_percent_of_geographic_area',
#  'waste_collection_coverage_urban_percent_of_households',
#  'waste_collection_coverage_urban_percent_of_population',
#  'waste_collection_coverage_urban_percent_of_waste',
#  'waste_treatment_anaerobic_digestion_percent',
#  'waste_treatment_compost_percent',
#  'waste_treatment_controlled_landfill_percent',
#  'waste_treatment_incineration_percent',
#  'waste_treatment_landfill_unspecified_percent',
#  'waste_treatment_open_dump_percent',
#  'waste_treatment_other_percent',
#  'waste_treatment_recycling_percent',
#  'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
#  'waste_treatment_unaccounted_for_percent',
#  'waste_treatment_waterways_marine_percent',
#  'where_where_is_this_data_measured']

# %%
# Looop through the data and extract the data for the project
country = []
region_id = []
gdp = []
pop = []

for i in gdp_df.index:
    if i < gdp_df.shape[0]-1:
        if gdp_df["gdp"][i] == "NaN":
            print(gdp_df["country_name"][i])
        else:
            country.append(gdp_df["country_name"][i])
            region_id.append(gdp_df["region_id"][i])
            gdp.append(gdp_df["gdp"][i])
            pop.append(gdp_df["population_population_number_of_people"][i])
    else:
        break

# %%
print(len(country))
# Out:
# 216

# %%
# Create a new dataframe to hold the data
pop = {"country_name":country, "region_id":region_id, 
       "gdp":gdp, "population":pop}
demo_df = pd.DataFrame(pop)

# %%
demo_df.head()
# Out:
#   country_name region_id           gdp  population
# 0        Aruba       LCN           NaN    103187.0
# 1  Afghanistan       SAS  2.141361e+10  34656032.0
# 2       Angola       SSF  1.030420e+11  25096150.0
# 3      Albania       ECS  1.347108e+10   2880703.0
# 4      Andorra       ECS  3.319880e+09     82431.0

# %%
geo_df = geo_df.rename(index=str, columns={"name":"country_name"})
geo_df.head()
# Out:
#   country   latitude  longitude          country_name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla

# %%
print(gini_index_df["gyear"].dtype)
print(happiness_df["year"].dtype)
# Out:
# object
# object

# %%
# Merging the dataframes
joined_df = pd.merge(demo_df, geo_df, on='country_name', how='inner')

# %%
joined_df = pd.merge(joined_df, gini_index_df, on="country_name", how="inner")

# %%
joined_df = pd.merge(joined_df, happiness_df, on="country_name", how="inner")

# %%
joined_df["gdpPerCap"] = round(joined_df["gdp"] / joined_df["population"], 2)
joined_df.head()
# print(joined_df["gdpPerCap"].min())
# Out:
#   country_name region_id           gdp  population country   latitude  \
# 0       Angola       SSF  1.030420e+11  25096150.0      AO -11.202692
# 1      Albania       ECS  1.347108e+10   2880703.0      AL  41.153332
# 2    Argentina       LCN  4.475180e+11  42981515.0      AR -38.416097
# 3      Armenia       ECS  1.150200e+10   2906220.0      AM  40.069099
# 4    Australia       EAS  1.349300e+12  23789338.0      AU -25.274398
#
#     longitude code gyear  gini  year  happiness  gdpPerCap
# 0   17.873887  AGO  2008  42.7  2014      3.795    4105.89
# 1   20.168331  ALB  2012  29.0  2018      5.004    4676.32
# 2  -63.616672  ARG  2016  42.4  2018      5.793   10411.87
# 3   45.038189  ARM  2016  32.5  2018      5.062    3957.72
# 4  133.775136  AUS  2010  34.7  2018      7.177   56718.69

# %%
# Export the dataframe to CSV file
joined_df.to_csv("../outputs/joined_data.csv", index=False, header=True)

# %%
joined_df.groupby('region_id')['country_name'].nunique()
# Out:
# region_id
# EAS     9
# ECS    43
# LCN    20
# MEA     9
# NAC     2
# SAS     5
# SSF    32
# Name: country_name, dtype: int64

# %%
joined_df.groupby('region_id')[['gini', 'happiness']].mean()
# Out:
#                 gini  happiness
# region_id
# EAS        37.755556   5.713667
# ECS        30.795349   6.277070
# LCN        46.225000   6.016200
# MEA        34.844444   5.239444
# NAC        37.750000   7.029000
# SAS        34.900000   4.872600
# SSF        43.468750   4.423344

# %%
joined_df.groupby("region_id")[["population", "gdp"]].sum()
# Out:
#              population           gdp
# region_id
# EAS        2.074071e+09  1.915634e+13
# ECS        7.112615e+08  2.100068e+13
# LCN        5.752082e+08  5.281536e+12
# MEA        1.457586e+08  9.468386e+11
# NAC        3.541080e+08  1.874830e+13
# SAS        3.998003e+08  4.976364e+11
# SSF        6.883020e+08  1.489419e+12

# %%
happi_df.head()
list(happi_df)
# Out:
# ['Country',
#  'Happiness score',
#  'Whisker-high',
#  'Whisker-low',
#  'Dystopia (1.88) + residual',
#  'Explained by: GDP per capita',
#  'Explained by: Social support',
#  'Explained by: Healthy life expectancy',
#  'Explained by: Freedom to make life choices',
#  'Explained by: Generosity',
#  'Explained by: Perceptions of corruption']

# %%
happy_df = pd.merge(happiness_df, geo_df, on='country_name', how='inner')
print(len(happy_df))
print(happy_df.head())
# Out:
# 154
#   country_name  year  happiness country   latitude  longitude
# 0  Afghanistan  2018      2.694      AF  33.939110  67.709953
# 1      Albania  2018      5.004      AL  41.153332  20.168331
# 2      Algeria  2018      5.043      DZ  28.033886   1.659626
# 3       Angola  2014      3.795      AO -11.202692  17.873887
# 4    Argentina  2018      5.793      AR -38.416097 -63.616672

# %%
# Export the dataframe and save it as a CSV file for later use
happy_df.to_csv("../outputs/happy.csv", index=False, header=True)

# %%
gini_df = pd.merge(gini_index_df, geo_df, on='country_name', how='inner')
print(len(gini_df))
# Out:
# 133

# %%
# Save data as CSV file for later use
gini_df.to_csv("../outputs/gini.csv", index=False, header=True)

# %%
demo_df = pd.merge(demo_df, geo_df, on='country_name', how='inner')
print(len(demo_df))
# Out:
# 182

# %%
# Save it as CSV file for later use
demo_df.to_csv("../outputs/demographic.csv", index=False, header=True)

# %%
# Creating SQLite Database
from sqlalchemy import create_engine, Column, Integer, String, Float, Text
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import Session
Base = declarative_base()

# %%
# Define the happiness table
class Happiness(Base):
    __tablename__ = "happiness"
    id =Column(Integer, primary_key=True)
    country = Column(String)
    year = Column(Text)
    happiness = Column(Float)
    lat = Column(Float)
    lon = Column(Float)

# %%
# Table only exists in python and not in the actual database yet
Base.metadata.tables
# Out:
# FacadeDict({'happiness': Table('happiness', MetaData(), Column('id', Integer(), table=<happiness>, primary_key=True, nullable=False), Column('country', String(), table=<happiness>), Column('year', Text(), table=<happiness>), Column('happiness', Float(), table=<happiness>), Column('lat', Float(), table=<happiness>), Column('lon', Float(), table=<happiness>), schema=None)})

# %%
# Create the database engine
engine = create_engine("sqlite:///../db/data.sqlite")

# %%
# This is where the tables was created in the database
Base.metadata.create_all(engine)

# %%
# The ORM's "handle" to the database is the Session
session = Session(engine)

# %%
# Adding the data to the session

for i in happy_df.index:
    session.add(Happiness(
        country = happy_df["country_name"][i], 
        year = happy_df["year"][i],
        happiness = happy_df["happiness"][i],
        lat = happy_df["latitude"][i],
        lon = happy_df["longitude"][i]
    ))

# %%
# Data has not been added to the database yet
engine.execute("SELECT * FROM Happiness").fetchall()
# Out:
# []

# %%
# Use the new attribute to see the queue of data ready to go into the database
session.new
# Out:
# IdentitySet([<__main__.Happiness object at 0x7ffea53dbd60>, <__main__.Happiness object at 0x7ffea53dbe50>, <__main__.Happiness object at 0x7ffea53dbf10>, <__main__.Happiness object at 0x7ffea53dbc10>, <__main__.Happiness object at 0x7ffea53dbfa0>, <__main__.Happiness object at 0x7ffea53db940>, <__main__.Happiness object at 0x7ffea53db520>, <__main__.Happiness object at 0x7ffea53db400>, <__main__.Happiness object at 0x7ffea53e9070>, <__main__.Happiness object at 0x7ffea53e90d0>, <__main__.Happiness object at 0x7ffea53e9130>, <__main__.Happiness object at 0x7ffea53e9190>, <__main__.Happiness object at 0x7ffea53e91f0>, <__main__.Happiness object at 0x7ffea53e9250>, <__main__.Happiness object at 0x7ffea53e92b0>, <__main__.Happiness object at 0x7ffea53e9310>, <__main__.Happiness object at 0x7ffea53e9370>, <__main__.Happiness object at 0x7ffea53e93d0>, <__main__.Happiness object at 0x7ffea53e9430>, <__main__.Happiness object at 0x7ffea53e9490>, <__main__.Happiness object at 0x7ffea53e94f0>, <__main__.Happiness object at 0x7ffea53e9550>, <__main__.Happiness object at 0x7ffea53e95b0>, <__main__.Happiness object at 0x7ffea53e9610>, <__main__.Happiness object at 0x7ffea53e9670>, <__main__.Happiness object at 0x7ffea53e96d0>, <__main__.
# IdentitySet([])

# %%
# Query the database to check the data
session.query(Happiness.country, Happiness.lat, Happiness.happiness).all()
# Out:
# [('Afghanistan', 33.93911, 2.694),
#  ('Albania', 41.153332, 5.004),
#  ('Algeria', 28.033886, 5.043),
#  ('Angola', -11.202692, 3.795),
#  ('Argentina', -38.416097, 5.793),
#  ('Armenia', 40.069099, 5.062),
#  ('Australia', -25.274398, 7.177),
#  ('Austria', 47.516231, 7.396),
#  ('Azerbaijan', 40.143105, 5.168),
#  ('Bahrain', 25.930414, 6.227),
#  ('Bangladesh', 23.684994, 4.499),
#  ('Belarus', 53.709807, 5.234),
#  ('Belgium', 50.503887, 6.892),
#  ('Belize', 17.189877, 5.956),
#  ('Benin', 9.30769, 5.82),
#  ('Bhutan', 27.514162, 5.082),
#  ('Bolivia', -16.290154, 5.916),
#  ('Bosnia and Herzegovina', 43.915886, 5.887),
#  ('Botswana', -22.328474, 3.461),
#  ('Brazil', -14.235004, 6.191),
#  ('Bulgaria', 42.733883, 5.099),
#  ('Burkina Faso', 12.238333, 4.927),
#  ('Burundi', -3.373056, 3.775),
#  ('Cambodia', 12.565679, 5.122),
#  ('Cameroon', 7.369722, 5.251),
#  ('Canada', 56.130366, 7.175),
#  ('Central African Republic', 6.611111, 3.476),
#  ('Chad', 15.454166, 4.486),
#  ('Chile', -35.675147, 6.436),
#  ('China', 35.86166, 5.131),
#  ('Colombia', 4.570868, 5.984),
#  ('Comoros', -11.875001, 3.973),
#  ('Costa Rica', 9.748917, 7.141),
#  ('Croatia', 45.1, 5.536),
#  ('Cuba', 21.521757, 5.418),
#  ('Cyprus', 35.126413, 6.276),
#  ('Czech Republic', 49.817492, 7.034),
#  ('Denmark', 56.26392, 7.649),
#  ('Djibouti', 11.825138, 4.369),
#  ('Dominican Republic', 18.735693, 5.433),
#  ('Ecuador', -1.831239, 6.128),
#  ('Egypt', 26.820553, 4.005),
#  ('El Salvador', 13.794185, 6.276),
#  ('Estonia', 58.595272, 6.091),
#  ('Ethiopia', 9.145, 4.379),
#  ('Finland', 61.92411, 7.858),
#  ('France', 46.227638, 6.666),
#  ('Gabon', -0.803689, 4.783),
#  ('Gambia', 13.443182, 4.922),
#  ('Georgia', 42.315407, 4.659),
#  ('Germany', 51.165691, 7.118),
#  ('Ghana', 7.946527, 5.481),
#  ('Greece', 39.074208, 5.409),
#  ('Guatemala', 15.783471, 6.627),
#  ('Guinea', 9.945587, 5.252),
#  ('Guyana', 4.860416, 5.993),
#  ('Haiti', 18.971187, 3.615),
#  ('Honduras', 15.199999, 5.908),
#  ('Hungary', 47.162494, 6.065),
#  ('Iceland', 64.963051, 7.476),
#  ('India', 20.593684, 3.818),
#  ('Indonesia', -0.789275, 5.34),
#  ('Iran', 32.427908, 4.278),
#  ('Iraq', 33.223191, 4.462),
#  ('Ireland', 53.41291, 6.962),
#  ('Israel', 31.046051, 6.927),
#  ('Italy', 41.87194, 6.517),
#  ('Jamaica', 18.109581, 5.89),
#  ('Japan', 36.204824, 5.794),
#  ('Jordan', 30.585164, 4.639),
#  ('Kazakhstan', 48.019573, 6.008),
#  ('Kenya', -0.023559, 4.656),
#  ('Kosovo', 42.602636, 6.392),
#  ('Kuwait', 29.31166, 6.094),
#  ('Kyrgyzstan', 41.20438, 5.297),
#  ('Laos', 19.85627, 4.859),
#  ('Latvia', 56.879635, 5.901),
#  ('Lebanon', 33.854721, 5.167),
#  ('Lesotho', -29.609988, 3.795),
#  ('Liberia', 6.428055, 4.135),
#  ('Libya', 26.3351, 5.494),
#  ('Lithuania', 55.169438, 6.309),
#  ('Luxembourg', 49.815273, 7.243),
#  ('Madagascar', -18.766947, 4.071),
#  ('Malawi', -13.254308, 3.335),
#  ('Malaysia', 4.210484, 5.339),
#  ('Mali', 17.570692, 4.416),
#  ('Malta', 35.937496, 6.91),
#  ('Mauritania', 21.00789, 4.314),
#  ('Mauritius', -20.348404, 5.882),
#  ('Mexico', 23.634501, 6.55),
#  ('Moldova', 47.411631, 5.682),
#  ('Mongolia', 46.862496, 5.465),
#  ('Montenegro', 42.708678, 5.65),
#  ('Morocco', 31.791702, 4.897),
#  ('Mozambique', -18.665695, 4.654),
#  ('Namibia', -22.95764, 4.834),
#  ('Nepal', 28.394857, 4.91),
#  ('Netherlands', 52.132633, 7.463),
#  ('New Zealand', -40.900557, 7.37),
#  ('Nicaragua', 12.865416, 5.819),
#  ('Niger', 17.607789, 5.164),
#  ('Nigeria', 9.081999, 5.252),
#  ('Norway', 60.472024, 7.444),
#  ('Oman', 21.512583, 6.853),
#  ('Pakistan', 30.375321, 5.472),
#  ('Palestinian Territories', 31.952162, 4.554),
#  ('Panama', 8.537981, 6.281),
#  ('Paraguay', -23.442503, 5.713),
#  ('Peru', -9.189967, 5.68),
#  ('Philippines', 12.879721, 5.869),
#  ('Poland', 51.919438, 6.201),
#  ('Portugal', 39.399872, 5.92),
#  ('Qatar', 25.354826, 6.375),
#  ('Romania', 45.943161, 6.151),
#  ('Russia', 61.52401, 5.514),
#  ('Rwanda', -1.940278, 3.561),
#  ('Saudi Arabia', 23.885942, 6.356),
#  ('Senegal', 14.497401, 4.769),
#  ('Serbia', 44.016521, 5.936),
#  ('Sierra Leone', 8.460555, 4.306),
#  ('Singapore', 1.352083, 6.375),
#  ('Slovakia', 48.669026, 6.235),
#  ('Slovenia', 46.151241, 6.249),
#  ('Somalia', 5.152149, 4.668),
#  ('South Africa', -30.559482, 4.884),
#  ('South Korea', 35.907757, 5.84),
#  ('Spain', 40.463667, 6.513),
#  ('Sri Lanka', 7.873054, 4.4),
#  ('Sudan', 12.862807, 4.139),
#  ('Suriname', 3.919305, 6.269),
#  ('Swaziland', -26.522503, 4.212),
#  ('Sweden', 60.128161, 7.375),
#  ('Switzerland', 46.818188, 7.509),
#  ('Syria', 34.802075, 3.462),
#  ('Tajikistan', 38.861034, 5.829),
#  ('Tanzania', -6.369028, 3.445),
#  ('Thailand', 15.870032, 6.012),
#  ('Togo', 8.619543, 4.023),
#  ('Trinidad and Tobago', 10.691803, 6.192),
#  ('Tunisia', 33.886917, 4.741),
#  ('Turkey', 38.963745, 5.186),
#  ('Turkmenistan', 38.969719, 4.621),
#  ('Uganda', 1.373333, 4.322),
#  ('Ukraine', 48.379433, 4.662),
#  ('United Arab Emirates', 23.424076, 6.604),
#  ('United Kingdom', 55.378051, 7.233),
#  ('United States', 37.09024, 6.883),
#  ('Uruguay', -32.522779, 6.372),
#  ('Uzbekistan', 41.377491, 6.205),
#  ('Venezuela', 6.42375, 5.006),
#  ('Vietnam', 14.058324, 5.296),
#  ('Yemen', 15.552727, 3.058),
#  ('Zambia', -13.133897, 4.041)]

# %%
# Create a class for gini
class Gini(Base):
    __tablename__ = "gini"
    id =Column(Integer, primary_key=True)
    country = Column(String)
    country_code = Column(String)
    year = Column(Text)
    gini = Column(Float)
    lat = Column(Float)
    lon = Column(Float)

# %%
Base.metadata.tables
# Out:
# FacadeDict({'happiness': Table('happiness', MetaData(), Column('id', Integer(), table=<happiness>, primary_key=True, nullable=False), Column('country', String(), table=<happiness>), Column('year', Text(), table=<happiness>), Column('happiness', Float(), table=<happiness>), Column('lat', Float(), table=<happiness>), Column('lon', Float(), table=<happiness>), schema=None), 'gini': Table('gini', MetaData(), Column('id', Integer(), table=<gini>, primary_key=True, nullable=False), Column('country', String(), table=<gini>), Column('country_code', String(), table=<gini>), Column('year', Text(), table=<gini>), Column('gini', Float(), table=<gini>), Column('lat', Float(), table=<gini>), Column('lon', Float(), table=<gini>), schema=None)})

# %%
engine = create_engine("sqlite:///../db/data.sqlite")

# %%
Base.metadata.create_all(engine)

# %%
session = Session(engine)

# %%
for i in gini_df.index:
    session.add(Gini(
        country = gini_df["country_name"][i], 
        country_code = gini_df["code"][i],
        year = gini_df["gyear"][i],
        gini = gini_df["gini"][i],
        lat = gini_df["latitude"][i],
        lon = gini_df["longitude"][i]
    ))

# %%
engine.execute("SELECT * FROM Gini").fetchall()
# Out:
# []

# %%
session.new
# Out:
# IdentitySet([<__main__.Gini object at 0x7ffea545f790>, <__main__.Gini object at 0x7ffea545f9d0>, <__main__.Gini object at 0x7ffea545f970>, <__main__.Gini object at 0x7ffea545faf0>, <__main__.Gini object at 0x7ffea545fb50>, <__main__.Gini object at 0x7ffea545fbb0>, <__main__.Gini object at 0x7ffea545fc10>, <__main__.Gini object at 0x7ffea545fc70>, <__main__.Gini object at 0x7ffea545fcd0>, <__main__.Gini object at 0x7ffea545fd30>, <__main__.Gini object at 0x7ffea545fd90>, <__main__.Gini object at 0x7ffea545fdf0>, <__main__.Gini object at 0x7ffea545fe50>, <__main__.Gini object at 0x7ffea545feb0>, <__main__.Gini object at 0x7ffea545ff10>, <__main__.Gini object at 0x7ffea545ff70>, <__main__.Gini object at 0x7ffea545ffd0>, <__main__.Gini object at 0x7ffea5466070>, <__main__.Gini object at 0x7ffea54660d0>, <__main__.Gini object at 0x7ffea5466130>, <__main__.Gini object at 0x7ffea5466190>, <__main__.Gini object at 0x7ffea54661
# %%
session.commit()

# %%
session.new
# Out:
# IdentitySet([])

# %%
session.query(Gini.country, Gini.country_code, Gini.year, Gini.gini).all()
# Out:
# [('Albania', 'ALB', '2012', 29.0),
#  ('Algeria', 'DZA', '2011', 27.6),
#  ('Angola', 'AGO', '2008', 42.7),
#  ('Argentina', 'ARG', '2016', 42.4),
#  ('Armenia', 'ARM', '2016', 32.5),
#  ('Australia', 'AUS', '2010', 34.7),
#  ('Austria', 'AUT', '2015', 30.5),
#  ('Azerbaijan', 'AZE', '2005', 16.6),
#  ('Bangladesh', 'BGD', '2016', 32.4),
#  ('Belarus', 'BLR', '2016', 27.0),
#  ('Belgium', 'BEL', '2015', 27.7),
#  ('Benin', 'BEN', '2015', 47.8),
#  ('Bhutan', 'BTN', '2012', 38.8),
#  ('Bolivia', 'BOL', '2016', 44.6),
#  ('Bosnia and Herzegovina', 'BIH', '2015', 32.7),
#  ('Botswana', 'BWA', '2009', 60.5),
#  ('Brazil', 'BRA', '2015', 51.3),
#  ('Bulgaria', 'BGR', '2014', 37.4),
#  ('Burkina Faso', 'BFA', '2014', 35.3),
#  ('Burundi', 'BDI', '2013', 38.6),
#  ('Cameroon', 'CMR', '2014', 46.6),
#  ('Canada', 'CAN', '2013', 34.0),
#  ('Central African Republic', 'CAF', '2008', 56.2),
#  ('Chad', 'TCD', '2011', 43.3),
#  ('Chile', 'CHL', '2015', 47.7),
#  ('China', 'CHN', '2012', 42.2),
#  ('Colombia', 'COL', '2016', 50.8),
#  ('Comoros', 'COM', '2013', 45.3),
#  ('Costa Rica', 'CRI', '2016', 48.7),
#  ('Croatia', 'HRV', '2015', 30.8),
#  ('Cyprus', 'CYP', '2015', 34.0),
#  ('Czech Republic', 'CZE', '2015', 25.9),
#  ('Denmark', 'DNK', '2015', 28.2),
#  ('Djibouti', 'DJI', '2013', 44.1),
#  ('Dominican Republic', 'DOM', '2016', 45.3),
#  ('Ecuador', 'ECU', '2016', 45.0),
#  ('El Salvador', 'SLV', '2016', 40.0),
#  ('Estonia', 'EST', '2015', 32.7),
#  ('Ethiopia', 'ETH', '2015', 39.1),
#  ('Fiji', 'FJI', '2013', 36.4),
#  ('Finland', 'FIN', '2015', 27.1),
#  ('France', 'FRA', '2015', 32.7),
#  ('Gabon', 'GAB', '2005', 42.2),
#  ('Georgia', 'GEO', '2016', 36.5),
#  ('Germany', 'DEU', '2015', 31.7),
#  ('Ghana', 'GHA', '2012', 42.4),
#  ('Greece', 'GRC', '2015', 36.0),
#  ('Guatemala', 'GTM', '2014', 48.3),
#  ('Guinea', 'GIN', '2012', 33.7),
#  ('Guinea-Bissau', 'GNB', '2010', 50.7),
#  ('Haiti', 'HTI', '2012', 41.1),
#  ('Honduras', 'HND', '2016', 50.0),
#  ('Hungary', 'HUN', '2015', 30.4),
#  ('Iceland', 'ISL', '2014', 25.6),
#  ('Indonesia', 'IDN', '2013', 39.5),
#  ('Iraq', 'IRQ', '2012', 29.5),
#  ('Ireland', 'IRL', '2014', 31.9),
#  ('Israel', 'ISR', '2012', 41.4),
#  ('Italy', 'ITA', '2014', 34.7),
#  ('Japan', 'JPN', '2008', 32.1),
#  ('Jordan', 'JOR', '2010', 33.7),
#  ('Kazakhstan', 'KAZ', '2015', 26.9),
#  ('Kiribati', 'KIR', '2006', 37.0),
#  ('Kosovo', 'XKX', '2015', 26.4),
#  ('Latvia', 'LVA', '2015', 34.2),
#  ('Lebanon', 'LBN', '2011', 31.8),
#  ('Lesotho', 'LSO', '2010', 54.2),
#  ('Liberia', 'LBR', '2014', 33.2),
#  ('Lithuania', 'LTU', '2015', 37.4),
#  ('Luxembourg', 'LUX', '2014', 31.2),
#  ('Madagascar', 'MDG', '2012', 42.6),
#  ('Malawi', 'MWI', '2010', 45.5),
#  ('Malaysia', 'MYS', '2009', 46.3),
#  ('Maldives', 'MDV', '2009', 38.4),
#  ('Mali', 'MLI', '2009', 33.0),
#  ('Malta', 'MLT', '2014', 29.0),
#  ('Mauritania', 'MRT', '2014', 32.6),
#  ('Mauritius', 'MUS', '2012', 35.8),
#  ('Mexico', 'MEX', '2016', 43.4),
#  ('Moldova', 'MDA', '2016', 26.3),
#  ('Mongolia', 'MNG', '2016', 32.3),
#  ('Montenegro', 'MNE', '2014', 31.9),
#  ('Morocco', 'MAR', '2006', 40.7),
#  ('Namibia', 'NAM', '2009', 61.0),
#  ('Nepal', 'NPL', '2010', 32.8),
#  ('Netherlands', 'NLD', '2015', 29.3),
#  ('Nicaragua', 'NIC', '2014', 46.2),
#  ('Niger', 'NER', '2014', 34.3),
#  ('Nigeria', 'NGA', '2009', 43.0),
#  ('Norway', 'NOR', '2015', 27.5),
#  ('Pakistan', 'PAK', '2013', 30.7),
#  ('Panama', 'PAN', '2016', 50.4),
#  ('Papua New Guinea', 'PNG', '2009', 41.9),
#  ('Paraguay', 'PRY', '2016', 47.9),
#  ('Peru', 'PER', '2016', 43.8),
#  ('Philippines', 'PHL', '2015', 40.1),
#  ('Poland', 'POL', '2015', 31.8),
#  ('Portugal', 'PRT', '2015', 35.5),
#  ('Romania', 'ROU', '2016', 28.3),
#  ('Rwanda', 'RWA', '2013', 50.4),
#  ('Samoa', 'WSM', '2008', 42.0),
#  ('Senegal', 'SEN', '2011', 40.3),
#  ('Serbia', 'SRB', '2015', 28.5),
#  ('Seychelles', 'SYC', '2013', 46.8),
#  ('Sierra Leone', 'SLE', '2011', 34.0),
#  ('Slovenia', 'SVN', '2015', 25.4),
#  ('Solomon Islands', 'SLB', '2013', 37.1),
#  ('South Africa', 'ZAF', '2014', 63.0),
#  ('Spain', 'ESP', '2015', 36.2),
#  ('Sri Lanka', 'LKA', '2016', 39.8),
#  ('Sudan', 'SDN', '2009', 35.4),
#  ('Suriname', 'SUR', '1999', 57.6),
#  ('Swaziland', 'SWZ', '2009', 51.5),
#  ('Sweden', 'SWE', '2015', 29.2),
#  ('Switzerland', 'CHE', '2014', 32.5),
#  ('Tajikistan', 'TJK', '2015', 34.0),
#  ('Tanzania', 'TZA', '2011', 37.8),
#  ('Thailand', 'THA', '2013', 37.8),
#  ('Timor-Leste', 'TLS', '2014', 28.7),
#  ('Togo', 'TGO', '2015', 43.1),
#  ('Tonga', 'TON', '2009', 37.5),
#  ('Trinidad and Tobago', 'TTO', '1992', 40.3),
#  ('Tunisia', 'TUN', '2010', 35.8),
#  ('Turkey', 'TUR', '2016', 41.9),
#  ('Tuvalu', 'TUV', '2010', 39.1),
#  ('Uganda', 'UGA', '2012', 41.0),
#  ('Ukraine', 'UKR', '2016', 25.0),
#  ('United Kingdom', 'GBR', '2015', 33.2),
#  ('United States', 'USA', '2016', 41.5),
#  ('Uruguay', 'URY', '2016', 39.7),
#  ('Vanuatu', 'VUT', '2010', 37.6),
#  ('Vietnam', 'VNM', '2014', 34.8),
#  ('Zambia', 'ZMB', '2015', 57.1)]

# %%
# Create a class for demographic
class Demographic(Base):
    __tablename__ = "demographic"
    id =Column(Integer, primary_key=True)
    country = Column(String)
    region_id = Column(String)
    year = Column(Text)
    gdp = Column(Float)
    population = Column(Float)
    lat = Column(Float)
    lon = Column(Float)

# %%
Base.metadata.tables
# Out:
# FacadeDict({'happiness': Table('happiness', MetaData(), Column('id', Integer(), table=<happiness>, primary_key=True, nullable=False), Column('country', String(), table=<happiness>), Column('year', Text(), table=<happiness>), Column('happiness', Float(), table=<happiness>), Column('lat', Float(), table=<happiness>), Column('lon', Float(), table=<happiness>), schema=None), 'gini': Table('gini', MetaData(), Column('id', Integer(), table=<gini>, primary_key=True, nullable=False), Column('country', String(), table=<gini>), Column('country_code', String(), table=<gini>), Column('year', Text(), table=<gini>), Column('gini', Float(), table=<gini>), Column('lat', Float(), table=<gini>), Column('lon', Float(), table=<gini>), schema=None), 'demographic': Table('demographic', MetaData(), Column('id', Integer(), table=<demographic>, primary_key=True, nullable=False), Column('country', String(), table=<demographic>), Column('region_id', String(), table=<demographic>), Column('year', Text(), table=<demographic>), Column('gdp', Float(), table=<demographic>), Column('population', Float(), table=<demographic>), Column('lat', Float(), table=<demographic>), Column('lon', Float(), table=<demographic>), schema=None)})

# %%
engine = create_engine("sqlite:///../db/data.sqlite")

# %%
Base.metadata.create_all(engine)

# %%
session = Session(engine)

# %%
demo_df
# Out:
#      country_name region_id           gdp   population
# 0           Aruba       LCN           NaN    103187.00
# 1     Afghanistan       SAS  2.141361e+10  34656032.00
# 2          Angola       SSF  1.030420e+11  25096150.00
# 3         Albania       ECS  1.347108e+10   2880703.00
# 4         Andorra       ECS  3.319880e+09     82431.00
# ..            ...       ...           ...          ...
# 211         Samoa       EAS  7.380417e+08    187665.00
# 212        Kosovo       ECS  7.129272e+09   1801800.00
# 213   Yemen, Rep.       MEA  1.192703e+10  27584213.00
# 214  South Africa       SSF  4.212090e+11  51729345.36
# 215        Zambia       SSF  2.703717e+10  14264756.00
#
# [216 rows x 4 columns]

# %%
for i in demo_df.index:
    session.add(Demographic(
        country = demo_df["country_name"][i], 
        region_id = demo_df["region_id"][i],
        year = "2018",
        gdp = demo_df["gdp"][i],
        population = demo_df["population"][i],
    ))

# %%
engine.execute("SELECT * FROM Demographic").fetchall()
# Out:
# []

# %%
session.new
# Out:
# IdentitySet([<__main__.Demographic object at 0x7ffea54c73a0>, <__main__.Demographic object at 0x7ffea54c75b0>, <__main__.Demographic object at 0x7ffea54c7550>, <__main__.Demographic object at 0x7ffea54c77c0>, <__main__.Demographic object at 0x7ffea54c7a30>, <__main__.Demographic object at 0x7ffea54c79d0>, <__main__.Demographic object at 0x7ffea54c7af0>, <__main__.Demographic object at 0x7ffea54c7b50>, <__main__.Demographic object at 0x7ffea54c7bb0>, <__main__.Demographic object at 0x7ffea54c7c10>, <__main__.Demographic object at 0x7ffea54c7c40>, <__main__.Demographic object at 0x7ffea54c7ca0>, <__main__.Demographic object at 0x7ffea54c7d00>, <__main__.Demographic object at 0x7ffea54c7d60>, <__main__.Demographic object at 0x7ffea54c7dc0>, <__main__.Demographic object at 0x7ffea54c7e50>, <__main__.Demographic object at 0x7ffea54c7e80>, <__main__.Demographic object at 0x7ffea54c7ee0>, <__main__.Demographic object at 0x7ffea54c7f40>, <__main__.Demographic object at 0x7ffea54c7fa0>, <__main__.Demographic object at 0x7ffea54c7190>, <__main__.Demographic object at 0x7ffea54c7700>, <__main__.Demographic object at 0x7ffea54c7730>, <__main__.Demographic object at 0x7ffea56250a0>, <__main__.Demographic object at 0x7ffea5625100>, <__main__.Demographic object at 0x7ffea5625160>, <__main__.Demographic object at 0x7ffea56251c0>, <__main__.Demographic object at 0x7ffea5625220>, <__main__.Demographic object at 0x7ffea5625280>, <__main__.Demographic object at 0x7ffea5625310>, <__main__.Demographic object at 0x7ffea5625370>, <__main__.Demographic object at 0x7ffea56253d0>, <__main__.Demographic object at 0x7ffea5625430>, <__main__.Demographic object at 0x7ffea5625490>, <__main__.Demographic object at 0x7ffea56254c0>, <__main__.Demographic object at 0x7ffea5452d00>, <__main__.Demographic object at 0x7ffea53c09a0>, <__main__.Demographic object at 0x7ffea5625070>, <__main__.Demographic object at 0x7ffea56255b0>, <__main__.Demographic object at 0x7ffea5625640>, <__main__.Demographic object at 0x7ffea56256a0>, <__main__.Demographic object at 0x7ffea5625700>, <__main__.Demographic object at 0x7ffea5625760>, <__main__.Demographic object at 0x7ffea56257c0>, <__main__.Demographic object at 0x7ffea56257f0>, <__main__.Demographic object at 0x7ffea5625880>, <__main__.Demographic object at 0x7ffea56258e0>, <__main__.Demographic object at 0x7ffea5625940>, <__main__.Demographic object at 0x7ffea56259a0>, <__main__.Demographic object at 0x7ffea5625a00>, <__main__.Demographic object at 0x7ffea5625a60>, <__main__.Demographic object at 0x7ffea5625ac0>, <__main__.Demographic object at 0x7ffea5625b20>, <__main__.Demographic object at 0x7ffea5625ca0>, <__main__.Demographic object at 0x7ffea5625cd0>, <__main__.Demographic object at 0x7ffea5625d60>, <__main__.Demographic object at 0x7ffea5625dc0>, <__main__.Demographic object at 0x7ffea5625e20>, <__main__.Demographic object at 0x7ffea5625e80>, <__main__.Demographic object at 0x7ffea5625f10>, <__main__.Demographic object at 0x7ffea5625f40>, <__main__.Demographic object at 0x7ffea5625fa0>, <__main__.Demographic object at 0x7ffea5625eb0>, <__main__.Demographic object at 0x7ffea5630070>, <__main__.Demographic object at 0x7ffea56300d0>, <__main__.Demographic object at 0x7ffea5630130>, <__main__.Demographic object at 0x7ffea5630190>, <__main__.Demographic object at 0x7ffea56301f0>, <__main__.Demographic object at 0x7ffea5630250>, <__main__.Demographic object at 0x7ffea56302b0>, <__main__.Demographic object at 0x7ffea5630310>, <__main__.Demographic object at 0x7ffea5630370>, <__main__.Demographic object at 0x7ffea56303d0>, <__main__.Demographic object at 0x7ffea5630430>, <__main__.Demographic object at 0x7ffea5630490>, <__main__.Demographic object at 0x7ffea56304f0>, <__main__.Demographic object at 0x7ffea5630550>, <__main__.Demographic object at 0x7ffea56305b0>, <__main__.Demographic object at 0x7ffea5630610>, <__main__.Demographic object at 0x7ffea5630670>, <__main__.Demographic object at 0x7ffea56306d0>, <__main__.Demograp ...

# %%
session.commit()

# %%
session.new
# Out:
# IdentitySet([])

# %%
session.query(Demographic.country, Demographic.region_id, Demographic.lat, Demographic.gdp, Demographic.population).all()
# Out:
# [('Aruba', 'LCN', None, None, 103187.0),
#  ('Afghanistan', 'SAS', None, 21413614653.0, 34656032.0),
#  ('Angola', 'SSF', None, 103042000000.0, 25096150.0),
#  ('Albania', 'ECS', None, 13471082475.0, 2880703.0),
#  ('Andorra', 'ECS', None, 3319880351.0, 82431.0),
#  ('United Arab Emirates', 'MEA', None, 384222000000.0, 9269612.0),
#  ('Argentina', 'LCN', None, 447518000000.0, 42981515.0),
#  ('Armenia', 'ECS', None, 11501998666.0, 2906220.0),
#  ('American Samoa', 'EAS', None, 534555066.1, 55599.0),
#  ('Antigua and Barbuda', 'LCN', None, 1344373698.0, 96777.0),
#  ('Australia', 'EAS', None, 1349300000000.0, 23789338.0),
#  ('Austria', 'ECS', None, 420040000000.0, 8633169.0),
#  ('Azerbaijan', 'ECS', None, 57195531762.0, 9649341.0),
#  ('Burundi', 'SSF', None, 2297241392.0, 6741569.0),
#  ('Belgium', 'ECS', None, 515103000000.0, 11274196.0),
#  ('Benin', 'SSF', None, 9102277423.0, 5521763.0),
#  ('Burkina Faso', 'SSF', None, 12380518526.0, 18110624.0),
#  ('Bangladesh', 'SAS', None, 167771000000.0, 155727053.0),
#  ('Bulgaria', 'ECS', None, 56792405577.0, 7177991.0),
#  ('Bahrain', 'MEA', None, 31769062885.0, 1425171.0),
#  ('Bahamas, The', 'LCN', None, 10343803832.0, 386838.0),
#  ('Bosnia and Herzegovina', 'ECS', None, 18929698720.0, 3535961.0),
#  ('Belarus', 'ECS', None, 59187019676.0, 9489616.0),
#  ('Belize', 'LCN', None, 1602671549.0, 359288.0),
#  ('Bermuda', 'NAC', None, None, 64798.0),
#  ('Bolivia', 'LCN', None, 26758341469.0, 10724705.0),
#  ('Brazil', 'LCN', None, 2256910000000.0, 205962108.0),
#  ('Barbados', 'LCN', None, 4637855785.0, 280601.0),
#  ('Brunei Darussalam', 'EAS', None, 13301457675.0, 423196.0),
#  ('Bhutan', 'SAS', None, 2234759342.0, 686958.0),
#  ('Botswana', 'SSF', None, 16843294913.0, 2014866.0),
#  ('Central African Republic', 'SSF', None, 1496562092.0, 4515392.0),
#  ('Canada', 'NAC', None, 1828000000000.0, 35544564.0),
#  ('Switzerland', 'ECS', None, 642090000000.0, 8372098.0),
#  ('Channel Islands', 'ECS', None, None, 164541.0),
#  ('Chile', 'LCN', None, 267904000000.0, 16829442.0),
#  ('China', 'EAS', None, 9505160000000.0, 1370000000.0),
#  ('Côte d’Ivoire', 'SSF', None, 36796468787.0, 20401331.0),
#  ('Cameroon', 'SSF', None, 35051979601.0, 21655715.0),
#  ('Congo, Dem. Rep.', 'SSF', None, 32089998961.0, 78736153.0),
#  ('Congo, Rep.', 'SSF', None, 14205686708.0, 2648507.0),
#  ('Colombia', 'LCN', None, 366457000000.0, 46406646.0),
#  ('Comoros', 'SSF', None, 611370805.2, 777424.0),
#  ('Cabo Verde', 'SSF', None, 1860165515.0, 513979.0),
#  ('Costa Rica', 'LCN', None, 46551438317.0, 4757575.0),
#  ('Cuba', 'LCN', None, None, 11303687.0),
#  ('Curacao', 'LCN', None, None, 153822.0),
#  ('Cayman Islands', 'LCN', None, None, 59172.0),
#  ('Cyprus', 'ECS', None, 24311614955.0, 1160985.0),
#  ('Czech Republic', 'ECS', None, 231340000000.0, 10546059.0),
#  ('Germany', 'ECS', None, 3781700000000.0, 81686611.0),
#  ('Djibouti', 'MEA', None, None, 746221.0),
#  ('Dominica', 'LCN', None, 506021862.9, 72400.0),
#  ('Denmark', 'ECS', None, 347520000000.0, 5683483.0),
#  ('Dominican Republic', 'LCN', None, 73664129265.0, 10528394.0),
#  ('Algeria', 'MEA', None, 196035000000.0, 40606052.0),
#  ('Ecuador', 'LCN', None, 85056519293.0, 16144368.0),
#  ('Egypt, Arab Rep.', 'MEA', None, 260816000000.0, 87813257.0),
#  ('Eritrea', 'SSF', None, None, 4474690.0),
#  ('Spain', 'ECS', None, 1464510000000.0, 46447697.0),
#  ('Estonia', 'ECS', None, 23808677023.0, 1315407.0),
#  ('Ethiopia', 'SSF', None, 52347226230.0, 99873033.0),
#  ('Finland', 'ECS', None, 252692000000.0, 5479531.0),
#  ('Fiji', 'EAS', None, 3771168286.0, 867086.0),
#  ('France', 'ECS', None, 2806040000000.0, 66624068.0),
#  ('Faeroe Islands', 'ECS', None, None, 48842.0),
#  ('Micronesia, Fed. Sts.', 'EAS', None, 296282644.0, 104937.0),
#  ('Gabon', 'SSF', None, 18912467101.0, 1086137.0),
#  ('United Kingdom', 'ECS', None, 2757620000000.0, 65128861.0),
#  ('Georgia', 'ECS', None, 15189614351.0, 3717100.0),
#  ('Ghana', 'SSF', None, 48199090352.0, 21542009.0),
#  ('Gibraltar', 'ECS', None, None, 33623.0),
#  ('Guinea', 'SSF', None, 9667718427.0, 8132552.0),
#  ('Gambia, The', 'SSF', None, 1084318241.0, 1311349.0),
#  ('Guinea-Bissau', 'SSF', None, 1062488925.0, 1770526.0),
#  ('Equatorial Guinea', 'SSF', None, 15045964750.0, 1221490.0),
#  ('Greece', 'ECS', None, 244481000000.0, 10892413.0),
#  ('Grenada', 'LCN', None, 931118693.5, 105481.0),
#  ('Greenland', 'ECS', None, 2823634004.0, 56905.0),
#  ('Guatemala', 'LCN', None, 51421926688.0, 16252429.0),
#  ('Guam', 'EAS', None, 5214914976.0, 159973.0),
#  ('Guyana', 'LCN', None, 2925825406.0, 746556.0),
#  ('Hong Kong SAR, China', 'EAS', None, 270105000000.0, 7305700.0),
#  ('Honduras', 'LCN', None, 19545909275.0, 9112867.0),
#  ('Croatia', 'ECS', None, 61095271083.0, 4203604.0),
#  ('Haiti', 'LCN', None, 7911616492.0, 10847334.0),
#  ('Hungary', 'ECS', None, 147183000000.0, 9843028.0),
#  ('Indonesia', 'EAS', None, 1037860000000.0, 261115456.0),
#  ('Isle of Man', 'ECS', None, None, 80759.0),
#  ('India', 'SAS', None, 2466180000000.0, 1071477855.0),
#  ('Ireland', 'ECS', None, 332361000000.0, 4586897.0),
#  ('Iran, Islamic Rep.', 'MEA', None, 540581000000.0, 80277428.0),
#  ('Iraq', 'MEA', None, 213938000000.0, 36115649.0),
#  ('Iceland', 'ECS', None, 16434890343.0, 330815.0),
#  ('Israel', 'MEA', None, 287808000000.0, 8380100.0),
#  ('Italy', 'ECS', None, 2080640000000.0, 60730582.0),
#  ('Jamaica', 'LCN', None, 13801803130.0, 2881355.0),
#  ('Jordan', 'MEA', None, 30811666897.0, 8413464.0),
#  ('Japan', 'EAS', None, 6052670000000.0, 127000000.0),
#  ('Kazakhstan', 'ECS', None, 188309000000.0, 16791425.0),
#  ('Kenya', 'SSF', None, 55409230682.0, 41350152.0),
#  ('Kyrgyz Republic', 'ECS', None, 6346700788.0, 5956900.0),
#  ('Cambodia', 'EAS', None, 17009386902.0, 15270790.0),
#  ('Kiribati', 'EAS', None, 192869131.3, 114395.0),
#  ('St. Kitts and Nevis', 'LCN', None, 858344680.0, 54288.0),
#  ('Korea, Rep.', 'EAS', None, 1305950000000.0, 50746659.0),
#  ('Kuwait', 'MEA', None, 142857000000.0, 2998083.0),
#  ('Lao PDR', 'EAS', None, 11102149875.0, 6663967.0),
#  ('Lebanon', 'MEA', None, 42911390492.0, 5603279.0),
#  ('Liberia', 'SSF', None, 1627046588.0, 3512932.0),
#  ('Libya', 'MEA', None, 36808842591.0, 6193501.0),
#  ('St. Lucia', 'LCN', None, 1489854701.0, 177206.0),
#  ('Liechtenstein', 'ECS', None, None, 36545.0),
#  ('Sri Lanka', 'SAS', None, 79907042295.0, 21200000.0),
#  ('Lesotho', 'SSF', None, 2980616573.0, 1965662.0),
#  ('Lithuania', 'ECS', None, 45735444769.0, 2904910.0),
#  ('Luxembourg', 'ECS', None, 63207264513.0, 569604.0),
#  ('Latvia', 'ECS', None, 28871503534.0, 1977527.0),
#  ('Macao SAR, China', 'EAS', None, 31920853732.0, 612167.0),
#  ('St. Martin (French part)', 'LCN', None, None, 30959.0),
#  ('Morocco', 'MEA', None, 114784000000.0, 34318082.0),
#  ('Monaco', 'ECS', None, None, 37783.0),
#  ('Moldova', 'ECS', None, 7354798041.0, 3554108.0),
#  ('Madagascar', 'SSF', None, 10356200861.0, 24894551.0),
#  ('Maldives', 'SAS', None, 3600398618.0, 409163.0),
#  ('Mexico', 'LCN', None, 1259040000000.0, 125890949.0),
#  ('Marshall Islands', 'EAS', None, 179041793.9, 52793.0),
#  ('Macedonia, FYR', 'ECS', None, 10924716122.0, 2081206.0),
#  ('Mali', 'SSF', None, 13421822111.0, 16006670.0),
#  ('Malta', 'MEA', None, 11868476821.0, 431874.0),
#  ('Myanmar', 'EAS', None, 74469832820.0, 46095462.0),
#  ('Montenegro', 'ECS', None, 4662831376.0, 622159.0),
#  ('Mongolia', 'EAS', None, 11825367387.0, 3027398.0),
#  ('Northern Mariana Islands', 'EAS', None, 1051785360.0, 54036.0),
#  ('Mozambique', 'SSF', None, 14846071335.0, 27212382.0),
#  ('Mauritania', 'SSF', None, 5574151157.0, 3506288.0),
#  ('Mauritius', 'SSF', None, 12409842083.0, 1263473.0),
#  ('Malawi', 'SSF', None, 8710223822.0, 16577147.0),
#  ('Malaysia', 'EAS', None, 344052000000.0, 30228017.0),
#  ('Namibia', 'SSF', None, 14950179757.0, 1559983.0),
#  ('New Caledonia', 'EAS', None, None, 278000.0),
#  ('Niger', 'SSF', None, 8106889865.0, 8842415.0),
#  ('Nigeria', 'SSF', None, 456775000000.0, 154402181.0),
#  ('Nicaragua', 'LCN', None, 11955466051.0, 5737723.0),
#  ('Netherlands', 'ECS', None, 890136000000.0, 16939923.0),
#  ('Norway', 'ECS', None, 472766000000.0, 5188607.0),
#  ('Nepal', 'SAS', None, 19856634053.0, 28982771.0),
#  ('Nauru', 'EAS', None, 125930267.7, 13049.0),
#  ('New Zealand', 'EAS', None, 176129000000.0, 4692700.0),
#  ('Oman', 'MEA', None, 75054356307.0, 3960925.0),
#  ('Pakistan', 'SAS', None, 227867000000.0, 193203476.0),
#  ('Panama', 'LCN', None, 44789036003.0, 3969249.0),
#  ('Peru', 'LCN', None, 193653000000.0, 30973354.0),
#  ('Philippines', 'EAS', None, 284349000000.0, 103320222.0),
#  ('Palau', 'EAS', None, 225308048.6, 21503.0),
#  ('Papua New Guinea', 'EAS', None, 19389192291.0, 7755785.0),
#  ('Poland', 'ECS', None, 572132000000.0, 37986412.0),
#  ('Puerto Rico', 'LCN', None, 93028633826.0, 3473181.0),
#  ('Portugal', 'ECS', None, 231745000000.0, 10401062.0),
#  ('Paraguay', 'LCN', None, 26400622643.0, 6639119.0),
#  ('West Bank and Gaza', 'MEA', None, 11767216976.0, 4046901.0),
#  ('French Polynesia', 'EAS', None, None, 273528.0),
#  ('Qatar', 'MEA', None, 170663000000.0, 2109568.0),
#  ('Romania', 'ECS', None, 200217000000.0, 19815481.0),
#  ('Russian Federation', 'ECS', None, 1654430000000.0, 143201676.0),
#  ('Rwanda', 'SSF', None, 8805014649.0, 11917508.0),
#  ('Saudi Arabia', 'MEA', None, 690000000000.0, 31557144.0),
#  ('Sudan', 'SSF', None, 76149479953.0, 38647803.0),
#  ('Senegal', 'SSF', None, 16833353304.0, 15411614.0),
#  ('Singapore', 'EAS', None, 299170000000.0, 5607283.0),
#  ('Solomon Islands', 'EAS', None, 900859048.9, 563513.0),
#  ('Sierra Leone', 'SSF', None, 3355384560.0, 5439695.0),
#  ('El Salvador', 'LCN', None, 21588556542.0, 6164626.0),
#  ('San Marino', 'ECS', None, 1746352442.0, 33203.0),
#  ('Somalia', 'SSF', None, None, 14317996.0),
#  ('Serbia', 'ECS', None, 41308012850.0, 7095383.0),
#  ('South Sudan', 'SSF', None, None, 11177490.0),
#  ('São Tomé and Príncipe', 'SSF', None, 256822056.3, 191266.0),
#  ('Suriname', 'LCN', None, 4527379879.0, 526103.0),
#  ('Slovak Republic', 'ECS', None, 104679000000.0, 5423801.0),
#  ('Slovenia', 'ECS', None, 50511749002.0, 2063531.0),
#  ('Sweden', 'ECS', None, 560387000000.0, 9799186.0),
#  ('Eswatini', 'SSF', None, 5246492516.0, 1343098.0),
#  ('Sint Maarten (Dutch part)', 'LCN', None, None, 37685.0),
#  ('Seychelles', 'SSF', None, 1287449683.0, 88303.0),
#  ('Syrian Arab Republic', 'MEA', None, None, 20824893.0),
#  ('Turks and Caicos Islands', 'LCN', None, None, 34900.0),
#  ('Chad', 'SSF', None, 12642608725.0, 11887202.0),
#  ('Togo', 'SSF', None, 4264876064.0, 7228915.0),
#  ('Thailand', 'EAS', None, 407015000000.0, 68657600.0),
#  ('Tajikistan', 'ECS', None, 8458800788.0, 8177809.0),
#  ('Turkmenistan', 'ECS', None, 39563379206.0, 5366277.0),
#  ('Timor-Leste', 'EAS', None, 3765074847.0, 1268671.0),
#  ('Tonga', 'EAS', None, 406237705.3, 104951.0),
#  ('Trinidad and Tobago', 'LCN', None, 21519942195.0, 1328100.0),
#  ('Tunisia', 'MEA', None, 48682059522.0, 11143908.0),
#  ('Turkey', 'ECS', None, 1122510000000.0, 78271472.0),
#  ('Tuvalu', 'EAS', None, 39216157.28, 11097.0),
#  (None, 'EAS', None, None, 23400000.0),
#  ('Tanzania', 'SSF', None, 46775259596.0, 49082997.0),
#  ('Uganda', 'SSF', None, 27483055272.0, 35093648.0),
#  ('Ukraine', 'ECS', None, 124000000000.0, 45004645.0),
#  ('Uruguay', 'LCN', None, 48362932954.0, 3431552.0),
#  ('United States', 'NAC', None, 16920300000000.0, 318563456.0),
#  ('Uzbekistan', 'ECS', None, 62469088152.0, 29774500.0),
#  ('St. Vincent and the Grenadines', 'LCN', None, 729264939.6, 109455.0),
#  ('Venezuela, RB', 'LCN', None, None, 29893080.0),
#  ('British Virgin Islands', 'LCN', None, None, 20645.0),
#  ('Virgin Islands (U.S.)', 'LCN', None, None, 105784.0),
#  ('Vietnam', 'EAS', None, 164105000000.0, 86932500.0),
#  ('Vanuatu', 'EAS', None, 777052317.5, 270402.0),
#  ('Samoa', 'EAS', None, 738041747.0, 187665.0),
#  ('Kosovo', 'ECS', None, 7129271792.0, 1801800.0),
#  ('Yemen, Rep.', 'MEA', None, 11927030389.0, 27584213.0),
#  ('South Africa', 'SSF', None, 421209000000.0, 51729345.36),
#  ('Zambia', 'SSF', None, 27037168289.0, 14264756.0)]

# %%
# Define the happiness table
class Geo(Base):
    __tablename__ = "geo"
    id =Column(Integer, primary_key=True)
    country = Column(String)
    lat = Column(Float)
    lon = Column(Float)
    init = Column(String)

# %%
Base.metadata.tables
# Out:
# FacadeDict({'happiness': Table('happiness', MetaData(), Column('id', Integer(), table=<happiness>, primary_key=True, nullable=False), Column('country', String(), table=<happiness>), Column('year', Text(), table=<happiness>), Column('happiness', Float(), table=<happiness>), Column('lat', Float(), table=<happiness>), Column('lon', Float(), table=<happiness>), schema=None), 'gini': Table('gini', MetaData(), Column('id', Integer(), table=<gini>, primary_key=True, nullable=False), Column('country', String(), table=<gini>), Column('country_code', String(), table=<gini>), Column('year', Text(), table=<gini>), Column('gini', Float(), table=<gini>), Column('lat', Float(), table=<gini>), Column('lon', Float(), table=<gini>), schema=None), 'demographic': Table('demographic', MetaData(), Column('id', Integer(), table=<demographic>, primary_key=True, nullable=False), Column('country', String(), table=<demographic>), Column('region_id', String(), table=<demographic>), Column('year', Text(), table=<demographic>), Column('gdp', Float(), table=<demographic>), Column('population', Float(), table=<demographic>), Column('lat', Float(), table=<demographic>), Column('lon', Float(), table=<demographic>), schema=None), 'geo': Table('geo', MetaData(), Column('id', Integer(), table=<geo>, primary_key=True, nullable=False), Column('country', String(), table=<geo>), Column('lat', Float(), table=<geo>), Column('lon', Float(), table=<geo>), Column('init', String(), table=<geo>), schema=None)})

# %%
engine = create_engine("sqlite:///../db/data.sqlite")

# %%
Base.metadata.create_all(engine)

# %%
session = Session(engine)

# %%
for i in geo_df.index:
    session.add(Geo(
        country = geo_df["country_name"][i], 
        lat = geo_df["latitude"][i],
        lon = geo_df["longitude"][i],
        init = geo_df["country"][i]
    ))

# %%
engine.execute("SELECT * FROM Geo").fetchall()
# Out:
# []

# %%
session.new
# Out:
# IdentitySet([<__main__.Geo object at 0x7ffea56d9a60>, <__main__.Geo object at 0x7ffea56d9be0>, <__main__.Geo object at 0x7ffea56d9910>, <__main__.Geo object at 0x7ffea56d9d30>, <__main__.Geo object at 0x7ffea56d9ca0>, <__main__.Geo object at 0x7ffea56d9e20>, <__main__.Geo object at 0x7ffea56d9df0>, <__main__.Geo object at 0x7ff
0x7ffea56e63a0>, <__main__.Geo object at 0x7ffea56e6430>, <__main__.Geo object at 0x7ffea56e64c0>, <__main__.Geo object at 0x7ffea56e6550>, <__main__.Geo object at 0x7ffea56e65e0>, <__main__.Geo object at 0x7ffea56e6670>, <__main__.Geo object at 0x7ffea56e6700>, <__main__.Geo object at 0x7ffea56e6790>, <__main__.Geo object at 0x7ffea56e6820>, <__main__.Geo object at 0x7ffea56e68b0>, <__main__.Geo object at 0x7ffea56e6940>, <__main__.Geo object at 0x7ffea56e69d0>, <__main__.Geo object at 0x7ffea56e6a60>, <__main__.Geo object at 0x7ffea56e6af0>, <__main__.Geo object at 0x7ffea56e6b80>, <__main__.Geo object at 0x7ffea56e6c10>, <__main__.Geo object at 0x7ffea56e6ca0>, <__main__.Geo object at 0x7ffea56e6d30>, <__main__.Geo object at 0x7ffea54a1f10>, <__main__.Geo object at 0x7ffea54b9910>, <__main__.Geo object at 0x7ffea54b96a0>, <__main__.Geo object at 0x7ffea545f880>, <__main__.Geo object at 0x7ffea53c7e50>, <__main__.Geo object at 0x7ffea567cca0>, <__main__.Geo object at 0x7ffea567cbe0>, <__main__.Geo object at 0x7ffea567caf0>, <__main__. ...

# %%
session.commit()

# %%
session.new
# Out:
# IdentitySet([])

# %%
session.query(Geo.country, Geo.lat, Geo.lon, Geo.init).all()
# Out:
# [('Andorra', 42.546245, 1.601554, 'AD'),
#  ('United Arab Emirates', 23.424076, 53.847818, 'AE'),
#  ('Afghanistan', 33.93911, 67.709953, 'AF'),
#  ('Antigua and Barbuda', 17.060816, -61.796428, 'AG'),
#  ('Anguilla', 18.220554, -63.068615, 'AI'),
#  ('Albania', 41.153332, 20.168331, 'AL'),
#  ('Armenia', 40.069099, 45.038189, 'AM'),
#  ('Netherlands Antilles', 12.226079, -69.060087, 'AN'),
#  ('Angola', -11.202692, 17.873887, 'AO'),
#  ('Antarctica', -75.250973, -0.071389, 'AQ'),
#  ('Argentina', -38.416097, -63.616672, 'AR'),
#  ('American Samoa', -14.270972, -170.132217, 'AS'),
#  ('Austria', 47.516231, 14.550072, 'AT'),
#  ('Australia', -25.274398, 133.775136, 'AU'),
#  ('Aruba', 12.52111, -69.968338, 'AW'),
#  ('Azerbaijan', 40.143105, 47.576927, 'AZ'),
#  ('Bosnia and Herzegovina', 43.915886, 17.679076, 'BA'),
#  ('Barbados', 13.193887, -59.543198, 'BB'),
#  ('Bangladesh', 23.684994, 90.356331, 'BD'),
#  ('Belgium', 50.503887, 4.469936, 'BE'),
#  ('Burkina Faso', 12.238333, -1.561593, 'BF'),
#  ('Bulgaria', 42.733883, 25.48583, 'BG'),
#  ('Bahrain', 25.930414, 50.637772, 'BH'),
#  ('Burundi', -3.373056, 29.918886, 'BI'),
#  ('Benin', 9.30769, 2.315834, 'BJ'),
#  ('Bermuda', 32.321384, -64.75737, 'BM'),
#  ('Brunei', 4.535277, 114.727669, 'BN'),
#  ('Bolivia', -16.290154, -63.588653, 'BO'),
#  ('Brazil', -14.235004, -51.92528, 'BR'),
#  ('Bahamas', 25.03428, -77.39628, 'BS'),
#  ('Bhutan', 27.514162, 90.433601, 'BT'),
#  ('Bouvet Island', -54.423199, 3.413194, 'BV'),
#  ('Botswana', -22.328474, 24.684866, 'BW'),
#  ('Belarus', 53.709807, 27.953389, 'BY'),
#  ('Belize', 17.189877, -88.49765, 'BZ'),
#  ('Canada', 56.130366, -106.346771, 'CA'),
#  ('Cocos [Keeling] Islands', -12.164165, 96.870956, 'CC'),
#  ('Congo [DRC]', -4.038333, 21.758664, 'CD'),
#  ('Central African Republic', 6.611111, 20.939444, 'CF'),
#  ('Congo [Republic]', -0.228021, 15.827659, 'CG'),
#  ('Switzerland', 46.818188, 8.227512, 'CH'),
#  ("Côte d'Ivoire", 7.539989, -5.54708, 'CI'),
#  ('Cook Islands', -21.236736, -159.777671, 'CK'),
#  ('Chile', -35.675147, -71.542969, 'CL'),
#  ('Cameroon', 7.369722, 12.354722, 'CM'),
#  ('China', 35.86166, 104.195397, 'CN'),
#  ('Colombia', 4.570868, -74.297333, 'CO'),
#  ('Costa Rica', 9.748917, -83.753428, 'CR'),
#  ('Cuba', 21.521757, -77.781167, 'CU'),
#  ('Cape Verde', 16.002082, -24.013197, 'CV'),
#  ('Christmas Island', -10.447525, 105.690449, 'CX'),
#  ('Cyprus', 35.126413, 33.429859, 'CY'),
#  ('Czech Republic', 49.817492, 15.472962, 'CZ'),
#  ('Germany', 51.165691, 10.451526, 'DE'),
#  ('Djibouti', 11.825138, 42.590275, 'DJ'),
#  ('Denmark', 56.26392, 9.501785, 'DK'),
#  ('Dominica', 15.414999, -61.370976, 'DM'),
#  ('Dominican Republic', 18.735693, -70.162651, 'DO'),
#  ('Algeria', 28.033886, 1.659626, 'DZ'),
#  ('Ecuador', -1.831239, -78.183406, 'EC'),
#  ('Estonia', 58.595272, 25.013607, 'EE'),
#  ('Egypt', 26.820553, 30.802498, 'EG'),
#  ('Western Sahara', 24.215527, -12.885834, 'EH'),
#  ('Eritrea', 15.179384, 39.782334, 'ER'),
#  ('Spain', 40.463667, -3.74922, 'ES'),
#  ('Ethiopia', 9.145, 40.489673, 'ET'),
#  ('Finland', 61.92411, 25.748151, 'FI'),
#  ('Fiji', -16.578193, 179.414413, 'FJ'),
#  ('Falkland Islands [Islas Malvinas]', -51.796253, -59.523613, 'FK'),
#  ('Micronesia', 7.425554, 150.550812, 'FM'),
#  ('Faroe Islands', 61.892635, -6.911806, 'FO'),
#  ('France', 46.227638, 2.213749, 'FR'),
#  ('Gabon', -0.803689, 11.609444, 'GA'),
#  ('United Kingdom', 55.378051, -3.435973, 'GB'),
#  ('Grenada', 12.262776, -61.604171, 'GD'),
#  ('Georgia', 42.315407, 43.356892, 'GE'),
#  ('French Guiana', 3.933889, -53.125782, 'GF'),
#  ('Guernsey', 49.465691, -2.585278, 'GG'),
#  ('Ghana', 7.946527, -1.023194, 'GH'),
#  ('Gibraltar', 36.137741, -5.345374, 'GI'),
#  ('Greenland', 71.706936, -42.604303, 'GL'),
#  ('Gambia', 13.443182, -15.310139, 'GM'),
#  ('Guinea', 9.945587, -9.696645, 'GN'),
#  ('Guadeloupe', 16.995971, -62.067641, 'GP'),
#  ('Equatorial Guinea', 1.650801, 10.267895, 'GQ'),
#  ('Greece', 39.074208, 21.824312, 'GR'),
#  ('South Georgia and the South Sandwich Islands', -54.429579, -36.587909, 'GS'),
#  ('Guatemala', 15.783471, -90.230759, 'GT'),
#  ('Guam', 13.444304, 144.793731, 'GU'),
#  ('Guinea-Bissau', 11.803749, -15.180413, 'GW'),
#  ('Guyana', 4.860416, -58.93018, 'GY'),
#  ('Gaza Strip', 31.354676, 34.308825, 'GZ'),
#  ('Hong Kong', 22.396428, 114.109497, 'HK'),
#  ('Heard Island and McDonald Islands', -53.08181, 73.504158, 'HM'),
#  ('Honduras', 15.199999, -86.241905, 'HN'),
#  ('Croatia', 45.1, 15.2, 'HR'),
#  ('Haiti', 18.971187, -72.285215, 'HT'),
#  ('Hungary', 47.162494, 19.503304, 'HU'),
#  ('Indonesia', -0.789275, 113.921327, 'ID'),
#  ('Ireland', 53.41291, -8.24389, 'IE'),
#  ('Israel', 31.046051, 34.851612, 'IL'),
#  ('Isle of Man', 54.236107, -4.548056, 'IM'),
#  ('India', 20.593684, 78.96288, 'IN'),
#  ('British Indian Ocean Territory', -6.343194, 71.876519, 'IO'),
#  ('Iraq', 33.223191, 43.679291, 'IQ'),
#  ('Iran', 32.427908, 53.688046, 'IR'),
#  ('Iceland', 64.963051, -19.020835, 'IS'),
#  ('Italy', 41.87194, 12.56738, 'IT'),
#  ('Jersey', 49.214439, -2.13125, 'JE'),
#  ('Jamaica', 18.109581, -77.297508, 'JM'),
#  ('Jordan', 30.585164, 36.238414, 'JO'),
#  ('Japan', 36.204824, 138.252924, 'JP'),
#  ('Kenya', -0.023559, 37.906193, 'KE'),
#  ('Kyrgyzstan', 41.20438, 74.766098, 'KG'),
#  ('Cambodia', 12.565679, 104.990963, 'KH'),
#  ('Kiribati', -3.370417, -168.734039, 'KI'),
#  ('Comoros', -11.875001, 43.872219, 'KM'),
#  ('Saint Kitts and Nevis', 17.357822, -62.782998, 'KN'),
#  ('North Korea', 40.339852, 127.510093, 'KP'),
#  ('South Korea', 35.907757, 127.766922, 'KR'),
#  ('Kuwait', 29.31166, 47.481766, 'KW'),
#  ('Cayman Islands', 19.513469, -80.566956, 'KY'),
#  ('Kazakhstan', 48.019573, 66.923684, 'KZ'),
#  ('Laos', 19.85627, 102.495496, 'LA'),
#  ('Lebanon', 33.854721, 35.862285, 'LB'),
#  ('Saint Lucia', 13.909444, -60.978893, 'LC'),
#  ('Liechtenstein', 47.166, 9.555373, 'LI'),
#  ('Sri Lanka', 7.873054, 80.771797, 'LK'),
#  ('Liberia', 6.428055, -9.429499, 'LR'),
#  ('Lesotho', -29.609988, 28.233608, 'LS'),
#  ('Lithuania', 55.169438, 23.881275, 'LT'),
#  ('Luxembourg', 49.815273, 6.129583, 'LU'),
#  ('Latvia', 56.879635, 24.603189, 'LV'),
#  ('Libya', 26.3351, 17.228331, 'LY'),
#  ('Morocco', 31.791702, -7.09262, 'MA'),
#  ('Monaco', 43.750298, 7.412841, 'MC'),
#  ('Moldova', 47.411631, 28.369885, 'MD'),
#  ('Montenegro', 42.708678, 19.37439, 'ME'),
#  ('Madagascar', -18.766947, 46.869107, 'MG'),
#  ('Marshall Islands', 7.131474, 171.184478, 'MH'),
#  ('Macedonia [FYROM]', 41.608635, 21.745275, 'MK'),
#  ('Mali', 17.570692, -3.996166, 'ML'),
#  ('Myanmar [Burma]', 21.913965, 95.956223, 'MM'),
#  ('Mongolia', 46.862496, 103.846656, 'MN'),
#  ('Macau', 22.198745, 113.543873, 'MO'),
#  ('Northern Mariana Islands', 17.33083, 145.38469, 'MP'),
#  ('Martinique', 14.641528, -61.024174, 'MQ'),
#  ('Mauritania', 21.00789, -10.940835, 'MR'),
#  ('Montserrat', 16.742498, -62.187366, 'MS'),
#  ('Malta', 35.937496, 14.375416, 'MT'),
#  ('Mauritius', -20.348404, 57.552152, 'MU'),
#  ('Maldives', 3.202778, 73.22068, 'MV'),
#  ('Malawi', -13.254308, 34.301525, 'MW'),
#  ('Mexico', 23.634501, -102.552784, 'MX'),
#  ('Malaysia', 4.210484, 101.975766, 'MY'),
#  ('Mozambique', -18.665695, 35.529562, 'MZ'),
#  ('Namibia', -22.95764, 18.49041, None),
#  ('New Caledonia', -20.904305, 165.618042, 'NC'),
#  ('Niger', 17.607789, 8.081666, 'NE'),
#  ('Norfolk Island', -29.040835, 167.954712, 'NF'),
#  ('Nigeria', 9.081999, 8.675277, 'NG'),
#  ('Nicaragua', 12.865416, -85.207229, 'NI'),
#  ('Netherlands', 52.132633, 5.291266, 'NL'),
#  ('Norway', 60.472024, 8.468946, 'NO'),
#  ('Nepal', 28.394857, 84.124008, 'NP'),
#  ('Nauru', -0.522778, 166.931503, 'NR'),
#  ('Niue', -19.054445, -169.867233, 'NU'),
#  ('New Zealand', -40.900557, 174.885971, 'NZ'),
#  ('Oman', 21.512583, 55.923255, 'OM'),
#  ('Panama', 8.537981, -80.782127, 'PA'),
#  ('Peru', -9.189967, -75.015152, 'PE'),
#  ('French Polynesia', -17.679742, -149.406843, 'PF'),
#  ('Papua New Guinea', -6.314993, 143.95555, 'PG'),
#  ('Philippines', 12.879721, 121.774017, 'PH'),
#  ('Pakistan', 30.375321, 69.345116, 'PK'),
#  ('Poland', 51.919438, 19.145136, 'PL'),
#  ('Saint Pierre and Miquelon', 46.941936, -56.27111, 'PM'),
#  ('Pitcairn Islands', -24.703615, -127.439308, 'PN'),
#  ('Puerto Rico', 18.220833, -66.590149, 'PR'),
#  ('Palestinian Territories', 31.952162, 35.233154, 'PS'),
#  ('Portugal', 39.399872, -8.224454, 'PT'),
#  ('Palau', 7.51498, 134.58252, 'PW'),
#  ('Paraguay', -23.442503, -58.443832, 'PY'),
#  ('Qatar', 25.354826, 51.183884, 'QA'),
#  ('Réunion', -21.115141, 55.536384, 'RE'),
#  ('Romania', 45.943161, 24.96676, 'RO'),
#  ('Serbia', 44.016521, 21.005859, 'RS'),
#  ('Russia', 61.52401, 105.318756, 'RU'),
#  ('Rwanda', -1.940278, 29.873888, 'RW'),
#  ('Saudi Arabia', 23.885942, 45.079162, 'SA'),
#  ('Solomon Islands', -9.64571, 160.156194, 'SB'),
#  ('Seychelles', -4.679574, 55.491977, 'SC'),
#  ('Sudan', 12.862807, 30.217636, 'SD'),
#  ('Sweden', 60.128161, 18.643501, 'SE'),
#  ('Singapore', 1.352083, 103.819836, 'SG'),
#  ('Saint Helena', -24.143474, -10.030696, 'SH'),
#  ('Slovenia', 46.151241, 14.995463, 'SI'),
#  ('Svalbard and Jan Mayen', 77.553604, 23.670272, 'SJ'),
#  ('Slovakia', 48.669026, 19.699024, 'SK'),
#  ('Sierra Leone', 8.460555, -11.779889, 'SL'),
#  ('San Marino', 43.94236, 12.457777, 'SM'),
#  ('Senegal', 14.497401, -14.452362, 'SN'),
#  ('Somalia', 5.152149, 46.199616, 'SO'),
#  ('Suriname', 3.919305, -56.027783, 'SR'),
#  ('São Tomé and Príncipe', 0.18636, 6.613081, 'ST'),
#  ('El Salvador', 13.794185, -88.89653, 'SV'),
#  ('Syria', 34.802075, 38.996815, 'SY'),
#  ('Swaziland', -26.522503, 31.465866, 'SZ'),
#  ('Turks and Caicos Islands', 21.694025, -71.797928, 'TC'),
#  ('Chad', 15.454166, 18.732207, 'TD'),
#  ('French Southern Territories', -49.280366, 69.348557, 'TF'),
#  ('Togo', 8.619543, 0.824782, 'TG'),
#  ('Thailand', 15.870032, 100.992541, 'TH'),
#  ('Tajikistan', 38.861034, 71.276093, 'TJ'),
#  ('Tokelau', -8.967363, -171.855881, 'TK'),
#  ('Timor-Leste', -8.874217, 125.727539, 'TL'),
#  ('Turkmenistan', 38.969719, 59.556278, 'TM'),
#  ('Tunisia', 33.886917, 9.537499, 'TN'),
#  ('Tonga', -21.178986, -175.198242, 'TO'),
#  ('Turkey', 38.963745, 35.243322, 'TR'),
#  ('Trinidad and Tobago', 10.691803, -61.222503, 'TT'),
#  ('Tuvalu', -7.109535, 177.64933, 'TV'),
#  ('Taiwan', 23.69781, 120.960515, 'TW'),
#  ('Tanzania', -6.369028, 34.888822, 'TZ'),
#  ('Ukraine', 48.379433, 31.16558, 'UA'),
#  ('Uganda', 1.373333, 32.290275, 'UG'),
#  ('U.S. Minor Outlying Islands', None, None, 'UM'),
#  ('United States', 37.09024, -95.712891, 'US'),
#  ('Uruguay', -32.522779, -55.765835, 'UY'),
#  ('Uzbekistan', 41.377491, 64.585262, 'UZ'),
#  ('Vatican City', 41.902916, 12.453389, 'VA'),
#  ('Saint Vincent and the Grenadines', 12.984305, -61.287228, 'VC'),
#  ('Venezuela', 6.42375, -66.58973, 'VE'),
#  ('British Virgin Islands', 18.420695, -64.639968, 'VG'),
#  ('U.S. Virgin Islands', 18.335765, -64.896335, 'VI'),
#  ('Vietnam', 14.058324, 108.277199, 'VN'),
#  ('Vanuatu', -15.376706, 166.959158, 'VU'),
#  ('Wallis and Futuna', -13.768752, -177.156097, 'WF'),
#  ('Samoa', -13.759029, -172.104629, 'WS'),
#  ('Kosovo', 42.602636, 20.902977, 'XK'),
#  ('Yemen', 15.552727, 48.516388, 'YE'),
#  ('Mayotte', -12.8275, 45.166244, 'YT'),
#  ('South Africa', -30.559482, 22.937506, 'ZA'),
#  ('Zambia', -13.133897, 27.849332, 'ZM'),
#  ('Zimbabwe', -19.015438, 29.154857, 'ZW')]

# %%
# Define the joined table
class Join(Base):
    __tablename__ = "join"
    id =Column(Integer, primary_key=True)
    country = Column(String)
    country_code = Column(String)
    region_id = Column(String)
    gdp = Column(Float)
    population = Column(Float)
    lat = Column(Float)
    lon = Column(Float)
    gini = Column(Float)
    happiness = Column(Float)
    gdpPerCap = Column(Float)

# %%
Base.metadata.tables
# Out:
# FacadeDict({'happiness': Table('happiness', MetaData(), Column('id', Integer(), table=<happiness>, primary_key=True, nullable=False), Column('country', String(), table=<happiness>), Column('year', Text(), table=<happiness>), Column('happiness', Float(), table=<happiness>), Column('lat', Float(), table=<happiness>), Column('lon', Float(), table=<happiness>), schema=None), 'gini': Table('gini', MetaData(), Column('id', Integer(), table=<gini>, primary_key=True, nullable=False), Column('country', String(), table=<gini>), Column('country_code', String(), table=<gini>), Column('year', Text(), table=<gini>), Column('gini', Float(), table=<gini>), Column('lat', Float(), table=<gini>), Column('lon', Float(), table=<gini>), schema=None), 'demographic': Table('demographic', MetaData(), Column('id', Integer(), table=<demographic>, primary_key=True, nullable=False), Column('country', String(), table=<demographic>), Column('region_id', String(), table=<demographic>), Column('year', Text(), table=<demographic>), Column('gdp', Float(), table=<demographic>), Column('population', Float(), table=<demographic>), Column('lat', Float(), table=<demographic>), Column('lon', Float(), table=<demographic>), schema=None), 'geo': Table('geo', MetaData(), Column('id', Integer(), table=<geo>, primary_key=True, nullable=False), Column('country', String(), table=<geo>), Column('lat', Float(), table=<geo>), Column('lon', Float(), table=<geo>), Column('init', String(), table=<geo>), schema=None), 'join': Table('join', MetaData(), Column('id', Integer(), table=<join>, primary_key=True, nullable=False), Column('country', String(), table=<join>), Column('country_code', String(), table=<join>), Column('region_id', String(), table=<join>), Column('gdp', Float(), table=<join>), Column('population', Float(), table=<join>), Column('lat', Float(), table=<join>), Column('lon', Float(), table=<join>), Column('gini', Float(), table=<join>), Column('happiness', Float(), table=<join>), Column('gdpPerCap', Float(), table=<join>), schema=None)})

# %%
engine = create_engine("sqlite:///../db/data.sqlite")

# %%
Base.metadata.create_all(engine)

# %%
session = Session(engine)

# %%
for i in joined_df.index:
    session.add(Join(
        country = joined_df["country_name"][i],
        country_code = joined_df["code"][i],
        region_id = joined_df["region_id"][i],
        gdp = joined_df["gdp"][i],
        population = joined_df["population"][i],
        lat = joined_df["latitude"][i],
        lon = joined_df["longitude"][i],
        gini = joined_df["gini"][i],
        happiness = joined_df["happiness"][i],
        gdpPerCap = joined_df["gdpPerCap"][i]
    ))

# %%
engine.execute("SELECT * FROM Geo").fetchall()
# Out:
# [(1, 'Andorra', 42.546245, 1.601554, 'AD'),
#  (2, 'United Arab Emirates', 23.424076, 53.847818, 'AE'),
#  (3, 'Afghanistan', 33.93911, 67.709953, 'AF'),
#  (4, 'Antigua and Barbuda', 17.060816, -61.796428, 'AG'),
#  (5, 'Anguilla', 18.220554, -63.068615, 'AI'),
#  (6, 'Albania', 41.153332, 20.168331, 'AL'),
#  (7, 'Armenia', 40.069099, 45.038189, 'AM'),
#  (8, 'Netherlands Antilles', 12.226079, -69.060087, 'AN'),
#  (9, 'Angola', -11.202692, 17.873887, 'AO'),
#  (10, 'Antarctica', -75.250973, -0.071389, 'AQ'),
#  (11, 'Argentina', -38.416097, -63.616672, 'AR'),
#  (12, 'American Samoa', -14.270972, -170.132217, 'AS'),
#  (13, 'Austria', 47.516231, 14.550072, 'AT'),
#  (14, 'Australia', -25.274398, 133.775136, 'AU'),
#  (15, 'Aruba', 12.52111, -69.968338, 'AW'),
#  (16, 'Azerbaijan', 40.143105, 47.576927, 'AZ'),
#  (17, 'Bosnia and Herzegovina', 43.915886, 17.679076, 'BA'),
#  (18, 'Barbados', 13.193887, -59.543198, 'BB'),
#  (19, 'Bangladesh', 23.684994, 90.356331, 'BD'),
#  (20, 'Belgium', 50.503887, 4.469936, 'BE'),
#  (21, 'Burkina Faso', 12.238333, -1.561593, 'BF'),
#  (22, 'Bulgaria', 42.733883, 25.48583, 'BG'),
#  (23, 'Bahrain', 25.930414, 50.637772, 'BH'),
#  (24, 'Burundi', -3.373056, 29.918886, 'BI'),
#  (25, 'Benin', 9.30769, 2.315834, 'BJ'),
#  (26, 'Bermuda', 32.321384, -64.75737, 'BM'),
#  (27, 'Brunei', 4.535277, 114.727669, 'BN'),
#  (28, 'Bolivia', -16.290154, -63.588653, 'BO'),
#  (29, 'Brazil', -14.235004, -51.92528, 'BR'),
#  (30, 'Bahamas', 25.03428, -77.39628, 'BS'),
#  (31, 'Bhutan', 27.514162, 90.433601, 'BT'),
#  (32, 'Bouvet Island', -54.423199, 3.413194, 'BV'),
#  (33, 'Botswana', -22.328474, 24.684866, 'BW'),
#  (34, 'Belarus', 53.709807, 27.953389, 'BY'),
#  (35, 'Belize', 17.189877, -88.49765, 'BZ'),
#  (36, 'Canada', 56.130366, -106.346771, 'CA'),
#  (37, 'Cocos [Keeling] Islands', -12.164165, 96.870956, 'CC'),
#  (38, 'Congo [DRC]', -4.038333, 21.758664, 'CD'),
#  (39, 'Central African Republic', 6.611111, 20.939444, 'CF'),
#  (40, 'Congo [Republic]', -0.228021, 15.827659, 'CG'),
#  (41, 'Switzerland', 46.818188, 8.227512, 'CH'),
#  (42, "Côte d'Ivoire", 7.539989, -5.54708, 'CI'),
#  (43, 'Cook Islands', -21.236736, -159.777671, 'CK'),
#  (44, 'Chile', -35.675147, -71.542969, 'CL'),
#  (233, 'Venezuela', 6.42375, -66.58973, 'VE'),
#  (234, 'British Virgin Islands', 18.420695, -64.639968, 'VG'),
#  (235, 'U.S. Virgin Islands', 18.335765, -64.896335, 'VI'),
#  (236, 'Vietnam', 14.058324, 108.277199, 'VN'),
#  (237, 'Vanuatu', -15.376706, 166.959158, 'VU'),
#  (238, 'Wallis and Futuna', -13.768752, -177.156097, 'WF'),
#  (239, 'Samoa', -13.759029, -172.104629, 'WS'),
#  (240, 'Kosovo', 42.602636, 20.902977, 'XK'),
#  (241, 'Yemen', 15.552727, 48.516388, 'YE'),
#  (242, 'Mayotte', -12.8275, 45.166244, 'YT'),
#  (243, 'South Africa', -30.559482, 22.937506, 'ZA'),
#  (244, 'Zambia', -13.133897, 27.849332, 'ZM'),
#  (245, 'Zimbabwe', -19.015438, 29.154857, 'ZW')]

# %%
session.new
# Out:
# IdentitySet([<__main__.Join object at 0x7ffea57794c0>, <__main__.Join object at 0x7ffea5779700>, <__main__.Join object at 0x7ffea57796a0>, <__main__.Join object at 0x7ffea5779820>, <__main__.Join object at 0x7ffea5779880>, <__main__.Join object at 0x7ffea57798e0>, <__main__.Join object at 0x7ffea5779940>, <__main__.Join object at 0x7ffea57799a0>, <__main__.Join object at 0x7ffea5779a00>, <__main__.Join object at 0x7ffea5779a60>, <__main__.Join object at 0x7ffea5779ac0>, <__main__.Join object at 0x7ffea5779b20>, <__main__.Join object at 0x7ffea5779b80>, <__main__.Join object at 0x7ffea5779be0>, <__main__.Join object at 0x7ffea5779c40>, <__main__.Join object at 0x7ffea5779cd0>, <__main__.Join object at 0x7ffea5779d30>, <__main__.Join object at 0x7ffea5779d90>, <__main__.Join object at 0x7ffea5779df0>, <__main__.Join object at 0x7ffea5779e50>, <__main__.Join object at 0x7ffea5779eb0>, <__main__.Join object at 0x7ffea5779f10>, <__main__.Join object at 0x7ffea5779c70>, <__main__.Join object at 0x7ffea5779fa0>, <__main__.Join object at 0x7ffea577e040>, <__main__.Join object at 0x7ffea577e0a0>, <__main__.Join object at 0x7ffea577e100>, <__main__.Join object at 0x7ffea577e160>, <__main__.Join object at 0x7ffea577e1c0>, <__main__.Join object at 0x7ffea577e220>, <__main__.Join object at 0x7ffea577e280>, <__main__.Join object at 0x7ffea577e2e0>, <__main__.Join object at 0x7ffea577e340>, <__main__.Join object at 0x7ffea577e3a0>, <__main__.Join object at 0x7ffea577e400>, <__main__.Join object at 0x7ffea577e460>, <__main__.Join object at 0x7ffea577e4c0>, <__main__.Join object at 0x7ffea577e520>, <__main__.Join object at 0x7ffea577e580>, <__main__.Join object at 0x7ffea577e5e0>, <__main__.Join object at 0x7ffea577e640>, <__main__.Join object at 0x7ffea577e6a0>, <__main__.Join object at 0x7ffea577e700>, <__main__.Join object at 0x7ffea577e760>, <__main__.Join object at 0x7ffea577e7c0>, <__main__.Join object at 0x7ffea577e8e0>, <__main__.Join object at 0x7ffea577e940>, <__main__.Join object at 0x7ffea577e9a0>, <__main__.Join object at 0x7ffea577ea00>, <__main__.Join object at 0x7ffea577ea60>, <__main__.Join object at 0x7ffea577eac0>, <__main__.Join object at 0x7ffea577eb20>, <__main__.Join object at 0x7ffea577eb80>, <__main__.Join object at 0x7ffea577ebe0>, <__main__.Join object at 0x7ffea577ec40>, <__main__.Join object at 0x7ffea577eca0>, <__main__.Join object at 0x7ffea577ed00>, <__main__.Join object at 0x7ffea577ed60>, <__main__.Join object at 0x7ffea577edc0>, <__main__.Join object at 0x7ffea577ee20>, <__main__.Join object at 0x7ffea577ee80>, <__main__.Join object at 0x7ffea577eee0>, <__main__.Join object at 0x7ffea577ef40>, <__main__.Join object at 0x7ffea577efa0>, <__main__.Join object at 0x7ffea578a040>, <__main__.Join object at 0x7ffea578a0a0>, <__main__.Join object at 0x7ffea578a100>, <__main__.Join object at 0x7ffea578a160>, <__main__.Join object at 0x7ffea578a1c0>, <__main__.Join object at 0x7ffea578a220>, <__main__.Join object at 0x7ffea578a280>, <__main__.Join object at 0x7ffea578a2e0>, <__main__.Join object at 0x7ffea578a340>, <__main__.Join object at 0x7ffea578a3a0>, <__main__.Join object at 0x7ffea578a400>, <__main__.Join object at 0x7ffea578a460>, <__main__.Join object at 0x7ffea578a4c0>, <__main__.Join object at 0x7ffea578a520>, <__main__.Join object at 0x7ffea578a580>, <__main__.Join object at 0x7ffea578a5e0>, <__main__.Join object at 0x7ffea578a640>, <__main__.Join object at 0x7ffea578a6a0>, <__main__.Join object at 0x7ffea578a700>, <__main__.Join object at 0x7ffea578a760>, <__main__.Join object at 0x7ffea578a7c0>, <__main__.Join object at 0x7ffea578a820>, <__main__.Join object at 0x7ffea578a880>, <__main__.Join object at 0x7ffea578a8e0>, <__main__.Join object at 0x7ffea578a940>, <__main__.Join object at 0x7ffea578a9a0>, <__main__.Join object at 0x7ffea578aa00>, <__main__.Join object at 0x7ffea578aa60>, <__main__.Join object at 0x7ffea578aac0>, <__main__.Join object at 0x7ffea578ab20>, <__main__.Join object at 0x7ffea578ab80 ...

# %%
session.commit()

# %%
session.new
# Out:
# IdentitySet([])

# %%
session.query(Join.country, Join.lat, Join.lon, Join.gdpPerCap).all()
# Out:
# [('Angola', -11.202692, 17.873887, 4105.89),
#  ('Albania', 41.153332, 20.168331, 4676.32),
#  ('Argentina', -38.416097, -63.616672, 10411.87),
#  ('Armenia', 40.069099, 45.038189, 3957.72),
#  ('Australia', -25.274398, 133.775136, 56718.69),
#  ('Austria', 47.516231, 14.550072, 48654.21),
#  ('Azerbaijan', 40.143105, 47.576927, 5927.4),
#  ('Burundi', -3.373056, 29.918886, 340.76),
#  ('Belgium', 50.503887, 4.469936, 45688.67),
#  ('Benin', 9.30769, 2.315834, 1648.44),
#  ('Burkina Faso', 12.238333, -1.561593, 683.61),
#  ('Bangladesh', 23.684994, 90.356331, 1077.34),
#  ('Bulgaria', 42.733883, 25.48583, 7912.02),
#  ('Bosnia and Herzegovina', 43.915886, 17.679076, 5353.48),
#  ('Belarus', 53.709807, 27.953389, 6237.03),
#  ('Moldova', 47.411631, 28.369885, 2069.38),
#  ('Madagascar', -18.766947, 46.869107, 416.0),
#  ('Mexico', 23.634501, -102.552784, 10001.04),
#  ('Mali', 17.570692, -3.996166, 838.51),
#  ('Malta', 35.937496, 14.375416, 27481.34),
#  ('Montenegro', 42.708678, 19.37439, 7494.6),
#  ('Mongolia', 46.862496, 103.846656, 3906.12),
#  ('Mauritania', 21.00789, -10.940835, 1589.76),
#  ('Mauritius', -20.348404, 57.552152, 9822.01),
#  ('Malawi', -13.254308, 34.301525, 525.44),
#  ('Malaysia', 4.210484, 101.975766, 11381.89),
#  ('Namibia', -22.95764, 18.49041, 9583.55),
#  ('Niger', 17.607789, 8.081666, 916.82),
#  ('Nigeria', 9.081999, 8.675277, 2958.35),
#  ('Nicaragua', 12.865416, -85.207229, 2083.66),
#  ('Netherlands', 52.132633, 5.291266, 52546.64),
#  ('Norway', 60.472024, 8.468946, 91116.17),
#  ('Nepal', 28.394857, 84.124008, 685.12),
#  ('Pakistan', 30.375321, 69.345116, 1179.41),
#  ('Panama', 8.537981, -80.782127, 11284.01),
#  ('Peru', -9.189967, -75.015152, 6252.25),
#  ('Philippines', 12.879721, 121.774017, 2752.11),
#  ('Poland', 51.919438, 19.145136, 15061.49),
#  ('Portugal', 39.399872, -8.224454, 22280.9),
#  ('Paraguay', -23.442503, -58.443832, 3976.52),
#  ('Romania', 45.943161, 24.96676, 10104.07),
#  ('Rwanda', -1.940278, 29.873888, 738.83),
#  ('Sudan', 12.862807, 30.217636, 1970.34),
#  ('Senegal', 14.497401, -14.452362, 1092.25),
#  ('Sierra Leone', 8.460555, -11.779889, 616.83),
#  ('El Salvador', 13.794185, -88.89653, 3502.01),
#  ('Serbia', 44.016521, 21.005859, 5821.82),
#  ('Suriname', 3.919305, -56.027783, 8605.5),
#  ('Slovenia', 46.151241, 14.995463, 24478.31),
#  ('Sweden', 60.128161, 18.643501, 57187.1),
#  ('Chad', 15.454166, 18.732207, 1063.55),
#  ('Togo', 8.619543, 0.824782, 589.97),
#  ('Thailand', 15.870032, 100.992541, 5928.19),
#  ('Tajikistan', 38.861034, 71.276093, 1034.36),
#  ('Trinidad and Tobago', 10.691803, -61.222503, 16203.56),
#  ('Tunisia', 33.886917, 9.537499, 4368.49),
#  ('Turkey', 38.963745, 35.243322, 14341.24),
#  ('Tanzania', -6.369028, 34.888822, 952.98),
#  ('Uganda', 1.373333, 32.290275, 783.13),
#  ('Ukraine', 48.379433, 31.16558, 2755.27),
#  ('Uruguay', -32.522779, -55.765835, 14093.6),
#  ('United States', 37.09024, -95.712891, 53114.38),
#  ('Vietnam', 14.058324, 108.277199, 1887.73),
#  ('Kosovo', 42.602636, 20.902977, 3956.75),
#  ('South Africa', -30.559482, 22.937506, 8142.55),
#  ('Zambia', -13.133897, 27.849332, 1895.38)]

# %%
# Define the joined table
class Explain(Base):
    __tablename__ = "explain"
    id =Column(Integer, primary_key=True)
    country = Column(String)
    happiness = Column(Float)
    gdppercap = Column(Float)
    social = Column(Float)
    health = Column(Float)
    freedom = Column(Float)
    generosity = Column(Float)
    corruption = Column(Float)
    residual = Column(Float)

# %%
Base.metadata.tables
# Out:
# FacadeDict({'happiness': Table('happiness', MetaData(), Column('id', Integer(), table=<happiness>, primary_key=True, nullable=False), Column('country', String(), table=<happiness>), Column('year', Text(), table=<happiness>), Column('happiness', Float(), table=<happiness>), Column('lat', Float(), table=<happiness>), Column('lon', Float(), table=<happiness>), schema=None), 'gini': Table('gini', MetaData(), Column('id', Integer(), table=<gini>, primary_key=True, nullable=False), Column('country', String(), table=<gini>), Column('country_code', String(), table=<gini>), Column('year', Text(), table=<gini>), Column('gini', Float(), table=<gini>), Column('lat', Float(), table=<gini>), Column('lon', Float(), table=<gini>), schema=None), 'demographic': Table('demographic', MetaData(), Column('id', Integer(), table=<demographic>, primary_key=True, nullable=False), Column('country', String(), table=<demographic>), Column('region_id', String(), table=<demographic>), Column('year', Text(), table=<demographic>), Column('gdp', Float(), table=<demographic>), Column('population', Float(), table=<demographic>), Column('lat', Float(), table=<demographic>), Column('lon', Float(), table=<demographic>), schema=None), 'geo': Table('geo', MetaData(), Column('id', Integer(), table=<geo>, primary_key=True, nullable=False), Column('country', String(), table=<geo>), Column('lat', Float(), table=<geo>), Column('lon', Float(), table=<geo>), Column('init', String(), table=<geo>), schema=None), 'join': Table('join', MetaData(), Column('id', Integer(), table=<join>, primary_key=True, nullable=False), Column('country', String(), table=<join>), Column('country_code', String(), table=<join>), Column('region_id', String(), table=<join>), Column('gdp', Float(), table=<join>), Column('population', Float(), table=<join>), Column('lat', Float(), table=<join>), Column('lon', Float(), table=<join>), Column('gini', Float(), table=<join>), Column('happiness', Float(), table=<join>), Column('gdpPerCap', Float(), table=<join>), schema=None), 'explain': Table('explain', MetaData(), Column('id', Integer(), table=<explain>, primary_key=True, nullable=False), Column('country', String(), table=<explain>), Column('happiness', Float(), table=<explain>), Column('gdppercap', Float(), table=<explain>), Column('social', Float(), table=<explain>), Column('health', Float(), table=<explain>), Column('freedom', Float(), table=<explain>), Column('generosity', Float(), table=<explain>), Column('corruption', Float(), table=<explain>), Column('residual', Float(), table=<explain>), schema=None)})

# %%
engine = create_engine("sqlite:///../db/data.sqlite")

# %%
Base.metadata.create_all(engine)

# %%
session = Session(engine)

# %%
for i in happi_df.index:
    session.add(Explain(
        country = happi_df["Country"][i],
        happiness = happi_df["Happiness score"][i],
        gdppercap = happi_df["Explained by: GDP per capita"][i],
        social = happi_df["Explained by: Social support"][i],
        health = happi_df["Explained by: Healthy life expectancy"][i],
        freedom = happi_df["Explained by: Freedom to make life choices"][i],
        generosity = happi_df["Explained by: Generosity"][i],
        corruption = happi_df["Explained by: Perceptions of corruption"][i],
        residual = happi_df["Dystopia (1.88) + residual"][i],
    ))

# %%
engine.execute("SELECT * FROM Explain").fetchall()
# Out:
# []

# %%
session.new
# Out:
ain object at 0x7ffea5911dc0>, <__main__.Explain object at 0x7ffea5911e20>, <__main__.Explain object at 0x7ffea5911e80>, <__main__.Explain object at 0x7ffea5911ee0>, <__main__.Explain object at 0x7ffea5911f40>, <__main__.Explain object at 0x7ffea5911fa0>, <__main__.Explain object at 0x7ffea5920040>, <__main__.Explain object at 0x7ffea59200a0>, <__main__.Explain object at 0x7ffea5920100>, <__main__.Explain object at 0x7ffea5920160>, <__main__.Explain object at 0x7ffea59201c0>, <__main__.Explain object at 0x7ffea5920220>, <__main__.Explain object at 0x7ffea5920280>, <__main__.Explain object at 0x7ffea59202e0>, <__main__.Explain object at 0x7ffea5920340>, <__main__.Explain object at 0x7ffea59203a0>, <__main__.Explain object at 0x7ffea5920400>, <__main__.Explain object at 0x7ffea5920460>, <__main__.Explain object at 0x7ffea59204c0>, <__main__.Explain object at 0x7ffea5920520>, <__main__.Explain object at ...

# %%
session.commit()

# %%
session.new
# Out:
# IdentitySet([])

# %%
session.query(Explain.country, Explain.gdppercap, Explain.social, Explain.health).all()
# Out:
# [('Finland', 1.34, 1.587, 0.986),
#  ('Denmark', 1.383, 1.573, 0.996),
#  ('Norway', 1.488, 1.582, 1.028),
#  ('Iceland', 1.38, 1.624, 1.026),
#  ('Netherlands', 1.396, 1.522, 0.999),
#  ('Switzerland', 1.452, 1.526, 1.052),
#  ('Sweden', 1.387, 1.487, 1.009),
#  ('New Zealand', 1.303, 1.557, 1.026),
#  ('Canada', 1.365, 1.505, 1.039),
#  ('Austria', 1.376, 1.475, 1.016),
#  ('Australia', 1.372, 1.548, 1.036),
#  ('Costa Rica', 1.034, 1.441, 0.963),
#  ('Israel', 1.276, 1.455, 1.029),
#  ('Luxembourg', 1.609, 1.479, 1.012),
#  ('United Kingdom', 1.333, 1.538, 0.996),
#  ('Ireland', 1.499, 1.553, 0.999),
#  ('Germany', 1.373, 1.454, 0.987),
#  ('Belgium', 1.356, 1.504, 0.986),
#  ('United States', 1.433, 1.457, 0.874),
#  ('Czech Republic', 1.269, 1.487, 0.92),
#  ('United Arab Emirates', 1.503, 1.31, 0.825),
#  ('Malta', 1.3, 1.52, 0.999),
#  ('Mexico', 1.07, 1.323, 0.861),
#  ('France', 1.324, 1.472, 1.045),
#  ('Taiwan Province of China', 1.368, 1.43, 0.914),
#  ('Chile', 1.159, 1.369, 0.92),
#  ('Guatemala', 0.8, 1.269, 0.746),
#  ('Saudi Arabia', 1.403, 1.357, 0.795),
#  ('Qatar', 1.684, 1.313, 0.871),
#  ('Spain', 1.286, 1.484, 1.062),
#  ('Panama', 1.149, 1.442, 0.91),
#  ('Brazil', 1.004, 1.439, 0.802),
#  ('Uruguay', 1.124, 1.465, 0.891),
#  ('Singapore', 1.572, 1.463, 1.141),
#  ('El Salvador', 0.794, 1.242, 0.789),
#  ('Italy', 1.294, 1.488, 1.039),
#  ('Bahrain', 1.362, 1.368, 0.871),
#  ('Slovakia', 1.246, 1.504, 0.881),
#  ('Trinidad and Tobago', 1.231, 1.477, 0.713),
#  ('Poland', 1.206, 1.438, 0.884),
#  ('Uzbekistan', 0.745, 1.529, 0.756),
#  ('Lithuania', 1.238, 1.515, 0.818),
#  ('Colombia', 0.985, 1.41, 0.841),
#  ('Slovenia', 1.258, 1.523, 0.953),
#  ('Nicaragua', 0.694, 1.325, 0.835),
#  ('Kosovo', 0.882, 1.232, 0.758),
#  ('Argentina', 1.092, 1.432, 0.881),
#  ('Romania', 1.162, 1.232, 0.825),
#  ('Cyprus', 1.263, 1.223, 1.042),
#  ('Ecuador', 0.912, 1.312, 0.868),
#  ('Kuwait', 1.5, 1.319, 0.808),
#  ('Thailand', 1.05, 1.409, 0.828),
#  ('Latvia', 1.187, 1.465, 0.812),
#  ('South Korea', 1.301, 1.219, 1.036),
#  ('Estonia', 1.237, 1.528, 0.874),
#  ('Jamaica', 0.831, 1.478, 0.831),
#  ('Mauritius', 1.12, 1.402, 0.798),
#  ('Japan', 1.327, 1.419, 1.088),
#  ('Honduras', 0.642, 1.236, 0.828),
#  ('Kazakhstan', 1.173, 1.508, 0.729),
#  ('Bolivia', 0.776, 1.209, 0.706),
#  ('Hungary', 1.201, 1.41, 0.828),
#  ('Paraguay', 0.855, 1.475, 0.777),
#  ('North Cyprus', 1.263, 1.252, 1.042),
#  ('Peru', 0.96, 1.274, 0.854),
#  ('Portugal', 1.221, 1.431, 0.999),
#  ('Pakistan', 0.677, 0.886, 0.535),
#  ('Russia', 1.183, 1.452, 0.726),
#  ('Philippines', 0.807, 1.293, 0.657),
#  ('Serbia', 1.004, 1.383, 0.854),
#  ('Moldova', 0.685, 1.328, 0.739),
#  ('Libya', 1.044, 1.303, 0.673),
#  ('Montenegro', 1.051, 1.361, 0.871),
#  ('Tajikistan', 0.493, 1.098, 0.718),
#  ('Croatia', 1.155, 1.266, 0.914),
#  ('Hong Kong S.A.R. of China', 1.438, 1.277, 1.122),
#  ('Dominican Republic', 1.015, 1.401, 0.779),
#  ('Bosnia and Herzegovina', 0.945, 1.212, 0.845),
#  ('Turkey', 1.183, 1.36, 0.808),
#  ('Malaysia', 1.221, 1.171, 0.828),
#  ('Belarus', 1.067, 1.465, 0.789),
#  ('Greece', 1.181, 1.156, 0.999),
#  ('Mongolia', 0.948, 1.531, 0.667),
#  ('Macedonia', 0.983, 1.294, 0.838),
#  ('Nigeria', 0.696, 1.111, 0.245),
#  ('Kyrgyzstan', 0.551, 1.438, 0.723),
#  ('Turkmenistan', 1.052, 1.538, 0.657),
#  ('Algeria', 1.002, 1.16, 0.785),
#  ('Morocco', 0.801, 0.782, 0.782),
#  ('Azerbaijan', 1.043, 1.147, 0.769),
#  ('Lebanon', 0.987, 1.224, 0.815),
#  ('Indonesia', 0.931, 1.203, 0.66),
#  ('China', 1.029, 1.125, 0.893),
#  ('Vietnam', 0.741, 1.346, 0.851),
#  ('Bhutan', 0.813, 1.321, 0.604),
#  ('Cameroon', 0.549, 0.91, 0.331),
#  ('Bulgaria', 1.092, 1.513, 0.815),
#  ('Ghana', 0.611, 0.868, 0.486),
#  ('Ivory Coast', 0.569, 0.808, 0.232),
#  ('Nepal', 0.446, 1.226, 0.677),
#  ('Jordan', 0.837, 1.225, 0.815),
#  ('Benin', 0.393, 0.437, 0.397),
#  ('Congo (Brazzaville)', 0.673, 0.799, 0.508),
#  ('Gabon', 1.057, 1.183, 0.571),
#  ('Laos', 0.764, 1.03, 0.551),
#  ('South Africa', 0.96, 1.351, 0.469),
#  ('Albania', 0.947, 0.848, 0.874),
#  ('Venezuela', 0.96, 1.427, 0.805),
#  ('Cambodia', 0.574, 1.122, 0.637),
#  ('Palestinian Territories', 0.657, 1.247, 0.672),
#  ('Senegal', 0.45, 1.134, 0.571),
#  ('Somalia', 0.0, 0.698, 0.268),
#  ('Namibia', 0.879, 1.313, 0.477),
#  ('Niger', 0.138, 0.774, 0.366),
#  ('Burkina Faso', 0.331, 1.056, 0.38),
#  ('Armenia', 0.85, 1.055, 0.815),
#  ('Iran', 1.1, 0.842, 0.785),
#  ('Guinea', 0.38, 0.829, 0.375),
#  ('Georgia', 0.886, 0.666, 0.752),
#  ('Gambia', 0.308, 0.939, 0.428),
#  ('Kenya', 0.512, 0.983, 0.581),
#  ('Mauritania', 0.57, 1.167, 0.489),
#  ('Mozambique', 0.204, 0.986, 0.39),
#  ('Tunisia', 0.921, 1.0, 0.815),
#  ('Bangladesh', 0.562, 0.928, 0.723),
#  ('Iraq', 1.043, 0.98, 0.574),
#  ('Congo (Kinshasa)', 0.094, 1.125, 0.357),
#  ('Mali', 0.385, 1.105, 0.308),
#  ('Sierra Leone', 0.268, 0.841, 0.242),
#  ('Sri Lanka', 0.949, 1.265, 0.831),
#  ('Myanmar', 0.71, 1.181, 0.555),
#  ('Chad', 0.35, 0.766, 0.192),
#  ('Ukraine', 0.82, 1.39, 0.739),
#  ('Ethiopia', 0.336, 1.033, 0.532),
#  ('Swaziland', 0.811, 1.149, 0.0),
#  ('Uganda', 0.332, 1.069, 0.443),
#  ('Egypt', 0.913, 1.039, 0.644),
#  ('Zambia', 0.578, 1.058, 0.426),
#  ('Togo', 0.275, 0.572, 0.41),
#  ('India', 0.755, 0.765, 0.588),
#  ('Liberia', 0.073, 0.922, 0.443),
#  ('Comoros', 0.274, 0.757, 0.505),
#  ('Madagascar', 0.274, 0.916, 0.555),
#  ('Lesotho', 0.489, 1.169, 0.168),
#  ('Burundi', 0.046, 0.447, 0.38),
#  ('Zimbabwe', 0.366, 1.114, 0.433),
#  ('Haiti', 0.323, 0.688, 0.449),
#  ('Botswana', 1.041, 1.145, 0.538),
#  ('Syria', 0.619, 0.378, 0.44),
#  ('Malawi', 0.191, 0.56, 0.495),
#  ('Yemen', 0.287, 1.163, 0.463),
#  ('Rwanda', 0.359, 0.711, 0.614),
#  ('Tanzania', 0.476, 0.885, 0.499),
#  ('Afghanistan', 0.35, 0.517, 0.361),
#  ('Central African Republic', 0.026, 0.0, 0.105),
#  ('South Sudan', 0.306, 0.575, 0.295)]
